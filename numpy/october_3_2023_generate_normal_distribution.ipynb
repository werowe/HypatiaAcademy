# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/numpy/october_3_2023_generate_normal_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import random
import numpy as np

mean=2654
std=2831

x = random.normal(loc=mean, scale=std, size=(76,)).astype(np.int16)

print(x)
# Out:
# [ 4971  -106  6663  1530  2258  6691 -2497   180  4334  1855  4602    47
#   4514  -184  1466  4219   -99  7734   -63  5175  5066  3177  3465  2500
#   3901 -1623  -140  7293  6583   216 -2105  2228  2254  3611  -545  2189
#  10529   418  2532  5601  1027 -4666 -3165  2928  2619  3743  -284  6822
#   2107  -912   944  2544  1463  1964  4623  2125  -765  -503  1337  6629
#   7902  4769 -2218  4132  6164  2423 -2525  3152   202  2527  7875  2791
#   3337   425  5216 -2217]

# %%
np.array([ [1,2,3],
          [4,5,6]
          ])

np.array([1,2,3,4,5,6])
# Out:
# 852

# %%
r1 = np.mean(r)
print("\nMean: ", r1)

r2 = np.std(r)
print("\nstd: ", r2)

r3 = np.var(r)
print("\nvariance: ", r3)
# Out:
# Mean:  2166.38
#
# std:  2753.2333783390027
#
# variance:  7580294.035599999

# %%
r2*r2
# Out:
# 7580294.035599998

# %%
import matplotlib.pyplot as plt

# Create a line plot of the values in r
plt.plot(r)

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Line Curve of Random Data')

# Show the plot
plt.show()

# %%
# z = x - mean / std

# this is not logical because here we take the entire array and subtract the mean from every element then divide by std

# home work

# fix this



z=(r - mean )/ std

print(z)
# Out:
# [-0.6365242  -1.34122218  0.3447545  -0.85199576 -0.17484988  1.75838926
#   1.19321794  0.06711409  0.97209467  0.91345814  0.51183327  0.74320028
#  -1.55634052  1.18580007  0.85870717 -0.0561639  -0.94348287  0.76827976
#  -1.04344755  0.82797598 -0.94171671 -0.75909573  0.16672554 -0.11409396
#  -0.92476157  1.10173084 -0.4482515   0.53020134 -0.79265277  0.39279407
#  -1.32956552  0.57400212 -2.03461674  0.6718474  -0.00847757 -0.03496998
#  -1.2433769  -0.20240198 -1.19427764 -0.07029318 -1.69092194 -2.30483928
#   0.46096786 -0.2059343   2.12716355  0.80854822  1.45849523 -0.35923702
#   0.92935359 -0.61638997 -0.17979513 -0.54256446 -2.31790887 -0.75944896
#   1.79724479 -1.29742141  0.80324974 -2.14729777  0.19321794 -0.75803603
#  -1.0561639   0.57718121 -0.47651007 -0.2433769   1.42140586 -1.1695514
#  -0.94948781  0.61321088 -0.93006005  0.42670434 -0.21123278  0.37195337
#   1.28011303 -1.42917697 -1.40868951  1.09501943 -0.30060049 -0.17379018
# ...

# %%
# multiple an array by scalar


a=np.array([1,2,3])

b=a*3
print(b)

(b-2)/2
# Out:
# [3 6 9]
# array([0.5, 2. , 3.5])

# %%
# homework

# create a pandas array of country, x (income),  z (z-score)
# using these 76 countries

# in other words we are going to create random data for these 76 countries based upon
# the random data that we created above


'''
index, country, income, z-score
0,  USA ,
1 , turkey,
2. , greece ,

'''


'''
Monaco
Bermuda
Norway
Luxembourg
Switzerland
Ireland
United States
Denmark
Qatar
Iceland
Singapore
Sweden
Australia
Netherlands
Austria
Israel
Hong Kong *
Finland
Germany
Canada
United Arab Emirates
United Kingdom
Belgium
New Zealand
France
Macao
Japan
Italy
South Korea
Spain
Slovenia
Estonia
Saudi Arabia
Czechia
Portugal
Lithuania
Slovakia
Greece
Latvia
Hungary
Poland
Romania
Chile
China
Russia
Malaysia
Argentina
Turkey
Mexico
Brazil
Thailand
South Africa
Colombia
Ecuador
Indonesia
Ukraine
Egypt
Vietnam
Philippines
Algeria
Iran
Morocco
Sri Lanka
Bangladesh
India
Kenya
Nigeria
Cambodia
Cameroon
Pakistan
Nepal
Myanmar
Ethiopia
Sudan
Niger
Afghanistan
'''
