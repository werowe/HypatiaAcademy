# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/ml/2024_06_04_lr_get_data_ready.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv("https://raw.githubusercontent.com/Annepikson/HypatiaAcademy/master/ml/Top_200_Movies_Dataset_2023(Cleaned).csv")
df


# we want to make a prediction,  we a model that give some inputs x1, x2, x3, ...  we can predict y

# Warner bros movies are highly ranked

# ranking is related to gross sales


#y=rank

#x1=total gross

#x=distributor
# Out:
#      Rank                                      Title Theaters   Total Gross  \
# 0       1                                     Barbie    4,337  $594,254,460
# 1       2                The Super Mario Bros. Movie    4,371  $574,759,600
# 2       3        Spider-Man: Across the Spider-Verse    4,332  $381,178,195
# 3       4             Guardians of the Galaxy Vol. 3    4,450  $358,995,815
# 4       5                                Oppenheimer    3,761  $300,144,670
# ..    ...                                        ...      ...           ...
# 195   196  Contempt4k Restoration - 60th Anniversary        8      $173,816
# 196   197                         The Wrath of Becky      274      $168,109
# 197   198                          The Starling Girl      114      $161,290
# 198   199                          ¡Que viva México!       90      $161,222
# 199   200                                   Enys Men       62      $189,579
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          200 non-null    int64
#  1   Title         200 non-null    object
#  2   Theaters      200 non-null    object
#  3   Total Gross   200 non-null    object
#  4   Release Date  200 non-null    object
#  5   Distributor   200 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.5+ KB

# %%
import re

a = "$594,254,460"

#s=re.sub(r'[\d\.]+', '', a)

s=a.replace('$', '')
t=s.replace(',', '')
int(t)
# Out:
# 594254460

# %%
import re


def tonumber(n):

  s=n.replace('$', '')
  t=s.replace(',', '')
  return int(t)

# %%
tonumber("$555,222,111")
# Out:
# 555222111

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

x2=le.fit_transform(df['Distributor'])

x2
# Out:
# array([49, 44, 10, 48, 44, 48,  1, 48, 20,  3, 48, 28, 28, 43, 48, 44, 44,
#        28, 49, 28, 44, 28, 34, 49, 49, 44, 10, 48, 49,  0, 20, 40, 49, 48,
#         2, 28, 44, 40, 20, 40, 14, 49, 20, 34, 40, 20, 14, 51, 48, 44, 23,
#        44, 14, 12, 28, 44, 20,  2, 20,  3, 11,  2, 40, 42, 11, 49,  2,  2,
#        20,  0, 20, 41, 28, 34, 44, 13, 38, 40, 43, 24,  2, 25, 18, 25, 47,
#        49, 33,  0, 13, 35, 13, 48,  5, 50, 14, 44, 36, 39, 35,  7, 51, 13,
#        43, 33, 40, 17, 44,  5, 33,  5, 13, 16,  8, 11, 35, 14, 24, 17, 13,
#         0, 46, 41, 15, 14, 17, 13, 48,  2,  5,  0, 24,  2,  9, 14, 33, 17,
#        39, 50,  0, 13,  0, 47, 40, 10, 22, 39, 17, 37, 13, 13, 13, 14,  7,
#         2, 17,  0, 26, 24, 39, 13, 39,  4,  6, 27, 30,  0,  0, 40, 29,  0,
#         0,  0, 11,  0, 13, 27, 21,  0,  6, 33, 45, 14, 35, 50, 45,  0,  0,
#        24, 37, 40, 13,  2,  0, 40, 19, 32, 31,  5, 40,  0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from pylab import *
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
y=df['Rank'].values
# Out:
# numpy.ndarray

# %%
x1=df['Total Gross'].apply(tonumber)

# %%
# use capital letters when dealing arrays that has more than one dimension
import numpy as np

X=np.column_stack((x1,x2))
X
# Out:
# array([[594254460,        49],
#        [574759600,        44],
#        [381178195,        10],
#        [358995815,        48],
#        [300144670,        44],
#        [297895447,        48],
#        [684075767,         1],
#        [214504909,        48],
#        [187131806,        20],
#        [180587629,         3],
#        [174116627,        48],
#        [168248955,        28],
#        [157066392,        28],
#        [156248615,        43],
#        [151692473,        48],
#        [145960660,        44],
#        [185535345,        44],
#        [108161389,        28],
#        [108133313,        49],
#        [ 99847538,        28],
#        [ 95043350,        44],
#        [ 93277026,        28],
#        [ 82042800,        34],
#        [ 74469810,        49],
#        [ 67233054,        49],
#        [ 64388510,        44],
#        [ 64267657,        10],
#        [ 62291150,        48],
#        [ 57638006,        49],
#        [ 52460106,         0],
# ...

# %%
X.shape
# Out:
# (200, 2)

# %%
y.shape
# Out:
# (200,)

# %%
X
# Out:
# array([[594254460,        49],
#        [574759600,        44],
#        [381178195,        10],
#        [358995815,        48],
#        [300144670,        44],
#        [297895447,        48],
#        [684075767,         1],
#        [214504909,        48],
#        [187131806,        20],
#        [180587629,         3],
#        [174116627,        48],
#        [168248955,        28],
#        [157066392,        28],
#        [156248615,        43],
#        [151692473,        48],
#        [145960660,        44],
#        [185535345,        44],
#        [108161389,        28],
#        [108133313,        49],
#        [ 99847538,        28],
#        [ 95043350,        44],
#        [ 93277026,        28],
#        [ 82042800,        34],
#        [ 74469810,        49],
#        [ 67233054,        49],
#        [ 64388510,        44],
#        [ 64267657,        10],
#        [ 62291150,        48],
#        [ 57638006,        49],
#        [ 52460106,         0],
# ...

# %%
y
# Out:
# -76.77361344617856

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
np.set_printoptions(suppress=True, precision=10)

print('Coefficients: \n', reg.coef_)
print('\n Intercept: \n', reg.intercept_)
# Out:
# Coefficients:
#  [-0.0000002863 -0.7538366995]
#
#  Intercept:
#  130.29943672732145

# %%
#. y = m1x1 + m2x2 + b

x1, x2 = [594254460,        49]


# so our linear regression model said that the movie rank (y) can be approximated by this formula

# m1 = -0.0000002863
# m2 = -0.7538366995

# for every x1 and every x2

y = -0.0000002863 * x1 -0.7538366995 * x2 + 130.29943672732145

# %%
y
# Out:
# -76.77361344617856

# %% [markdown]
# # to test this we would do a lot
#
#
# now we have our model.  we have to ask:  is it correct?  is it logical?
#
# draw a chart
#
# R-score

# %% [markdown]
# # Homework
#
# Our hypothese is that life expectancy (how long will you live) is
# corelated with
#
# * y =
#
# * Alcohol make that me x1
#
# * life expectancy
#
# * x2 = Diphtheria
#
# * x3 = under-five deaths
#
# * x4 = percentage expenditure
#
# * x5 = Status (use labeleconder)
#
#
# ```
# 'Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling']
#   ```

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/ml/Life%20Expectancy%20Data.csv")

df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')
