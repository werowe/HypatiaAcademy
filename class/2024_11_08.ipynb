# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/2024_11_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input('The first number= '))
b = int(input('The second number= '))


# put loop here so it does not no run forever

i=0
while True and i < 30:
    c = a - b
    if c == 0:
        break
    elif b > c:
        a = b
        b = c
    else:
        a = c

    i=i + 1

print(f'The greatest common divisor is {a}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2331eb3c5691> in <cell line: 1>()
# ----> 1 a = int(input('The first number= '))
#       2 b = int(input('The second number= '))
#       3
#       4
#       5 # put loop here so it does not no run forever
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
a = 17
b = 7*3

print("a={} b={} c={}".format(a,b,a-b))

i=0
while True and i < 30:
    c = a - b
    if c == 0 or c==1:
        break
    elif b > c:
        a = b
        b = c
    else:
        a = c

    print("i={} a={} b={} c={}".format(i, a,b,c))

    i = i + 1

print(f'The greatest common divisor is {a}')
# Out:
# a=17 b=21 c=-4
# i=0 a=21 b=-4 c=-4
# i=1 a=25 b=-4 c=25
# i=2 a=29 b=-4 c=29
# i=3 a=33 b=-4 c=33
# i=4 a=37 b=-4 c=37
# i=5 a=41 b=-4 c=41
# i=6 a=45 b=-4 c=45
# i=7 a=49 b=-4 c=49
# i=8 a=53 b=-4 c=53
# i=9 a=57 b=-4 c=57
# i=10 a=61 b=-4 c=61
# i=11 a=65 b=-4 c=65
# i=12 a=69 b=-4 c=69
# i=13 a=73 b=-4 c=73
# i=14 a=77 b=-4 c=77
# i=15 a=81 b=-4 c=81
# i=16 a=85 b=-4 c=85
# i=17 a=89 b=-4 c=89
# i=18 a=93 b=-4 c=93
# i=19 a=97 b=-4 c=97
# i=20 a=101 b=-4 c=101
# i=21 a=105 b=-4 c=105
# i=22 a=109 b=-4 c=109
# i=23 a=113 b=-4 c=113
# i=24 a=117 b=-4 c=117
# i=25 a=121 b=-4 c=121
# i=26 a=125 b=-4 c=125
# i=27 a=129 b=-4 c=129
# i=28 a=133 b=-4 c=133
# i=29 a=137 b=-4 c=137
# The greatest common divisor is 137

# %% [markdown]
# Homework:  The algorithm does not work when one number is prime and the other is not
# It goes into an infinite loop
#
#
# ![Screenshot 2024-11-08 at 18.57.25.png](data:image/png;base64,...)
