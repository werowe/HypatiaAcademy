# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/2026_03_06_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv("https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/pandas/pandasdata.csv")

df
# Out:
#   StudentName  Grade      Major   Advisor  StudentNumber
# 0        Fred    100       math  Mr Watts            123
# 1         Sam     92    English  Ms Smith            456
# 2      Sally      84  computers  Mr Watts            789
# 3       Susan     93       math  Ms Smith            101
# 4      Arthur     74    biology  Mr Watts            102

# %%
# 1. get dataframe group avisor.
# 2  ["Grade"]  that means a series
# average

df.groupby("Advisor")["Grade"].mean()
# Out:
# Advisor
# Mr Watts    86.0
# Ms Smith    92.5
# Name: Grade, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['StudentName', 'Grade', 'Major', 'Advisor', 'StudentNumber'], dtype='object')

# %%
df.set_index(df['StudentNumber'],inplace=True)

# %%
df
# Out:
#               StudentName  Grade      Major   Advisor  StudentNumber
# StudentNumber
# 123                  Fred    100       math  Mr Watts            123
# 456                   Sam     92    English  Ms Smith            456
# 789                Sally      84  computers  Mr Watts            789
# 101                 Susan     93       math  Ms Smith            101
# 102                Arthur     74    biology  Mr Watts            102

# %%
df['StudentName']
# Out:
# StudentNumber
# 123      Fred
# 456       Sam
# 789    Sally
# 101     Susan
# 102    Arthur
# Name: StudentName, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 123 to 102
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StudentName    5 non-null      object
#  1   Grade          5 non-null      int64
#  2   Major          5 non-null      object
#  3   Advisor        5 non-null      object
#  4   StudentNumber  5 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 240.0+ bytes

# %%
b = pd.DataFrame({
     "cars": ['mercedes', 'bmw'],
     "colors" : ['white', 'black']
})

b
# Out:
#        cars colors
# 0  mercedes  white
# 1       bmw  black

# %%
df['Grade'].describe()
# Out:
# count      5.000000
# mean      88.600000
# std        9.939819
# min       74.000000
# 25%       84.000000
# 50%       92.000000
# 75%       93.000000
# max      100.000000
# Name: Grade, dtype: float64

# %%
df['Grade'].plot()
# Out:
# <Axes: xlabel='StudentNumber'>

# %%
df
# Out:
#               StudentName  Grade      Major   Advisor  StudentNumber
# StudentNumber
# 123                  Fred    100       math  Mr Watts            123
# 456                   Sam     92    English  Ms Smith            456
# 789                Sally      84  computers  Mr Watts            789
# 101                 Susan     93       math  Ms Smith            101
# 102                Arthur     74    biology  Mr Watts            102

# %%
df
# Out:
#                Grade      Major   Advisor  StudentNumber
# StudentNumber
# 123              100       math  Mr Watts            123
# 456               92    English  Ms Smith            456
# 789               84  computers  Mr Watts            789
# 101               93       math  Ms Smith            101
# 102               74    biology  Mr Watts            102

# %%
# axis = 1 means column
# axis = 0 means row

df.drop("StudentNumber",inplace=True, axis=1)

# %%
# take the dataframe and throw away the index

df_reset = df.reset_index()

# %%
df_reset
# Out:
#    StudentNumber  Grade      Major   Advisor
# 0            123    100       math  Mr Watts
# 1            456     92    English  Ms Smith
# 2            789     84  computers  Mr Watts
# 3            101     93       math  Ms Smith
# 4            102     74    biology  Mr Watts

# %%
df_reset.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df_reset
# Out:
#    StudentNumber  Grade      Major   Advisor
# 0            123    100       math  Mr Watts
# 1            456     92    English  Ms Smith
# 2            789     84  computers  Mr Watts
# 3            101     93       math  Ms Smith
# 4            102     74    biology  Mr Watts

# %%
df_reset.plot.scatter(x="StudentNumber", y="Grade")
# Out:
# <Axes: xlabel='StudentNumber', ylabel='Grade'>

# %%
from datetime import datetime, timedelta
import random

def random_datetime_2025(_):
    start = datetime(2025, 1, 1)
    end = datetime(2026, 1, 1)
    delta = end - start
    random_seconds = random.randrange(int(delta.total_seconds()))
    return start + timedelta(seconds=random_seconds)


random_datetime_2025("2")
# Out:
# datetime.datetime(2025, 8, 29, 20, 59, 26)

# %%
df['enroll_date'] = df['Grade'].map(random_datetime_2025)

# %%
c=df.set_index("enroll_date")

# %%
c.index
# Out:
# DatetimeIndex(['2025-03-11 14:14:52', '2025-04-21 13:33:10',
#                '2025-12-25 06:22:27', '2025-07-10 14:32:54',
#                '2025-04-04 00:03:25'],
#               dtype='datetime64[ns]', name='enroll_date', freq=None)

# %%
df.loc[df['Advisor'] == 'Mr Watts']
# Out:
#                Grade      Major   Advisor         enroll_date
# StudentNumber
# 123              100       math  Mr Watts 2025-03-11 14:14:52
# 789               84  computers  Mr Watts 2025-12-25 06:22:27
# 102               74    biology  Mr Watts 2025-04-04 00:03:25

# %%
df
# Out:
#                Grade      Major   Advisor         enroll_date
# StudentNumber
# 123              100       math  Mr Watts 2025-03-11 14:14:52
# 456               92    English  Ms Smith 2025-04-21 13:33:10
# 789               84  computers  Mr Watts 2025-12-25 06:22:27
# 101               93       math  Ms Smith 2025-07-10 14:32:54
# 102               74    biology  Mr Watts 2025-04-04 00:03:25

# %%
df.loc[df['Advisor'] == 'Mr Watts'].sort_values(by='Grade')
# Out:
#                Grade      Major   Advisor         enroll_date
# StudentNumber
# 102               74    biology  Mr Watts 2025-04-04 00:03:25
# 789               84  computers  Mr Watts 2025-12-25 06:22:27
# 123              100       math  Mr Watts 2025-03-11 14:14:52

# %%
# normal

#c['column_number' = 'value']

c.loc['2025-03-11 14:14:52']
# Out:
# Grade           100
# Major          math
# Advisor    Mr Watts
# Name: 2025-03-11 14:14:52, dtype: object

# %%
c.iloc
# Out:
#                      Grade      Major   Advisor
# enroll_date
# 2025-03-11 14:14:52    100       math  Mr Watts
# 2025-04-21 13:33:10     92    English  Ms Smith
# 2025-12-25 06:22:27     84  computers  Mr Watts
# 2025-07-10 14:32:54     93       math  Ms Smith
# 2025-04-04 00:03:25     74    biology  Mr Watts

# %% [markdown]
# # single row (as Series)
# df.iloc[3]                # 4th row
#
# # single value
# df.iloc[3, 1]             # 4th row, 2nd column
#
# # row slice
# df.iloc[1:4]              # rows 1,2,3
#
# # rows and columns slice
# df.iloc[1:4, 0:2]         # rows 1-3, cols 0-1
#
# # pick specific rows/cols by position
# df.iloc[[0, 2], [1, 3]]   # rows 0 and 2, cols 1 and 3

# %%
df.iloc[0:2]
# Out:
#                Grade    Major   Advisor         enroll_date
# StudentNumber
# 123              100     math  Mr Watts 2025-03-11 14:14:52
# 456               92  English  Ms Smith 2025-04-21 13:33:10

# %%
e=df.iloc[0]
e
# Out:
# Grade                          100
# Major                         math
# Advisor                   Mr Watts
# enroll_date    2025-03-11 14:14:52
# Name: 123, dtype: object

# %%
e.name="george"

e
# Out:
# Grade                          100
# Major                         math
# Advisor                   Mr Watts
# enroll_date    2025-03-11 14:14:52
# Name: george, dtype: object

# %%
# df.loc[from : to - 1]


df.iloc[1:4, 0:2] # rows 1-3, cols 0-1
# Out:
#                Grade      Major
# StudentNumber
# 456               92    English
# 789               84  computers
# 101               93       math

# %%
df.iloc[:, 0:2]
# Out:
#                Grade      Major
# StudentNumber
# 123              100       math
# 456               92    English
# 789               84  computers
# 101               93       math
# 102               74    biology

# %%
df.iloc[-2:,1]
# Out:
# StudentNumber
# 101       math
# 102    biology
# Name: Major, dtype: object

# %%
df.iloc[-2:-1]
# Out:
#                Grade Major   Advisor         enroll_date
# StudentNumber
# 101               93  math  Ms Smith 2025-07-10 14:32:54

# %%
df.iloc[-2:]
# Out:
#                Grade    Major   Advisor         enroll_date
# StudentNumber
# 101               93     math  Ms Smith 2025-07-10 14:32:54
# 102               74  biology  Mr Watts 2025-04-04 00:03:25

# %%
df
# Out:
#                Grade      Major   Advisor         enroll_date
# StudentNumber
# 123              100       math  Mr Watts 2025-03-11 14:14:52
# 456               92    English  Ms Smith 2025-04-21 13:33:10
# 789               84  computers  Mr Watts 2025-12-25 06:22:27
# 101               93       math  Ms Smith 2025-07-10 14:32:54
# 102               74    biology  Mr Watts 2025-04-04 00:03:25

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anandshaw2001/netflix-movies-and-tv-shows")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.34M/1.34M [00:00<00:00, 108MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anandshaw2001/netflix-movies-and-tv-shows/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/anandshaw2001/netflix-movies-and-tv-shows/versions/1
# Out:
# netflix_titles.csv

# %% [markdown]
# Homework
#
#
# Do some exercises use the functions I did against this netflix data
#
# do count by year

# %%
df = pd.read_csv(path + "/netflix_titles.csv")

df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
