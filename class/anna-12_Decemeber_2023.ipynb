# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/anna-12_Decemeber_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URL of the CSV file
data_url = "https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/class/DP_LIVE_05122023161331688.csv"

# Read the data into a pandas DataFrame
df = pd.read_csv(data_url)

# %%
df
# Out:
#        LOCATION INDICATOR       SUBJECT MEASURE FREQUENCY     TIME     Value  \
# 0           AUT       CPI          FOOD  AGRWTH         M  2022-10  14.37008
# 1           AUT       CPI          FOOD  AGRWTH         M  2022-11  15.21099
# 2           AUT       CPI          FOOD  AGRWTH         M  2022-12  16.09756
# 3           AUT       CPI          FOOD  AGRWTH         M  2023-01  16.99219
# 4           AUT       CPI          FOOD  AGRWTH         M  2023-02  16.15970
# ...         ...       ...           ...     ...       ...      ...       ...
# 1683  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-06   6.20000
# 1684  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-07   6.20000
# 1685  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-08   5.90000
# 1686  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-09   5.10000
# 1687  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-10   4.80000
#
#       Flag Codes
# 0            NaN
# ...

# %%
df['priceInDollars']=0
df['dateObject']=0

# %%
df
# Out:
#        LOCATION INDICATOR       SUBJECT MEASURE FREQUENCY     TIME     Value  \
# 0           AUT       CPI          FOOD  AGRWTH         M  2022-10  14.37008
# 1           AUT       CPI          FOOD  AGRWTH         M  2022-11  15.21099
# 2           AUT       CPI          FOOD  AGRWTH         M  2022-12  16.09756
# 3           AUT       CPI          FOOD  AGRWTH         M  2023-01  16.99219
# 4           AUT       CPI          FOOD  AGRWTH         M  2023-02  16.15970
# ...         ...       ...           ...     ...       ...      ...       ...
# 1683  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-06   6.20000
# 1684  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-07   6.20000
# 1685  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-08   5.90000
# 1686  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-09   5.10000
# 1687  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-10   4.80000
#
#       Flag Codes  priceInDollars  dateObject
# ...

# %%
# to convert euros to dollars multiple x 1.07

# so 1 euros is 1.07 dollars

# %%
# use this to convert euros to USD


import requests

# global scope
exchange_rate=0

base_currency = 'EUR'
target_currency = 'USD'
# Make a request to the Open Exchange Rates API
url = f'https://open.er-api.com/v6/latest/{base_currency}'
response = requests.get(url)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    data = response.json()
    # local scope
    exchange_rate = data['rates'][target_currency]
    print(f'1 {base_currency} = {exchange_rate} {target_currency}')
else:
    print(f'Error: Unable to fetch exchange rates. Status code: {response.status_code}')
# Out:
# 1 EUR = 1.076344 USD

# %%
exchange_rate
# Out:
# 1.076344

# %%
from datetime import date

class Price:

  #priceInDollars=0.    # < df['value'] * theNumberfromtheAPI (dollars per euro)
  #priceInEuros=0
  #date = date()

  #county="AUT"


  # define the constructor

  # copied from below.  create an instance of Price

  # price=Price(country,dateText,priceInEuros)

  # parameters just means the items that you pass to a function like a, b, c

  # FIX THE CONSTRUCTOR



  # part of the work is to calculate the price in dollars in a function.  so we will
  # do that later

  def __init__(self, country,dateText,priceInEuros):
  #def __init__(self, parameteers,priceDollars,priceInEuros,date):
        # 1==1. a do nothing line.  I put this here as a placeholder
        self.country = country,
        #self.princeDollars = priceDollars
        self.priceInEuros = priceInEuros
        self.dateText = dateText

  #def setPriceinDollars(self,priceinEuros):
        # do the calculation
        # here you need to multiply priceInEuros * conversionRate (which is dollars per euro)

        # return price in euros * exchange_rate

  # follow this example
  def doublePrice(self):
    return 2 * self.priceInEuros

  #def convertYYYY-MM-to-Dateobject():

      # we have something like this YYYY-MM '2022-10' .  but is no day
      # just make the day be 1

      # then return the value as a date object
      # so remeber from the date lecture we did to create a date you date(day=1, month=10, year=2020)

      # a better way is to use this:

      # from datetime import datetime
      # date_string = '2021-12-31'
      # datetime = datetime.strptime(date_string, '%Y-%m-%d')

  def toString(self):
    return (self.country, self.priceInEuros, self.dateText)

# %%
# we need a way to loop through every row in the dataframe.  because we want to convert every row
# to a class. so we can use the iterrows() method


# we need to make a list of prices

prices = []

for _, row in df.iterrows():

    # so it is easy to convert a dictionary to a call

    priceDict=row.to_dict()
    #print(row.to_dict())

    # look at diana's example
    #telsa = Cars("blue", "")

    # here create a price object

    priceInEuros=priceDict['Value']
    #print(priceInEuros)

    # we need to get yearMonth

    # we need to get country

    # this is not from the dictionary

    country = priceDict['LOCATION']
    dateText = priceDict['TIME']


    # HERE WE CREATE THE PRICE OBJECT


    price=Price(country,dateText,priceInEuros)

    prices.append(price)

# %%
prices[0].doublePrice()
# Out:
# 28.74016

# %%
prices[0].toString()
# Out:
# (('AUT',), 14.37008, '2022-10')

# %%
x={'LOCATION': 'ARG', 'INDICATOR': 'CPI', 'SUBJECT': 'FOOD', 'MEASURE': 'AGRWTH', 'FREQUENCY': 'M', 'TIME': '2023-06', 'Value': 116.8594, 'Flag Codes': 0, 'priceInDollars': 0, 'dateObject': 0}
x['LOCATION']
# Out:
# 'ARG'

# %%
# mistake you made was to take the column from the dataframe df and not the dictionary priceDict


df['LOCATION']
# Out:
# 0             AUT
# 1             AUT
# 2             AUT
# 3             AUT
# 4             AUT
#           ...
# 1683    EU27_2020
# 1684    EU27_2020
# 1685    EU27_2020
# 1686    EU27_2020
# 1687    EU27_2020
# Name: LOCATION, Length: 1688, dtype: object
