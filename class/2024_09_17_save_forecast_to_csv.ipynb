# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/2024_09_17_save_forecast_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

import requests

url = "http://api.openweathermap.org/data/2.5/weather?"

params = {'lat': 50.45,
               'lon': 30.52,
               'appid' : 'bd5e378503939ddaee76f12ad7a97608',
               'units' : 'metric',
               'exclude' : ['daily', 'hourly']
               }


response = requests.get(url, params=params)

print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "coord": {
#         "lon": 30.52,
#         "lat": 50.45
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 11.28,
#         "feels_like": 10.13,
#         "temp_min": 11.28,
#         "temp_max": 12.91,
#         "pressure": 1028,
#         "humidity": 64,
#         "sea_level": 1028,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.89,
#         "deg": 335,
#         "gust": 0.89
#     },
#     "clouds": {
#         "all": 61
#     },
#     "dt": 1726715522,
#     "sys": {
#         "type": 2,
#         "id": 2003742,
#         "country": "UA",
#         "sunrise": 1726717197,
#         "sunset": 1726761807
#     },
#     "timezone": 10800,
#     "id": 696050,
#     "name": "Pushcha-Vodytsya",
#     "cod": 200
# }

# %%
import json

import requests


url="https://api.openweathermap.org/data/2.5/forecast"


params = {'lat': 50.45,
               'lon': 30.52,
               'appid' : 'bd5e378503939ddaee76f12ad7a97608',
               'units' : 'metric',
               'exclude' : ['daily', 'hourly']
               }


response = requests.get(url, params=params)

print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1726725600,
#             "main": {
#                 "temp": 12.67,
#                 "feels_like": 11.3,
#                 "temp_min": 12.67,
#                 "temp_max": 15.44,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 1012,
#                 "humidity": 50,
#                 "temp_kf": -2.77
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 66
#             },
#             "wind": {
#                 "speed": 3.96,
#                 "deg": 74,
#                 "gust": 8.81
#             },
#             "visibility": 10000,
#             "pop": 0,
# ...

# %%
forecast=response.json()['list']

# %%
for f in forecast:
  print(f['dt_txt'])
# Out:
# 2024-09-19 06:00:00
# 2024-09-19 09:00:00
# 2024-09-19 12:00:00
# 2024-09-19 15:00:00
# 2024-09-19 18:00:00
# 2024-09-19 21:00:00
# 2024-09-20 00:00:00
# 2024-09-20 03:00:00
# 2024-09-20 06:00:00
# 2024-09-20 09:00:00
# 2024-09-20 12:00:00
# 2024-09-20 15:00:00
# 2024-09-20 18:00:00
# 2024-09-20 21:00:00
# 2024-09-21 00:00:00
# 2024-09-21 03:00:00
# 2024-09-21 06:00:00
# 2024-09-21 09:00:00
# 2024-09-21 12:00:00
# 2024-09-21 15:00:00
# 2024-09-21 18:00:00
# 2024-09-21 21:00:00
# 2024-09-22 00:00:00
# 2024-09-22 03:00:00
# 2024-09-22 06:00:00
# 2024-09-22 09:00:00
# 2024-09-22 12:00:00
# 2024-09-22 15:00:00
# 2024-09-22 18:00:00
# 2024-09-22 21:00:00
# 2024-09-23 00:00:00
# 2024-09-23 03:00:00
# 2024-09-23 06:00:00
# 2024-09-23 09:00:00
# 2024-09-23 12:00:00
# 2024-09-23 15:00:00
# 2024-09-23 18:00:00
# 2024-09-23 21:00:00
# 2024-09-24 00:00:00
# 2024-09-24 03:00:00

# %%
#Sunrise, sunset at the specific coordinates (I put Kyiv here)


url = 'https://api.sunrise-sunset.org/json?lat=50.450001&lng=30.523333'

# Look in the documentation to see if you can get multiple days on sunrise information in one API call, meaning can date be a range?

params = {'lat': 50.45,
               'lon': 30.52,
          'date': '1997-09-17'
               }


response = requests.get(url, params=params)

print(json.dumps(response.json(), indent=4))


# we want just the key['result'] as the important data is below that.

sunrise=response.json()['results']

#There is no info about how get the multiple days at once
#We can do it only doing seperate API requests
# Out:
# {
#     "results": {
#         "sunrise": "3:34:59 AM",
#         "sunset": "4:09:47 PM",
#         "solar_noon": "9:52:23 AM",
#         "day_length": "12:34:48",
#         "civil_twilight_begin": "3:03:54 AM",
#         "civil_twilight_end": "4:40:53 PM",
#         "nautical_twilight_begin": "2:24:55 AM",
#         "nautical_twilight_end": "5:19:52 PM",
#         "astronomical_twilight_begin": "1:44:00 AM",
#         "astronomical_twilight_end": "6:00:47 PM"
#     },
#     "status": "OK",
#     "tzid": "UTC"
# }

# %%
# we need the data to write to be a list.  because here we only have one row which is the sunrise for one day.  But normall you would have many rows.

days=[]

# add the sunsrise dictionary to the list

days.append(sunrise)

# %%
w=[]

wHeaders=['dateTime', 'temp', 'temp_min', 'temp_max', 'weather', 'windSpeed', 'windDirection']
for f in forecast:

  d={}

  d['dateTime']= f['dt_txt']
  d['temp']=f['main']['temp']
  d['temp_min']=f['main']['temp_min']
  d['temp_max']=f['main']['temp_max']
  d['weather']=f['weather'][0]['main']
  d['windSpeed']=f['wind']['speed']
  d['windDirection']=f['wind']['deg']

  w.append(d)

# %%
d
# Out:
# {'dateTime': '2024-09-24 03:00:00',
#  'temp': 12.01,
#  'temp_min': 12.01,
#  'temp_max': 12.01,
#  'weather': 'Clouds',
#  'windSpeed': 2.2,
#  'windDirection': 132}

# %%
forecast[0]
# Out:
# {'dt': 1726725600,
#  'main': {'temp': 12.67,
#   'feels_like': 11.3,
#   'temp_min': 12.67,
#   'temp_max': 15.44,
#   'pressure': 1028,
#   'sea_level': 1028,
#   'grnd_level': 1012,
#   'humidity': 50,
#   'temp_kf': -2.77},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 66},
#  'wind': {'speed': 3.96, 'deg': 74, 'gust': 8.81},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2024-09-19 06:00:00'}

# %%
with open('forecast.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=wHeaders)
    writer.writeheader()  # Write header
    writer.writerows(w)  # Write data rows

# %%
# !head forecast.csv
# Out:
# dateTime,temp,temp_min,temp_max,weather,windSpeed,windDirection
# 2024-09-19 06:00:00,12.67,12.67,15.44,Clouds,3.96,74
# 2024-09-19 09:00:00,18.37,18.37,21.92,Clouds,4.79,86
# 2024-09-19 12:00:00,24.24,24.24,24.24,Clouds,4.53,74
# 2024-09-19 15:00:00,22.83,22.83,22.83,Clear,3.07,58
# 2024-09-19 18:00:00,18.14,18.14,18.14,Clear,2.15,48
# 2024-09-19 21:00:00,16.1,16.1,16.1,Clear,2.06,36
# 2024-09-20 00:00:00,14.81,14.81,14.81,Clear,1.64,27
# 2024-09-20 03:00:00,13.76,13.76,13.76,Clouds,1.68,22
# 2024-09-20 06:00:00,16.86,16.86,16.86,Clouds,2.66,22

# %%
import csv


# create column headers

columnHeaders=sunrise.keys()


# write the data to a text csv (comma-delimited file) using the csv.DictWriter API

with open('sunrise.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=columnHeaders)
    writer.writeheader()  # Write header
    writer.writerows(days)  # Write data rows

# %%
# !ls
# Out:
# drive  forecast.csv  sample_data  sunrise.csv

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')

# Source path of your file (assuming it's in the current working directory)
source_path = "sunrise.csv"

# Destination path in your Google Drive

destination_path = '/content/drive/My Drive/weather/' + 'sunrise.csv'

# Copy the file
shutil.copy(source_path, destination_path)

print(f'File saved to {destination_path}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File saved to /content/drive/My Drive/weather/sunrise.csv

# %%
# Source path of your file (assuming it's in the current working directory)
source_path = "forecast.csv"

# Destination path in your Google Drive

destination_path = '/content/drive/My Drive/weather/' + 'forecast.csv'

# Copy the file
shutil.copy(source_path, destination_path)

print(f'File saved to {destination_path}')
# Out:
# File saved to /content/drive/My Drive/weather/forecast.csv

# %% [markdown]
# Below we use the bash cat command to print out the results.  Next I will show you how to load this data to Google Sheets
#
# Look in the documentation to see if you can get multiple days on sunrise information in one API call.
#
# If not we will switch to using the weather API to do that.  Because that allows date ranges.  Meaning this one. Go ahead and get an API key from openweathermap.com and try this one (documentation on this API is here:  https://openweathermap.org/api/one-call-3#current)
#
# ```
#
# # we want to use the json and request Python packages
#
#
# import json
#
#
# # requests does get, post, delete
#
# import requests
#
# url = "http://api.openweathermap.org/data/2.5/weather?"
#
# # query line parameters
#
# params = {'lat': 35.17,
#                'lon': 33.37,
#                'appid' : '91d1fc2871fedb0a0d70b09b77963b9b'}
#
#
# response = requests.get(url, params=params)
#
# print(json.dumps(response.json(), indent=4, sort_keys=True))
#
# print("In Nicosia it's hot!!!", response.json()['main']['temp']/10 )
# ```

# %%
# !cat sunrise.csv
# Out:
# sunrise,sunset,solar_noon,day_length,civil_twilight_begin,civil_twilight_end,nautical_twilight_begin,nautical_twilight_end,astronomical_twilight_begin,astronomical_twilight_end
# 3:34:59 AM,4:09:47 PM,9:52:23 AM,12:34:48,3:03:54 AM,4:40:53 PM,2:24:55 AM,5:19:52 PM,1:44:00 AM,6:00:47 PM

# %%
columnHeaders
# Out:
# dict_keys(['sunrise', 'sunset', 'solar_noon', 'day_length', 'civil_twilight_begin', 'civil_twilight_end', 'nautical_twilight_begin', 'nautical_twilight_end', 'astronomical_twilight_begin', 'astronomical_twilight_end'])

# %%
#generates a random sentence using music genres

import json
import requests

url = 'https://binaryjazz.us/wp-json/genrenator/v1/story/'

response = requests.get(url)

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# "I'm really into game denver grunge right now."

# %%
#dictionary

url = 'https://api.dictionaryapi.dev/api/v2/entries/en/hello'

response = requests.get(url)

print(json.dumps(response.json(), indent=3))
# Out:
# [
#    {
#       "word": "hello",
#       "phonetics": [
#          {
#             "audio": "https://api.dictionaryapi.dev/media/pronunciations/en/hello-au.mp3",
#             "sourceUrl": "https://commons.wikimedia.org/w/index.php?curid=75797336",
#             "license": {
#                "name": "BY-SA 4.0",
#                "url": "https://creativecommons.org/licenses/by-sa/4.0"
#             }
#          },
#          {
#             "text": "/h\u0259\u02c8l\u0259\u028a/",
#             "audio": "https://api.dictionaryapi.dev/media/pronunciations/en/hello-uk.mp3",
#             "sourceUrl": "https://commons.wikimedia.org/w/index.php?curid=9021983",
#             "license": {
#                "name": "BY 3.0 US",
#                "url": "https://creativecommons.org/licenses/by/3.0/us"
#             }
#          },
#          {
#             "text": "/h\u0259\u02c8lo\u028a/",
#             "audio": ""
#          }
#       ],
#       "meanings": [
#          {
# ...

# %%
#Information about Disney characters

url = 'https://api.disneyapi.dev/character'

response = requests.get(url)

print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "info": {
#         "count": 50,
#         "totalPages": 149,
#         "previousPage": null,
#         "nextPage": "http://api.disneyapi.dev/character?page=2&pageSize=50"
#     },
#     "data": [
#         {
#             "_id": 112,
#             "films": [
#                 "Hercules (film)"
#             ],
#             "shortFilms": [],
#             "tvShows": [
#                 "Hercules (TV series)"
#             ],
#             "videoGames": [
#                 "Kingdom Hearts III"
#             ],
#             "parkAttractions": [],
#             "allies": [],
#             "enemies": [],
#             "sourceUrl": "https://disney.fandom.com/wiki/Achilles_(Hercules)",
#             "name": "Achilles",
#             "imageUrl": "https://static.wikia.nocookie.net/disney/images/d/d3/Vlcsnap-2015-05-06-23h04m15s601.png",
#             "createdAt": "2021-04-12T01:31:30.547Z",
#             "updatedAt": "2021-12-20T20:39:18.033Z",
# ...

# %%
# flatten

disney = response.json()

for i in range(6):
  d=disney['data'][i]
  for k, v in d.items():
    if isinstance(v, list):
      for j in v:
        print(j)
    else:
      print(v)
# Out:
# 112
# Hercules (film)
# Hercules (TV series)
# Kingdom Hearts III
# https://disney.fandom.com/wiki/Achilles_(Hercules)
# Achilles
# https://static.wikia.nocookie.net/disney/images/d/d3/Vlcsnap-2015-05-06-23h04m15s601.png
# 2021-04-12T01:31:30.547Z
# 2021-12-20T20:39:18.033Z
# https://api.disneyapi.dev/characters/112
# 0
# 18
# The Fox and the Hound
# The Fox and the Hound 2
# https://disney.fandom.com/wiki/Abigail_the_Cow
# Abigail the Cow
# https://static.wikia.nocookie.net/disney/images/0/05/Fox-disneyscreencaps_com-901.jpg
# 2021-04-12T01:26:03.413Z
# 2021-12-20T20:39:18.032Z
# https://api.disneyapi.dev/characters/18
# 0
# 16
# Cheetah
# https://disney.fandom.com/wiki/Abdullah
# Abdullah
# https://static.wikia.nocookie.net/disney/images/c/cb/1087603-44532-clp-950.jpg
# 2021-04-12T01:26:02.377Z
# 2021-12-20T20:39:18.032Z
# https://api.disneyapi.dev/characters/16
# 0
# 45
# Mary Poppins (film)
# Mary Poppins Returns
# https://disney.fandom.com/wiki/Admiral_Boom_and_Mr._Binnacle
# ...

# %%
#lists all the currently available currencies

url = 'https://cdn.jsdelivr.net/npm/@fawazahmed0/currency-api@latest/v1/currencies.json'

response = requests.get(url)

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "1000sats": "",
#     "1inch": "1inch",
#     "aave": "Aave",
#     "ada": "Cardano",
#     "aed": "Emirati Dirham",
#     "afn": "Afghan Afghani",
#     "agix": "SingularityNET",
#     "akt": "Akash Network",
#     "algo": "Algorand",
#     "all": "Albanian Lek",
#     "amd": "Armenian Dram",
#     "amp": "Amp",
#     "ang": "Dutch Guilder",
#     "aoa": "Angolan Kwanza",
#     "ape": "ApeCoin",
#     "apt": "Aptos",
#     "ar": "Arweave",
#     "arb": "Arbitrum",
#     "ars": "Argentine Peso",
#     "atom": "Cosmos",
#     "ats": "Austrian Schilling",
#     "aud": "Australian Dollar",
#     "avax": "Avalanche",
#     "awg": "Aruban or Dutch Guilder",
#     "axs": "Axie Infinity",
#     "azm": "Azerbaijani Manat",
#     "azn": "Azerbaijan Manat",
#     "bake": "BakeryToken",
#     "bam": "Bosnian Convertible Mark",
#     "bat": "Basic Attention Token",
#     "bbd": "Barbadian or Bajan Dollar",
#     "bch": "Bitcoin Cash",
#     "bdt": "Bangladeshi Taka",
# ...

# %%
#generates a random emojie

url = 'https://emojihub.yurace.pro/api/random'

response = requests.get(url)

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "category": "smileys and people",
#     "group": "body",
#     "htmlCode": [
#         "&#128078;",
#         "&#127997;"
#     ],
#     "name": "thumbs down, type-4",
#     "unicode": [
#         "U+1F44E",
#         "U+1F3FD"
#     ]
# }

# %%
#generates a random color palette (rgb format)

url = "http://colormind.io/api/"

data = {
    "model": "default",

}

response = requests.post(url, json=data)

palette = response.json().get('result')
print("Palette:", palette)
# Out:
# Palette: [[47, 36, 44], [119, 73, 79], [165, 113, 102], [239, 229, 178], [226, 140, 88]]

# %%
#all the spells from the Harry Potter

url = 'https://hp-api.herokuapp.com/api/spells'

response = requests.get(url)

print(json.dumps(response.json(), indent=4))
# Out:
# [
#     {
#         "id": "c76a2922-ba4c-4278-baab-44defb631236",
#         "name": "Aberto",
#         "description": "Opens locked doors"
#     },
#     {
#         "id": "06485500-d023-4799-93fd-77f2c3341aa3",
#         "name": "Accio",
#         "description": "Summons objects"
#     },
#     {
#         "id": "acbc0ae1-12e1-4813-b51e-09d22de40475",
#         "name": "Aguamenti",
#         "description": "Summons water"
#     },
#     {
#         "id": "c9d2f389-a419-4f7e-8d3d-254959638019",
#         "name": "Alohomora",
#         "description": "Unlocks objects"
#     },
#     {
#         "id": "018429a5-15d5-41af-bf8f-98a966733d77",
#         "name": "Anapneo",
#         "description": "Clears someone's airway"
#     },
#     {
#         "id": "c828685c-52d2-466d-bcc6-fbcd8376cfb5",
#         "name": "Aparecium",
#         "description": "Reveals secret written messages"
#     },
#     {
#         "id": "7fdd393c-2608-4ef3-9fd0-f691ad6f8b88",
#         "name": "Apparate",
# ...

# %%
#shows what crimes have been done in London today

url = 'https://data.police.uk/api/crimes-street/all-crime?lat=52.629729&lng=-1.131592'

params = {'lat': 51.51,
               'lon': 0.12

               }


response = requests.get(url, params=params)

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# [
#     {
#         "category": "burglary",
#         "context": "",
#         "id": 120298155,
#         "location": {
#             "latitude": "51.522568",
#             "longitude": "-1.132798",
#             "street": {
#                 "id": 1962011,
#                 "name": "On or near Sloane Close"
#             }
#         },
#         "location_subtype": "",
#         "location_type": "Force",
#         "month": "2024-07",
#         "outcome_status": {
#             "category": "Under investigation",
#             "date": "2024-07"
#         },
#         "persistent_id": "5545b17fe9b8503738480bdb55bfc4ab2b10ef600ac8a22be6b73922b8bd34d0"
#     },
#     {
#         "category": "public-order",
#         "context": "",
#         "id": 120296421,
#         "location": {
#             "latitude": "51.503817",
#             "longitude": "-1.121397",
#             "street": {
#                 "id": 1962230,
#                 "name": "On or near Hartslock View"
#             }
# ...

# %%
#Flatten JSON (disney)

import requests
import json
from flatten_json import flatten

url = 'https://api.disneyapi.dev/character'
response = requests.get(url)
data = response.json()


flattened_data = flatten(data)


print("Flattened JSON:")
print(json.dumps(flattened_data, indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-95-fcbb7f29d28b> in <cell line: 5>()
#       3 import requests
#       4 import json
# ----> 5 from flatten_json import flatten
#       6
#       7 url = 'https://api.disneyapi.dev/character'
#
# ModuleNotFoundError: No module named 'flatten_json'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install flatten-json

# %%
#PUBG API

import requests

API_KEY = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5Mzc4M2M2MC01NjQ4LTAxM2QtMjQzZC01MjYyZmIwNzJkYjAiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNzI2NDg0MzI5LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii04YzM0YTMxZS0xNmI5LTQyNmMtOTQxMy04YjJhZjlhMDY3MTgifQ.1DPIX1kNX7dUj5wUzoXCsULPAq3VHeJFmpGWIh3a7YY'
PLAYER_NAME = 'mpPØTATØ'
PLATFORM = 'steam'

headers = {
    'Authorization': f'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5Mzc4M2M2MC01NjQ4LTAxM2QtMjQzZC01MjYyZmIwNzJkYjAiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNzI2NDg0MzI5LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii04YzM0YTMxZS0xNmI5LTQyNmMtOTQxMy04YjJhZjlhMDY3MTgifQ.1DPIX1kNX7dUj5wUzoXCsULPAq3VHeJFmpGWIh3a7YY',
    'Accept': 'application/vnd.api+json'
}


url = f'https://api.pubg.com/shards/steam/players?filter[playerNames]=mpPØTATØ'


response = requests.get(url, headers=headers)

print(json.dumps(response.json(), indent=4, sort_keys=True))
