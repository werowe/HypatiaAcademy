# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/2024_09_17_save_forecast_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests


api_key="563f19204c5b4751e6f9eb0b00aaf357"
URL="https://api.openweathermap.org/data/2.5/forecast"

params={"lat":"49.4413",
        "lon":"32.0643",
        "exclude":"current,minutely,hourly,alerts",
        "appid": api_key,
        "units":"metric",
        "cnt":"56",
        "lang":"ua"}

response=requests.get(URL,params=params)
result=response.json()
print(json.dumps(result, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 49.4413,
#             "lon": 32.0643
#         },
#         "country": "UA",
#         "id": 710791,
#         "name": "Cherkasy",
#         "population": 297568,
#         "sunrise": 1727062794,
#         "sunset": 1727106492,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1727071200,
#             "dt_txt": "2024-09-23 06:00:00",
#             "main": {
#                 "feels_like": 14.5,
#                 "grnd_level": 1007,
#                 "humidity": 52,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 15.53,
#                 "temp_kf": -1.63,
#                 "temp_max": 17.16,
#                 "temp_min": 15.53
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 62,
#                 "gust": 4.7,
#                 "speed": 3.67
#             }
#         },
#         {
#             "clouds": {
#                 "all": 95
#             },
#             "dt": 1727082000,
#             "dt_txt": "2024-09-23 09:00:00",
#             "main": {
#                 "feels_like": 18.16,
#                 "grnd_level": 1007,
#                 "humidity": 45,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 19.03,
#                 "temp_kf": -2.16,
#                 "temp_max": 21.19,
#                 "temp_min": 19.03
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 87,
#                 "gust": 3.75,
#                 "speed": 2.83
#             }
#         },
#         {
#             "clouds": {
#                 "all": 97
#             },
#             "dt": 1727092800,
#             "dt_txt": "2024-09-23 12:00:00",
#             "main": {
#                 "feels_like": 21.54,
#                 "grnd_level": 1006,
#                 "humidity": 38,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 22.27,
#                 "temp_kf": 0,
#                 "temp_max": 22.27,
#                 "temp_min": 22.27
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 121,
#                 "gust": 3.27,
#                 "speed": 2.21
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1727103600,
#             "dt_txt": "2024-09-23 15:00:00",
#             "main": {
#                 "feels_like": 20.07,
#                 "grnd_level": 1005,
#                 "humidity": 43,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 20.81,
#                 "temp_kf": 0,
#                 "temp_max": 20.81,
#                 "temp_min": 20.81
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 59,
#                 "gust": 0.97,
#                 "speed": 0.69
#             }
#         },
#         {
#             "clouds": {
#                 "all": 88
#             },
#             "dt": 1727114400,
#             "dt_txt": "2024-09-23 18:00:00",
#             "main": {
#                 "feels_like": 17.41,
#                 "grnd_level": 1006,
#                 "humidity": 49,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 18.25,
#                 "temp_kf": 0,
#                 "temp_max": 18.25,
#                 "temp_min": 18.25
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 28,
#                 "gust": 2.59,
#                 "speed": 2.71
#             }
#         },
#         {
#             "clouds": {
#                 "all": 42
#             },
#             "dt": 1727125200,
#             "dt_txt": "2024-09-23 21:00:00",
#             "main": {
#                 "feels_like": 15.99,
#                 "grnd_level": 1006,
#                 "humidity": 51,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 16.91,
#                 "temp_kf": 0,
#                 "temp_max": 16.91,
#                 "temp_min": 16.91
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0443\u0440\u0438\u0432\u0447\u0430\u0441\u0442\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 99,
#                 "gust": 4.22,
#                 "speed": 3.26
#             }
#         },
#         {
#             "clouds": {
#                 "all": 33
#             },
#             "dt": 1727136000,
#             "dt_txt": "2024-09-24 00:00:00",
#             "main": {
#                 "feels_like": 14.78,
#                 "grnd_level": 1007,
#                 "humidity": 57,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 15.67,
#                 "temp_kf": 0,
#                 "temp_max": 15.67,
#                 "temp_min": 15.67
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0443\u0440\u0438\u0432\u0447\u0430\u0441\u0442\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "gust": 4.94,
#                 "speed": 3.33
#             }
#         },
#         {
#             "clouds": {
#                 "all": 12
#             },
#             "dt": 1727146800,
#             "dt_txt": "2024-09-24 03:00:00",
#             "main": {
#                 "feels_like": 13.94,
#                 "grnd_level": 1007,
#                 "humidity": 61,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 14.81,
#                 "temp_kf": 0,
#                 "temp_max": 14.81,
#                 "temp_min": 14.81
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 112,
#                 "gust": 4.07,
#                 "speed": 3
#             }
#         },
#         {
#             "clouds": {
#                 "all": 9
#             },
#             "dt": 1727157600,
#             "dt_txt": "2024-09-24 06:00:00",
#             "main": {
#                 "feels_like": 17.42,
#                 "grnd_level": 1007,
#                 "humidity": 46,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 18.33,
#                 "temp_kf": 0,
#                 "temp_max": 18.33,
#                 "temp_min": 18.33
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 103,
#                 "gust": 4.21,
#                 "speed": 3.41
#             }
#         },
#         {
#             "clouds": {
#                 "all": 3
#             },
#             "dt": 1727168400,
#             "dt_txt": "2024-09-24 09:00:00",
#             "main": {
#                 "feels_like": 20.82,
#                 "grnd_level": 1007,
#                 "humidity": 38,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 21.61,
#                 "temp_kf": 0,
#                 "temp_max": 21.61,
#                 "temp_min": 21.61
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 114,
#                 "gust": 4.97,
#                 "speed": 4
#             }
#         },
#         {
#             "clouds": {
#                 "all": 2
#             },
#             "dt": 1727179200,
#             "dt_txt": "2024-09-24 12:00:00",
#             "main": {
#                 "feels_like": 22.81,
#                 "grnd_level": 1006,
#                 "humidity": 36,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 23.47,
#                 "temp_kf": 0,
#                 "temp_max": 23.47,
#                 "temp_min": 23.47
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 93,
#                 "gust": 4.78,
#                 "speed": 4.68
#             }
#         },
#         {
#             "clouds": {
#                 "all": 34
#             },
#             "dt": 1727190000,
#             "dt_txt": "2024-09-24 15:00:00",
#             "main": {
#                 "feels_like": 21.05,
#                 "grnd_level": 1005,
#                 "humidity": 43,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 21.7,
#                 "temp_kf": 0,
#                 "temp_max": 21.7,
#                 "temp_min": 21.7
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0443\u0440\u0438\u0432\u0447\u0430\u0441\u0442\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 106,
#                 "gust": 6.44,
#                 "speed": 3.94
#             }
#         },
#         {
#             "clouds": {
#                 "all": 18
#             },
#             "dt": 1727200800,
#             "dt_txt": "2024-09-24 18:00:00",
#             "main": {
#                 "feels_like": 18.31,
#                 "grnd_level": 1006,
#                 "humidity": 49,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 19.07,
#                 "temp_kf": 0,
#                 "temp_max": 19.07,
#                 "temp_min": 19.07
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 142,
#                 "gust": 5.44,
#                 "speed": 3.82
#             }
#         },
#         {
#             "clouds": {
#                 "all": 1
#             },
#             "dt": 1727211600,
#             "dt_txt": "2024-09-24 21:00:00",
#             "main": {
#                 "feels_like": 16.68,
#                 "grnd_level": 1007,
#                 "humidity": 47,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 17.63,
#                 "temp_kf": 0,
#                 "temp_max": 17.63,
#                 "temp_min": 17.63
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 175,
#                 "gust": 4.96,
#                 "speed": 3.71
#             }
#         },
#         {
#             "clouds": {
#                 "all": 4
#             },
#             "dt": 1727222400,
#             "dt_txt": "2024-09-25 00:00:00",
#             "main": {
#                 "feels_like": 15.68,
#                 "grnd_level": 1007,
#                 "humidity": 53,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 16.58,
#                 "temp_kf": 0,
#                 "temp_max": 16.58,
#                 "temp_min": 16.58
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 192,
#                 "gust": 4.7,
#                 "speed": 3.35
#             }
#         },
#         {
#             "clouds": {
#                 "all": 1
#             },
#             "dt": 1727233200,
#             "dt_txt": "2024-09-25 03:00:00",
#             "main": {
#                 "feels_like": 14.76,
#                 "grnd_level": 1008,
#                 "humidity": 62,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 15.53,
#                 "temp_kf": 0,
#                 "temp_max": 15.53,
#                 "temp_min": 15.53
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 176,
#                 "gust": 3.25,
#                 "speed": 3.06
#             }
#         },
#         {
#             "clouds": {
#                 "all": 5
#             },
#             "dt": 1727244000,
#             "dt_txt": "2024-09-25 06:00:00",
#             "main": {
#                 "feels_like": 18.5,
#                 "grnd_level": 1009,
#                 "humidity": 49,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 19.24,
#                 "temp_kf": 0,
#                 "temp_max": 19.24,
#                 "temp_min": 19.24
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 176,
#                 "gust": 4.8,
#                 "speed": 3.34
#             }
#         },
#         {
#             "clouds": {
#                 "all": 14
#             },
#             "dt": 1727254800,
#             "dt_txt": "2024-09-25 09:00:00",
#             "main": {
#                 "feels_like": 23.22,
#                 "grnd_level": 1008,
#                 "humidity": 44,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 23.65,
#                 "temp_kf": 0,
#                 "temp_max": 23.65,
#                 "temp_min": 23.65
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 133,
#                 "gust": 6.05,
#                 "speed": 4.87
#             }
#         },
#         {
#             "clouds": {
#                 "all": 32
#             },
#             "dt": 1727265600,
#             "dt_txt": "2024-09-25 12:00:00",
#             "main": {
#                 "feels_like": 23.27,
#                 "grnd_level": 1007,
#                 "humidity": 36,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 23.89,
#                 "temp_kf": 0,
#                 "temp_max": 23.89,
#                 "temp_min": 23.89
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0443\u0440\u0438\u0432\u0447\u0430\u0441\u0442\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "gust": 6.99,
#                 "speed": 6.7
#             }
#         },
#         {
#             "clouds": {
#                 "all": 16
#             },
#             "dt": 1727276400,
#             "dt_txt": "2024-09-25 15:00:00",
#             "main": {
#                 "feels_like": 20.66,
#                 "grnd_level": 1007,
#                 "humidity": 45,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 21.3,
#                 "temp_kf": 0,
#                 "temp_max": 21.3,
#                 "temp_min": 21.3
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "gust": 9.22,
#                 "speed": 5.57
#             }
#         },
#         {
#             "clouds": {
#                 "all": 20
#             },
#             "dt": 1727287200,
#             "dt_txt": "2024-09-25 18:00:00",
#             "main": {
#                 "feels_like": 17.11,
#                 "grnd_level": 1008,
#                 "humidity": 52,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 17.91,
#                 "temp_kf": 0,
#                 "temp_max": 17.91,
#                 "temp_min": 17.91
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 159,
#                 "gust": 9.37,
#                 "speed": 4.18
#             }
#         },
#         {
#             "clouds": {
#                 "all": 31
#             },
#             "dt": 1727298000,
#             "dt_txt": "2024-09-25 21:00:00",
#             "main": {
#                 "feels_like": 15.5,
#                 "grnd_level": 1008,
#                 "humidity": 56,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 16.35,
#                 "temp_kf": 0,
#                 "temp_max": 16.35,
#                 "temp_min": 16.35
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0443\u0440\u0438\u0432\u0447\u0430\u0441\u0442\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 137,
#                 "gust": 6.59,
#                 "speed": 4.36
#             }
#         },
#         {
#             "clouds": {
#                 "all": 24
#             },
#             "dt": 1727308800,
#             "dt_txt": "2024-09-26 00:00:00",
#             "main": {
#                 "feels_like": 14.34,
#                 "grnd_level": 1007,
#                 "humidity": 57,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 15.27,
#                 "temp_kf": 0,
#                 "temp_max": 15.27,
#                 "temp_min": 15.27
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 167,
#                 "gust": 3.59,
#                 "speed": 3.06
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1727319600,
#             "dt_txt": "2024-09-26 03:00:00",
#             "main": {
#                 "feels_like": 14.66,
#                 "grnd_level": 1006,
#                 "humidity": 60,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 15.49,
#                 "temp_kf": 0,
#                 "temp_max": 15.49,
#                 "temp_min": 15.49
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 153,
#                 "gust": 4.4,
#                 "speed": 3.39
#             }
#         },
#         {
#             "clouds": {
#                 "all": 88
#             },
#             "dt": 1727330400,
#             "dt_txt": "2024-09-26 06:00:00",
#             "main": {
#                 "feels_like": 18.28,
#                 "grnd_level": 1007,
#                 "humidity": 49,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 19.04,
#                 "temp_kf": 0,
#                 "temp_max": 19.04,
#                 "temp_min": 19.04
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 162,
#                 "gust": 7.05,
#                 "speed": 4.55
#             }
#         },
#         {
#             "clouds": {
#                 "all": 63
#             },
#             "dt": 1727341200,
#             "dt_txt": "2024-09-26 09:00:00",
#             "main": {
#                 "feels_like": 21.91,
#                 "grnd_level": 1006,
#                 "humidity": 40,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 22.55,
#                 "temp_kf": 0,
#                 "temp_max": 22.55,
#                 "temp_min": 22.55
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 134,
#                 "gust": 7.2,
#                 "speed": 5.61
#             }
#         },
#         {
#             "clouds": {
#                 "all": 75
#             },
#             "dt": 1727352000,
#             "dt_txt": "2024-09-26 12:00:00",
#             "main": {
#                 "feels_like": 23.49,
#                 "grnd_level": 1005,
#                 "humidity": 40,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 23.99,
#                 "temp_kf": 0,
#                 "temp_max": 23.99,
#                 "temp_min": 23.99
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 160,
#                 "gust": 6.99,
#                 "speed": 5.85
#             }
#         },
#         {
#             "clouds": {
#                 "all": 69
#             },
#             "dt": 1727362800,
#             "dt_txt": "2024-09-26 15:00:00",
#             "main": {
#                 "feels_like": 22.14,
#                 "grnd_level": 1004,
#                 "humidity": 44,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 22.67,
#                 "temp_kf": 0,
#                 "temp_max": 22.67,
#                 "temp_min": 22.67
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 161,
#                 "gust": 7.3,
#                 "speed": 4.79
#             }
#         },
#         {
#             "clouds": {
#                 "all": 56
#             },
#             "dt": 1727373600,
#             "dt_txt": "2024-09-26 18:00:00",
#             "main": {
#                 "feels_like": 17.73,
#                 "grnd_level": 1004,
#                 "humidity": 57,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 18.35,
#                 "temp_kf": 0,
#                 "temp_max": 18.35,
#                 "temp_min": 18.35
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 142,
#                 "gust": 8.29,
#                 "speed": 4.44
#             }
#         },
#         {
#             "clouds": {
#                 "all": 94
#             },
#             "dt": 1727384400,
#             "dt_txt": "2024-09-26 21:00:00",
#             "main": {
#                 "feels_like": 16.02,
#                 "grnd_level": 1005,
#                 "humidity": 65,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 16.61,
#                 "temp_kf": 0,
#                 "temp_max": 16.61,
#                 "temp_min": 16.61
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 154,
#                 "gust": 6.14,
#                 "speed": 3.88
#             }
#         },
#         {
#             "clouds": {
#                 "all": 79
#             },
#             "dt": 1727395200,
#             "dt_txt": "2024-09-27 00:00:00",
#             "main": {
#                 "feels_like": 15.01,
#                 "grnd_level": 1004,
#                 "humidity": 76,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 15.43,
#                 "temp_kf": 0,
#                 "temp_max": 15.43,
#                 "temp_min": 15.43
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 172,
#                 "gust": 8.39,
#                 "speed": 4.15
#             }
#         },
#         {
#             "clouds": {
#                 "all": 82
#             },
#             "dt": 1727406000,
#             "dt_txt": "2024-09-27 03:00:00",
#             "main": {
#                 "feels_like": 14.68,
#                 "grnd_level": 1003,
#                 "humidity": 80,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 15.03,
#                 "temp_kf": 0,
#                 "temp_max": 15.03,
#                 "temp_min": 15.03
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 167,
#                 "gust": 6.87,
#                 "speed": 4.04
#             }
#         },
#         {
#             "clouds": {
#                 "all": 91
#             },
#             "dt": 1727416800,
#             "dt_txt": "2024-09-27 06:00:00",
#             "main": {
#                 "feels_like": 17.92,
#                 "grnd_level": 1004,
#                 "humidity": 67,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 18.29,
#                 "temp_kf": 0,
#                 "temp_max": 18.29,
#                 "temp_min": 18.29
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 168,
#                 "gust": 9.09,
#                 "speed": 5.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 78
#             },
#             "dt": 1727427600,
#             "dt_txt": "2024-09-27 09:00:00",
#             "main": {
#                 "feels_like": 23.15,
#                 "grnd_level": 1003,
#                 "humidity": 45,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 23.56,
#                 "temp_kf": 0,
#                 "temp_max": 23.56,
#                 "temp_min": 23.56
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 172,
#                 "gust": 8.53,
#                 "speed": 6.77
#             }
#         },
#         {
#             "clouds": {
#                 "all": 85
#             },
#             "dt": 1727438400,
#             "dt_txt": "2024-09-27 12:00:00",
#             "main": {
#                 "feels_like": 25.16,
#                 "grnd_level": 1002,
#                 "humidity": 37,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 25.58,
#                 "temp_kf": 0,
#                 "temp_max": 25.58,
#                 "temp_min": 25.58
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0445\u043c\u0430\u0440\u043d\u043e",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 182,
#                 "gust": 8.29,
#                 "speed": 6.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 70
#             },
#             "dt": 1727449200,
#             "dt_txt": "2024-09-27 15:00:00",
#             "main": {
#                 "feels_like": 24.03,
#                 "grnd_level": 1001,
#                 "humidity": 39,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 24.51,
#                 "temp_kf": 0,
#                 "temp_max": 24.51,
#                 "temp_min": 24.51
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 187,
#                 "gust": 8.59,
#                 "speed": 5.51
#             }
#         },
#         {
#             "clouds": {
#                 "all": 51
#             },
#             "dt": 1727460000,
#             "dt_txt": "2024-09-27 18:00:00",
#             "main": {
#                 "feels_like": 19.11,
#                 "grnd_level": 1003,
#                 "humidity": 53,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 19.7,
#                 "temp_kf": 0,
#                 "temp_max": 19.7,
#                 "temp_min": 19.7
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 172,
#                 "gust": 10.43,
#                 "speed": 4.8
#             }
#         },
#         {
#             "clouds": {
#                 "all": 14
#             },
#             "dt": 1727470800,
#             "dt_txt": "2024-09-27 21:00:00",
#             "main": {
#                 "feels_like": 17.34,
#                 "grnd_level": 1003,
#                 "humidity": 66,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 17.78,
#                 "temp_kf": 0,
#                 "temp_max": 17.78,
#                 "temp_min": 17.78
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u043a\u0456\u043b\u044c\u043a\u0430 \u0445\u043c\u0430\u0440",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 180,
#                 "gust": 10.32,
#                 "speed": 4.48
#             }
#         },
#         {
#             "clouds": {
#                 "all": 7
#             },
#             "dt": 1727481600,
#             "dt_txt": "2024-09-28 00:00:00",
#             "main": {
#                 "feels_like": 16.28,
#                 "grnd_level": 1004,
#                 "humidity": 69,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 16.75,
#                 "temp_kf": 0,
#                 "temp_max": 16.75,
#                 "temp_min": 16.75
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 179,
#                 "gust": 11.54,
#                 "speed": 4.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 4
#             },
#             "dt": 1727492400,
#             "dt_txt": "2024-09-28 03:00:00",
#             "main": {
#                 "feels_like": 15.15,
#                 "grnd_level": 1005,
#                 "humidity": 77,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 15.53,
#                 "temp_kf": 0,
#                 "temp_max": 15.53,
#                 "temp_min": 15.53
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "\u0447\u0438\u0441\u0442\u0435 \u043d\u0435\u0431\u043e",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 177,
#                 "gust": 9.87,
#                 "speed": 4.13
#             }
#         }
#     ],
#     "message": 0
# }

# %%
description="\u0440\u0432\u0430\u043d\u0456 \u0445\u043c\u0430\u0440\u0438"

description.encode('utf-8').decode('utf-8')
# Out:
# 'рвані хмари'

# %%
result
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1727071200,
#    'main': {'temp': 15.53,
#     'feels_like': 14.5,
#     'temp_min': 15.53,
#     'temp_max': 17.16,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 52,
#     'temp_kf': -1.63},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.67, 'deg': 62, 'gust': 4.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-23 06:00:00'},
#   {'dt': 1727082000,
#    'main': {'temp': 19.03,
#     'feels_like': 18.16,
#     'temp_min': 19.03,
#     'temp_max': 21.19,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1007,
#     'humidity': 45,
#     'temp_kf': -2.16},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 2.83, 'deg': 87, 'gust': 3.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-23 09:00:00'},
#   {'dt': 1727092800,
#    'main': {'temp': 22.27,
#     'feels_like': 21.54,
#     'temp_min': 22.27,
#     'temp_max': 22.27,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.21, 'deg': 121, 'gust': 3.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-23 12:00:00'},
#   {'dt': 1727103600,
#    'main': {'temp': 20.81,
#     'feels_like': 20.07,
#     'temp_min': 20.81,
#     'temp_max': 20.81,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1005,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 0.69, 'deg': 59, 'gust': 0.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-23 15:00:00'},
#   {'dt': 1727114400,
#    'main': {'temp': 18.25,
#     'feels_like': 17.41,
#     'temp_min': 18.25,
#     'temp_max': 18.25,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 2.71, 'deg': 28, 'gust': 2.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-23 18:00:00'},
#   {'dt': 1727125200,
#    'main': {'temp': 16.91,
#     'feels_like': 15.99,
#     'temp_min': 16.91,
#     'temp_max': 16.91,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'уривчасті хмари',
#      'icon': '03n'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 3.26, 'deg': 99, 'gust': 4.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-23 21:00:00'},
#   {'dt': 1727136000,
#    'main': {'temp': 15.67,
#     'feels_like': 14.78,
#     'temp_min': 15.67,
#     'temp_max': 15.67,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'уривчасті хмари',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 3.33, 'deg': 111, 'gust': 4.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-24 00:00:00'},
#   {'dt': 1727146800,
#    'main': {'temp': 14.81,
#     'feels_like': 13.94,
#     'temp_min': 14.81,
#     'temp_max': 14.81,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 3, 'deg': 112, 'gust': 4.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-24 03:00:00'},
#   {'dt': 1727157600,
#    'main': {'temp': 18.33,
#     'feels_like': 17.42,
#     'temp_min': 18.33,
#     'temp_max': 18.33,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1007,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 3.41, 'deg': 103, 'gust': 4.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-24 06:00:00'},
#   {'dt': 1727168400,
#    'main': {'temp': 21.61,
#     'feels_like': 20.82,
#     'temp_min': 21.61,
#     'temp_max': 21.61,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1007,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 4, 'deg': 114, 'gust': 4.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-24 09:00:00'},
#   {'dt': 1727179200,
#    'main': {'temp': 23.47,
#     'feels_like': 22.81,
#     'temp_min': 23.47,
#     'temp_max': 23.47,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 4.68, 'deg': 93, 'gust': 4.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-24 12:00:00'},
#   {'dt': 1727190000,
#    'main': {'temp': 21.7,
#     'feels_like': 21.05,
#     'temp_min': 21.7,
#     'temp_max': 21.7,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1005,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'уривчасті хмари',
#      'icon': '03d'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 3.94, 'deg': 106, 'gust': 6.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-24 15:00:00'},
#   {'dt': 1727200800,
#    'main': {'temp': 19.07,
#     'feels_like': 18.31,
#     'temp_min': 19.07,
#     'temp_max': 19.07,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.82, 'deg': 142, 'gust': 5.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-24 18:00:00'},
#   {'dt': 1727211600,
#    'main': {'temp': 17.63,
#     'feels_like': 16.68,
#     'temp_min': 17.63,
#     'temp_max': 17.63,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.71, 'deg': 175, 'gust': 4.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-24 21:00:00'},
#   {'dt': 1727222400,
#    'main': {'temp': 16.58,
#     'feels_like': 15.68,
#     'temp_min': 16.58,
#     'temp_max': 16.58,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.35, 'deg': 192, 'gust': 4.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-25 00:00:00'},
#   {'dt': 1727233200,
#    'main': {'temp': 15.53,
#     'feels_like': 14.76,
#     'temp_min': 15.53,
#     'temp_max': 15.53,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1008,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.06, 'deg': 176, 'gust': 3.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-25 03:00:00'},
#   {'dt': 1727244000,
#    'main': {'temp': 19.24,
#     'feels_like': 18.5,
#     'temp_min': 19.24,
#     'temp_max': 19.24,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1009,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 3.34, 'deg': 176, 'gust': 4.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-25 06:00:00'},
#   {'dt': 1727254800,
#    'main': {'temp': 23.65,
#     'feels_like': 23.22,
#     'temp_min': 23.65,
#     'temp_max': 23.65,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1008,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 4.87, 'deg': 133, 'gust': 6.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-25 09:00:00'},
#   {'dt': 1727265600,
#    'main': {'temp': 23.89,
#     'feels_like': 23.27,
#     'temp_min': 23.89,
#     'temp_max': 23.89,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1007,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'уривчасті хмари',
#      'icon': '03d'}],
#    'clouds': {'all': 32},
#    'wind': {'speed': 6.7, 'deg': 111, 'gust': 6.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-25 12:00:00'},
#   {'dt': 1727276400,
#    'main': {'temp': 21.3,
#     'feels_like': 20.66,
#     'temp_min': 21.3,
#     'temp_max': 21.3,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02d'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 5.57, 'deg': 111, 'gust': 9.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-25 15:00:00'},
#   {'dt': 1727287200,
#    'main': {'temp': 17.91,
#     'feels_like': 17.11,
#     'temp_min': 17.91,
#     'temp_max': 17.91,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1008,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 4.18, 'deg': 159, 'gust': 9.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-25 18:00:00'},
#   {'dt': 1727298000,
#    'main': {'temp': 16.35,
#     'feels_like': 15.5,
#     'temp_min': 16.35,
#     'temp_max': 16.35,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1008,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'уривчасті хмари',
#      'icon': '03n'}],
#    'clouds': {'all': 31},
#    'wind': {'speed': 4.36, 'deg': 137, 'gust': 6.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-25 21:00:00'},
#   {'dt': 1727308800,
#    'main': {'temp': 15.27,
#     'feels_like': 14.34,
#     'temp_min': 15.27,
#     'temp_max': 15.27,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1007,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02n'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 3.06, 'deg': 167, 'gust': 3.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-26 00:00:00'},
#   {'dt': 1727319600,
#    'main': {'temp': 15.49,
#     'feels_like': 14.66,
#     'temp_min': 15.49,
#     'temp_max': 15.49,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 3.39, 'deg': 153, 'gust': 4.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-26 03:00:00'},
#   {'dt': 1727330400,
#    'main': {'temp': 19.04,
#     'feels_like': 18.28,
#     'temp_min': 19.04,
#     'temp_max': 19.04,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1007,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 4.55, 'deg': 162, 'gust': 7.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-26 06:00:00'},
#   {'dt': 1727341200,
#    'main': {'temp': 22.55,
#     'feels_like': 21.91,
#     'temp_min': 22.55,
#     'temp_max': 22.55,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1006,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04d'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 5.61, 'deg': 134, 'gust': 7.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-26 09:00:00'},
#   {'dt': 1727352000,
#    'main': {'temp': 23.99,
#     'feels_like': 23.49,
#     'temp_min': 23.99,
#     'temp_max': 23.99,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1005,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 5.85, 'deg': 160, 'gust': 6.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-26 12:00:00'},
#   {'dt': 1727362800,
#    'main': {'temp': 22.67,
#     'feels_like': 22.14,
#     'temp_min': 22.67,
#     'temp_max': 22.67,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1004,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04d'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 4.79, 'deg': 161, 'gust': 7.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-26 15:00:00'},
#   {'dt': 1727373600,
#    'main': {'temp': 18.35,
#     'feels_like': 17.73,
#     'temp_min': 18.35,
#     'temp_max': 18.35,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1004,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04n'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 4.44, 'deg': 142, 'gust': 8.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-26 18:00:00'},
#   {'dt': 1727384400,
#    'main': {'temp': 16.61,
#     'feels_like': 16.02,
#     'temp_min': 16.61,
#     'temp_max': 16.61,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1005,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 3.88, 'deg': 154, 'gust': 6.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-26 21:00:00'},
#   {'dt': 1727395200,
#    'main': {'temp': 15.43,
#     'feels_like': 15.01,
#     'temp_min': 15.43,
#     'temp_max': 15.43,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1004,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04n'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 4.15, 'deg': 172, 'gust': 8.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 00:00:00'},
#   {'dt': 1727406000,
#    'main': {'temp': 15.03,
#     'feels_like': 14.68,
#     'temp_min': 15.03,
#     'temp_max': 15.03,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1003,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04n'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 4.04, 'deg': 167, 'gust': 6.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 03:00:00'},
#   {'dt': 1727416800,
#    'main': {'temp': 18.29,
#     'feels_like': 17.92,
#     'temp_min': 18.29,
#     'temp_max': 18.29,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1004,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 5.81, 'deg': 168, 'gust': 9.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 06:00:00'},
#   {'dt': 1727427600,
#    'main': {'temp': 23.56,
#     'feels_like': 23.15,
#     'temp_min': 23.56,
#     'temp_max': 23.56,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1003,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04d'}],
#    'clouds': {'all': 78},
#    'wind': {'speed': 6.77, 'deg': 172, 'gust': 8.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 09:00:00'},
#   {'dt': 1727438400,
#    'main': {'temp': 25.58,
#     'feels_like': 25.16,
#     'temp_min': 25.58,
#     'temp_max': 25.58,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1002,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'хмарно',
#      'icon': '04d'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 6.81, 'deg': 182, 'gust': 8.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 12:00:00'},
#   {'dt': 1727449200,
#    'main': {'temp': 24.51,
#     'feels_like': 24.03,
#     'temp_min': 24.51,
#     'temp_max': 24.51,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1001,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04d'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 5.51, 'deg': 187, 'gust': 8.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 15:00:00'},
#   {'dt': 1727460000,
#    'main': {'temp': 19.7,
#     'feels_like': 19.11,
#     'temp_min': 19.7,
#     'temp_max': 19.7,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1003,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'рвані хмари',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 4.8, 'deg': 172, 'gust': 10.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 18:00:00'},
#   {'dt': 1727470800,
#    'main': {'temp': 17.78,
#     'feels_like': 17.34,
#     'temp_min': 17.78,
#     'temp_max': 17.78,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1003,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'кілька хмар',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 4.48, 'deg': 180, 'gust': 10.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 21:00:00'},
#   {'dt': 1727481600,
#    'main': {'temp': 16.75,
#     'feels_like': 16.28,
#     'temp_min': 16.75,
#     'temp_max': 16.75,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1004,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01n'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 4.81, 'deg': 179, 'gust': 11.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-28 00:00:00'},
#   {'dt': 1727492400,
#    'main': {'temp': 15.53,
#     'feels_like': 15.15,
#     'temp_min': 15.53,
#     'temp_max': 15.53,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1005,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'чисте небо',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.13, 'deg': 177, 'gust': 9.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-28 03:00:00'}],
#  'city': {'id': 710791,
#   'name': 'Cherkasy',
#   'coord': {'lat': 49.4413, 'lon': 32.0643},
#   'country': 'UA',
#   'population': 297568,
#   'timezone': 10800,
#   'sunrise': 1727062794,
#   'sunset': 1727106492}}

# %%
result['list'][0]
# Out:
# {'dt': 1727071200,
#  'main': {'temp': 15.53,
#   'feels_like': 14.5,
#   'temp_min': 15.53,
#   'temp_max': 17.16,
#   'pressure': 1018,
#   'sea_level': 1018,
#   'grnd_level': 1007,
#   'humidity': 52,
#   'temp_kf': -1.63},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'хмарно',
#    'icon': '04d'}],
#  'clouds': {'all': 100},
#  'wind': {'speed': 3.67, 'deg': 62, 'gust': 4.7},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2024-09-23 06:00:00'}

# %%
f={}

columnHeaders=[]
weather=[]

getHeader = True

for l in result['list']:

  w = dict()

  for k,v in l.items():


    if isinstance(v,dict):
      for k1,v1 in v.items():
        w[k1]=v1
    elif isinstance(v,list):
      for k2,v2 in v[0].items():
        w[k2]=v2
    else:
      w[k]=v

  print(w)
  weather.append(w)


  if getHeader:
    columnHeaders=w.keys()
    getHeader=False
# Out:
# {'dt': 1727071200, 'temp': 15.53, 'feels_like': 14.5, 'temp_min': 15.53, 'temp_max': 17.16, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1007, 'humidity': 52, 'temp_kf': -1.63, 'id': 804, 'main': 'Clouds', 'description': 'хмарно', 'icon': '04d', 'all': 100, 'speed': 3.67, 'deg': 62, 'gust': 4.7, 'visibility': 10000, 'pop': 0, 'pod': 'd', 'dt_txt': '2024-09-23 06:00:00'}
# {'dt': 1727082000, 'temp': 19.03, 'feels_like': 18.16, 'temp_min': 19.03, 'temp_max': 21.19, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 1007, 'humidity': 45, 'temp_kf': -2.16, 'id': 804, 'main': 'Clouds', 'description': 'хмарно', 'icon': '04d', 'all': 95, 'speed': 2.83, 'deg': 87, 'gust': 3.75, 'visibility': 10000, 'pop': 0, 'pod': 'd', 'dt_txt': '2024-09
 'visibility': 10000, 'pop': 0, 'pod': 'd', 'dt_txt': '2024-09-27 15:00:00'}
# {'dt': 1727460000, 'temp': 19.7, 'feels_like': 19.11, 'temp_min': 19.7, 'temp_max': 19.7, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 1003, 'humidity': 53, 'temp_kf': 0, 'id': 803, 'main': 'Clouds', 'description': 'рвані хмари', 'icon': '04n', 'all': 51, 'speed': 4.8, 'deg': 172, 'gust': 10.43, 'visibility': 10000, 'pop': 0, 'pod': 'n', 'dt_txt': '2024-09-27 18:00:00'}
# {'dt': 1727470800, 'temp': 17.78, 'feels_like': 17.34, 'temp_min': 17.78, 'temp_max': 17.78, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 1003, 'humidity': 66, 'temp_kf': 0, 'id': 801, 'main': 'Clouds', 'description': 'кілька хмар', 'icon': '02n', 'all': 14, 'speed': 4.48, 'deg': 180, 'gust': 10.32, 'visibility': 10000, 'pop': 0, 'pod': 'n', 'dt_txt': '2024-09-27 21:00:00'}
# {'dt': 1727481600, 'temp': 16.75, 'feels_like': 16.28, 'temp_min': 16.75, 'temp_max': 16.75, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 1004, 'humidity': 69, 'temp_kf': 0, 'id': 800, 'main': 'Clear', 'description': 'чисте небо', 'icon': '01n', 'all': 7, 'speed': 4.81, 'deg': 179, 'gust': 11.54, 'visibility': 10000, 'pop': 0, 'pod': 'n', 'dt_txt': '2024-09-28 00:00:00'}
# {'dt': 1727492400, 'temp': 15.53, 'feels_like': 15.15, 'temp_min': 15.53, 'temp_max': 15.53, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 1005, 'humidity': 77, 'temp_kf': 0, 'id': 800, 'main': 'Clear', 'description': 'чисте небо', 'icon': '01n', 'all': 4, 'speed': 4.13, 'deg': 177, 'gust': 9.87, 'visibility': 10000, 'pop': 0, 'pod': 'n', 'dt_txt': '2024-09-28 03:00:00'}

# %%
columnHeaders
# Out:
# dict_keys(['dt', 'temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'sea_level', 'grnd_level', 'humidity', 'temp_kf', 'id', 'main', 'description', 'icon', 'all', 'speed', 'deg', 'gust', 'visibility', 'pop', 'pod', 'dt_txt'])

# %%
import csv

with open('forecast.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=columnHeaders)
    writer.writeheader()  # Write header
    writer.writerows(weather)  # Write data rows

# %%
# !cat forecast.csv
# Out:
# dt,temp,feels_like,temp_min,temp_max,pressure,sea_level,grnd_level,humidity,temp_kf,id,main,description,icon,all,speed,deg,gust,visibility,pop,pod,dt_txt
# 1727071200,15.53,14.5,15.53,17.16,1018,1018,1007,52,-1.63,804,Clouds,хмарно,04d,100,3.67,62,4.7,10000,0,d,2024-09-23 06:00:00
# 1727082000,19.03,18.16,19.03,21.19,1019,1019,1007,45,-2.16,804,Clouds,хмарно,04d,95,2.83,87,3.75,10000,0,d,2024-09-23 09:00:00
# 1727092800,22.27,21.54,22.27,22.27,1018,1018,1006,38,0,804,Clouds,хмарно,04d,97,2.21,121,3.27,10000,0,d,2024-09-23 12:00:00
# 1727103600,20.81,20.07,20.81,20.81,1017,1017,1005,43,0,804,Clouds,хмарно,04d,98,0.69,59,0.97,10000,0,d,2024-09-23 15:00:00
# 1727114400,18.25,17.41,18.25,18.25,1018,1018,1006,49,0,804,Clouds,хмарно,04n,88,2.71,28,2.59,10000,0,n,2024-09-23 18:00:00
# 1727125200,16.91,15.99,16.91,16.91,1018,1018,1006,51,0,802,Clouds,уривчасті хмари,03n,42,3.26,99,4.22,10000,0,n,2024-09-23 21:00:00
# 1727330400,19.04,18.28,19.04,19.04,1018,1018,1007,49,0,804,Clouds,хмарно,04d,88,4.55,162,7.05,10000,0,d,2024-09-26 06:00:00
# 1727341200,22.55,21.91,22.55,22.55,1018,1018,1006,40,0,803,Clouds,рвані хмари,04d,63,5.61,134,7.2,10000,0,d,2024-09-26 09:00:00
# 1727352000,23.99,23.49,23.99,23.99,1016,1016,1005,40,0,803,Clouds,рвані хмари,04d,75,5.85,160,6.99,10000,0,d,2024-09-26 12:00:00
# 1727362800,22.67,22.14,22.67,22.67,1016,1016,1004,44,0,803,Clouds,рвані хмари,04d,69,4.79,161,7.3,10000,0,d,2024-09-26 15:00:00
# 1727373600,18.35,17.73,18.35,18.35,1016,1016,1004,57,0,803,Clouds,рвані хмари,04n,56,4.44,142,8.29,10000,0,n,2024-09-26 18:00:00
# 1727384400,16.61,16.02,16.61,16.61,1016,1016,1005,65,0,804,Clouds,хмарно,04n,94,3.88,154,6.14,10000,0,n,2024-09-26 21:00:00
# 1727395200,15.43,15.01,15.43,15.43,1015,1015,1004,76,0,803,Clouds,рвані хмари,04n,79,4.15,172,8.39,10000,0,n,2024-09-27 00:00:00
# 1727406000,15.03,14.68,15.03,15.03,1015,1015,1003,80,0,803,Clouds,рвані хмари,04n,82,4.04,167,6.87,10000,0,n,2024-09-27 03:00:00
# 1727416800,18.29,17.92,18.29,18.29,1015,1015,1004,67,0,804,Clouds,хмарно,04d,91,5.81,168,9.09,10000,0,d,2024-09-27 06:00:00
# 1727427600,23.56,23.15,23.56,23.56,1014,1014,1003,45,0,803,Clouds,рвані хмари,04d,78,6.77,172,8.53,10000,0,d,2024-09-27 09:00:00
# 1727438400,25.58,25.16,25.58,25.58,1013,1013,1002,37,0,804,Clouds,хмарно,04d,85,6.81,182,8.29,10000,0,d,2024-09-27 12:00:00
# 1727449200,24.51,24.03,24.51,24.51,1013,1013,1001,39,0,803,Clouds,рвані хмари,04d,70,5.51,187,8.59,10000,0,d,2024-09-27 15:00:00
# 1727460000,19.7,19.11,19.7,19.7,1014,1014,1003,53,0,803,Clouds,рвані хмари,04n,51,4.8,172,10.43,10000,0,n,2024-09-27 18:00:00
# 1727470800,17.78,17.34,17.78,17.78,1015,1015,1003,66,0,801,Clouds,кілька хмар,02n,14,4.48,180,10.32,10000,0,n,2024-09-27 21:00:00
# 1727481600,16.75,16.28,16.75,16.75,1016,1016,1004,69,0,800,Clear,чисте небо,01n,7,4.81,179,11.54,10000,0,n,2024-09-28 00:00:00
# 1727492400,15.53,15.15,15.53,15.53,1016,1016,1005,77,0,800,Clear,чисте небо,01n,4,4.13,177,9.87,10000,0,n,2024-09-28 03:00:00

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')



# Source path of your file (assuming it's in the current working directory)
sourcePath = "forecast.csv"

destinationPath = '/content/drive/My Drive/' + sourcePath

# Copy the file
shutil.copy(sourcePath, destinationPath)

print(f'File saved to {destinationPath}')
# Out:
# Mounted at /content/drive
# File saved to /content/drive/My Drive/forecast.csv
