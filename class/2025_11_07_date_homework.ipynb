# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/2025_11_07_date_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Programming **Homework** Assignment: Working with Dates and Times
#
#
#
# **Instructions:**
#
# Using Python’s `datetime` module:
#
# 1. **Import Modules**
#    - Import `datetime` and `timedelta` from the `datetime` module.
#
# 2. **Get the Current Date and Time**
#    - Print today’s date.
#    - Print the current date and time.
#
# 3. **Format Dates**
#    - Print today’s date in the following formats:
#      - YYYY-MM-DD
#      - Month name, day, year (e.g. November 04, 2025)
#      - Day of the week (e.g. Tuesday)
#
# 4. **Add or Subtract Days**
#    - Calculate what the date will be 14 days from today and print it.
#    - Calculate what the date was 30 days ago and print it.
#
# 5. **Age Calculator**
#    - Write a function that accepts a person’s birthdate (as a string in `YYYY-MM-DD` format) and returns their age in years.
#
# 6. **Days Until an Event**
#    - Choose a future date (e.g. last day of class, a holiday, etc.).
#    - Write a function that tells how many days remain until that event.
#
# 7. **Weekly Practice**
#    - Write a function that, given any date, returns the week number in the year.
#
# ---

# %%
from datetime import date, timedelta

# there is a python function to convert a string to a date


# bad.  use the function to convert a string to a date

birthday = "2012-07-07"

# slicing operation [from:to + 1]
year = birthday[0:4]

month = birthday[5:7]

day=birthday[-2:]

try:
  birth = date(year=int(year), month=int(month), day=int(day))
except ValueError as e:
  print("error", e)

birth

age = date.today().year - int(year)

age
# Out:
# 13

# %% [markdown]
# # spreadsheet history
#
# Microsoft DOS operation system.  It did not have graphics
#
# Then they had I think it was multiplan
#
# The Microsoft copied Apple and Apple copied Xerox to create graphics
#
# In Boston, Massachusetts Lotus 123 became the first spreadsheet
#
# Then Microsoft Lotus 123.  Lotus 123 bankrupt.  They called it Microsoft Office.  Office included Excel, Powerpoint, Word, and Microsoft Access.
#
# Then Google copied Microsoft
#
# Mac has Pages.  and Numbers.
#
#
# werowe@walkerrowe.com

# %% [markdown]
# # Google Sheets Homework
#
# **Google Sheets Homework Assignment: Working with Dates and Times**
#
# ---
#
# **Objective:**
# Practice adding dates, formatting dates, and using Google Sheets date functions.
#
# ---
#
# **Instructions:**
#
# Using Google Sheets functions:
#
# 1. **Current Date and Time**
#    - Enter a formula that shows today’s date.
#    - Enter a formula that shows the current date and time.
#
# 2. **Create a Date**
#    - Use `DATE(year, month, day)` to create a specific date value.
#
# 3. **Extract Date Parts**
#    - Use formulas to get the year, month, and day from today’s date.
#
# 4. **Date Formatting**
#    - Format a date cell in the following ways:
#      - YYYY-MM-DD
#      - Month name, day, year (e.g. November 04, 2025)
#      - Day of the week
#
# 5. **Date Arithmetic**
#    - Write a formula to get the date 14 days from today.
#    - Write a formula to get the date 30 days ago.
#
# 6. **Days Between Dates**
#    - Calculate the number of days between two dates using a formula.
#
# 7. **Weekday/Weekend**
#    - Use a formula to return the weekday name for a given date.
#    - Write a formula to check if a given date is a weekend.
#
# 8. **Workdays**
#    - Use the `WORKDAY` function to calculate a workday a set number of days from today, excluding weekends.
#
# 9. **Networkdays**
#    - Use the `NETWORKDAYS` function to calculate the number of working days between two dates, excluding weekends.
#
# ---
#
# **Sample Formulas:**
