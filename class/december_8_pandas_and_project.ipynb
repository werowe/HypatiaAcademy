# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/december_8_pandas_and_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ** Project First Steps **
#
# 1.    Don't use the Python from the previous document.  It's too complicated
#
# 2.  Here we already have code to reads the csv file into a Pandas dataframe
#
# 3.   what you need to do is fix the constructor in the Price class below.  That means the def __init__() piece.  You can look at this example
#
# 4.  save   exchange_rate = data['rates'][target_currency] in a variable so that you can multiple df['Value'] * that number.  All we did below was print it.  So make a variable to save it.  [a global variable.  that means it has scope in the whole program.  that means you can use it anywhere, like inside a function]
#
# 5.  THen below we have already written the code to look through the dataframe.

# %% [markdown]
# ** Project Next Steps**
#
# Goal of the project is to practice some of the main things we have learned this semester. (Pandas is new.)
#
# 1. read a csv file.  we will use Pandas.  Because it is the easiest way to read a csv vile.
#
# 2. The csv file has some text, date and numbers.  It's price information.  Consumer price indicator.  AUT is Austria.
#
# 3.  We write some functions to (a) convert the number in euros to USD dollars and (b) convert the date YYYY-MM to a date object.  [Goal is to practice converting test to date].
#
# 3a.  we need to use an API to convert euros to dollars.  [Goal is practice APIs.]
#
# 4.  Pandas dataframe you will need to add attributes
#
# 5.
#
# 6.  convert each object in the Pandas dataframe to a class called Price.
#
# 7.  this class will have date, price in euros, prices in dollars, country, ...
#
# 8.  the class also needs two functions:  (a) convert euros to dollars and (b) convert YYYY-MM to a date object

# %%
import pandas as pd

# URL of the CSV file
data_url = "https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/class/DP_LIVE_05122023161331688.csv"

# Read the data into a pandas DataFrame
df = pd.read_csv(data_url)

# Example lambda function that simply prints each row
# this is lambda function.  in the program you will write you will make a def function that is a member function of the class

#lambda_function = lambda row: print(row)

# Applying the lambda function to each row of the DataFrame
#df.apply(lambda_function, axis=1)

# %%
df
# Out:
#        LOCATION INDICATOR       SUBJECT MEASURE FREQUENCY     TIME     Value  \
# 0           AUT       CPI          FOOD  AGRWTH         M  2022-10  14.37008
# 1           AUT       CPI          FOOD  AGRWTH         M  2022-11  15.21099
# 2           AUT       CPI          FOOD  AGRWTH         M  2022-12  16.09756
# 3           AUT       CPI          FOOD  AGRWTH         M  2023-01  16.99219
# 4           AUT       CPI          FOOD  AGRWTH         M  2023-02  16.15970
# ...         ...       ...           ...     ...       ...      ...       ...
# 1683  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-06   6.20000
# 1684  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-07   6.20000
# 1685  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-08   5.90000
# 1686  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-09   5.10000
# 1687  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-10   4.80000
#
#       Flag Codes
# 0            NaN
# ...

# %%
# need to add to this:

# here is how to add columns to a dataframe.  Just make up a new name


df['priceInDollars']=0
df['dateObject']=0


# then later we will calculate the price in dollars and convert the date in text to a date object
# now we just made them empty as a place holder

# %%
df
# Out:
#        LOCATION INDICATOR       SUBJECT MEASURE FREQUENCY     TIME     Value  \
# 0           AUT       CPI          FOOD  AGRWTH         M  2022-10  14.37008
# 1           AUT       CPI          FOOD  AGRWTH         M  2022-11  15.21099
# 2           AUT       CPI          FOOD  AGRWTH         M  2022-12  16.09756
# 3           AUT       CPI          FOOD  AGRWTH         M  2023-01  16.99219
# 4           AUT       CPI          FOOD  AGRWTH         M  2023-02  16.15970
# ...         ...       ...           ...     ...       ...      ...       ...
# 1683  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-06   6.20000
# 1684  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-07   6.20000
# 1685  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-08   5.90000
# 1686  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-09   5.10000
# 1687  EU27_2020       CPI  TOT_FOODENRG  AGRWTH         M  2023-10   4.80000
#
#       Flag Codes  priceInDollars  dateObject
# ...

# %%
# to convert euros to dollars multiple x 1.07

# so 1 euros is 1.07 dollars
# Out:
# 1.0869565217391304

# %%
# use this to convert euros to USD


import requests

base_currency = 'EUR'
target_currency = 'USD'
# Make a request to the Open Exchange Rates API
url = f'https://open.er-api.com/v6/latest/{base_currency}'
response = requests.get(url)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    data = response.json()
    exchange_rate = data['rates'][target_currency]
    print(f'1 {base_currency} = {exchange_rate} {target_currency}')
else:
    print(f'Error: Unable to fetch exchange rates. Status code: {response.status_code}')
# Out:
# 1 EUR = 1.078727 USD

# %%
# make a class called Price


# finish this part

from datetime import date

class Price:

  #priceInDollars=0.    # < df['value'] * theNumberfromtheAPI (dollars per euro)
  #priceInEuros=0
  #date = date()

  #county="AUT"


  # define the constructor

  # FIX THE CONSTRUCTOR


  def __init__(self, parameteers):
        1==1


  #def setPriceinDollars(self,priceinEuros):
        # do the calculation

  #def convertYYYY-MM-to-Dateobject():

# %%
# we need a way to loop through every row in the dataframe.  because we want to convert every row
# to a class. so we can use the iterrows() method


for _, row in df.iterrows():

    # so it is easy to convert a dictionary to a call

    priceDict=row.to_dict()
    print(row.to_dict())

    # look at diana's example
    #telsa = Cars("blue", "")

    # here create a price object

    priceInEuros=priceDict['Value']
    print(priceInEuros)

    # we need to get yearMonth

    # we need to get country

    country = df['LOCATION']
    dateText = df['TIME']



    # HERE WE CREATE THE PRICE OBJECT


    #price=Price(country,dateText,priceInEuros)
# Out:
# {'LOCATION': 'AUT', 'INDICATOR': 'CPI', 'SUBJECT': 'FOOD', 'MEASURE': 'AGRWTH', 'FREQUENCY': 'M', 'TIME': '2022-10', 'Value': 14.37008, 'Flag Codes': nan, 'priceInDollars': 0, 'dateObject': 0}
# 14.37008
# {'LOCATION': 'AUT', 'INDICATOR': 'CPI', 'SUBJECT': 'FOOD', 'MEASURE': 'AGRWTH', 'FREQUENCY': 'M', 'TIME': '2022-11', 'Value': 15.21099, 'Flag Codes': nan, 'priceInDollars': 0, 'dateObject': 0}
# 15.21099
# {'LOCATION': 'AUT', 'INDICATOR': 'CPI', 'SUBJECT': 'FOOD', 'MEASURE': 'AGRWTH', 'FREQUENCY': 'M', 'TIME': '2022-12', 'Value': 16.09756, 'Flag Codes': nan, 'priceInDollars': 0, 'dateObject': 0}
# 16.09756
# {'LOCATION': 'AUT', 'INDICATOR': 'CPI', 'SUBJECT': 'FOOD', 'MEASURE': 'AGRWTH', 'FREQUENCY': 'M', 'TIME': '2023-01', 'Value': 16.99219, 'Flag Codes': nan, 'priceInDollars': 0, 'dateObject': 0}
# 16.99219
# ...
