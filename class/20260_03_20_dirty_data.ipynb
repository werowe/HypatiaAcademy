# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/20260_03_20_dirty_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/werowe/HypatiaAcademy/refs/heads/master/ml/dirty_cafe_sales.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.set_index("Transaction ID", inplace=True)

# %%
df
# Out:
#                     Item Quantity Price Per Unit Total Spent  Payment Method  \
# Transaction ID
# TXN_1961373       Coffee        2            2.0         4.0     Credit Card
# TXN_4977031         Cake        4            3.0        12.0            Cash
# TXN_4271903       Cookie        4            1.0       ERROR     Credit Card
# TXN_7034554        Salad        2            5.0        10.0         UNKNOWN
# TXN_3160411       Coffee        2            2.0         4.0  Digital Wallet
# ...                  ...      ...            ...         ...             ...
# TXN_7672686       Coffee        2            2.0         4.0             NaN
# TXN_9659401          NaN        3            NaN         3.0  Digital Wallet
# TXN_5255387       Coffee        4            2.0         8.0  Digital Wallet
# TXN_7695629       Cookie        3            NaN         3.0  Digital Wallet
# TXN_6170729     Sandwich        3            4.0        12.0            Cash
#
# ...

# %%
# cast a  value to a number

#df['Total Spent'], errors='coerce')

j = "3"

3 * j

# concatenate
# Out:
# '333'

# %%
3 * int(j)
# Out:
# 9

# %%
float(j)
# Out:
# 3.0

# %%
import numpy as np


# take 3.5 and conver it to a 8 integer


1111 1111

11<----memory 1111 1111



np.array(2570).astype(np.int8)
# Out:
# array(10, dtype=int8)

# %%
pd.to_numeric(df['Total Spent'], errors='coerce').isna()
# Out:
# Transaction ID
# TXN_1961373    False
# TXN_4977031    False
# TXN_4271903     True
# TXN_7034554    False
# TXN_3160411    False
#                ...
# TXN_7672686    False
# TXN_9659401    False
# TXN_5255387    False
# TXN_7695629    False
# TXN_6170729    False
# Name: Total Spent, Length: 10000, dtype: bool

# %%
df.iloc[0]['Total Spent']
# Out:
# '4.0'

# %%
# turns into np.NaN if it cannot be converred to number

bad = pd.to_numeric(df['Total Spent'], errors='coerce').isna()


#df.loc[logical expression]

l = ['TXN_4271903']
df.loc[l]

df.loc[bad]
# Out:
#                     Item Quantity Price Per Unit Total Spent  Payment Method  \
# Transaction ID
# TXN_4271903       Cookie        4            1.0       ERROR     Credit Card
# TXN_7958992     Smoothie        3            4.0         NaN         UNKNOWN
# TXN_8927252      UNKNOWN        2            1.0       ERROR     Credit Card
# TXN_6650263          Tea        2            1.5     UNKNOWN             NaN
# TXN_4987129     Sandwich        3            NaN         NaN             NaN
# ...                  ...      ...            ...         ...             ...
# TXN_3809533        Juice        2            NaN       ERROR  Digital Wallet
# TXN_1191659       Coffee        4            2.0       ERROR     Credit Card
# TXN_5548914        Juice        2            3.0       ERROR  Digital Wallet
# TXN_9594133         Cake        5            3.0         NaN           ERROR
# TXN_4766549     Smoothie        2            4.0         NaN            Cash
#
# ...

# %%
# ñ tilde means not

df.loc[~bad]
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# 5       TXN_2602893  Smoothie        5            4.0        20.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
bad = pd.to_numeric(df['Quantity'], errors='coerce').isna()

df.loc[bad]
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 20      TXN_3522028  Smoothie    ERROR            4.0        20.0
# 55      TXN_5522862    Cookie    ERROR            1.0         2.0
# 57      TXN_2080895      Cake  UNKNOWN            3.0         3.0
# 66      TXN_8501819     Juice      NaN            3.0         6.0
# 117     TXN_2148617     Juice    ERROR            3.0         9.0
# ...             ...       ...      ...            ...         ...
# 9932    TXN_8502079       Tea  UNKNOWN            1.5         3.0
# 9935    TXN_9778251       Tea    ERROR            1.5         6.0
# 9944    TXN_7495283      Cake  UNKNOWN            3.0        15.0
# 9957    TXN_6487003    Coffee    ERROR            2.0         8.0
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
#
#       Payment Method  Location Transaction Date
# 20              Cash  In-store       2023-04-04
# 55       Credit Card  Takeaway       2023-03-19
# ...

# %%
# find outliers.  that means far away from everyone else


bad = pd.to_numeric(df['Quantity'], errors='coerce').isna()

good=df.loc[~bad]

std=good['Quantity'].astype(int).std()
mean=good['Quantity'].astype(int).std()

# %%
std, mean
# Out:
# (1.4190068732212457, 1.4190068732212457)

# %%
good['Quantity'].describe()
# Out:
# count     9521
# unique       5
# top          5
# freq      2013
# Name: Quantity, dtype: object

# %%
good['Quantity'].astype(int).describe()
# Out:
# count    9521.000000
# mean        3.028463
# std         1.419007
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Quantity, dtype: float64

# %%
# 32 * 1 1 std


good['Quantity'] = pd.to_numeric(good['Quantity'], errors='coerce')


std = good['Quantity'].std()

good.loc[good['Quantity'] > 2 * std]
# Out:
# /tmp/ipykernel_3927/2492571576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good['Quantity'] = pd.to_numeric(good['Quantity'], errors='coerce')
#      Transaction ID      Item  Quantity Price Per Unit Total Spent  \
# 1       TXN_4977031      Cake         4            3.0        12.0
# 2       TXN_4271903    Cookie         4            1.0       ERROR
# 5       TXN_2602893  Smoothie         5            4.0        20.0
# 6       TXN_4433211   UNKNOWN         3            3.0         9.0
# 7       TXN_6699534  Sandwich         4            4.0        16.0
# ...             ...       ...       ...            ...         ...
# 9994    TXN_7851634   UNKNOWN         4            4.0        16.0
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df.groupby("Item").count()
# Out:
#           Transaction ID  Quantity  Price Per Unit  Total Spent  \
# Item
# Cake                1139      1121            1118         1120
# Coffee              1165      1146            1146         1149
# Cookie              1092      1075            1068         1073
# ERROR                292       287             285          285
# Juice               1171      1158            1154         1159
# Salad               1148      1135            1132         1129
# Sandwich            1131      1113            1114         1105
# Smoothie            1096      1086            1072         1078
# Tea                 1089      1076            1069         1064
# UNKNOWN              344       335             337          336
#
#           Payment Method  Location  Transaction Date
# Item
# Cake                 855       767              1122
# Coffee               816       750              1151
# Cookie               829       762              1071
# ...

# %%
 df[df['Item'].isin(['UNKNOWN', 'ERROR'])]
# Out:
#      Transaction ID     Item Quantity Price Per Unit Total Spent  \
# 6       TXN_4433211  UNKNOWN        3            3.0         9.0
# 14      TXN_8915701    ERROR        2            1.5         3.0
# 31      TXN_8927252  UNKNOWN        2            1.0       ERROR
# 33      TXN_7710508  UNKNOWN        5            1.0         5.0
# 36      TXN_6855453  UNKNOWN        4            3.0        12.0
# ...             ...      ...      ...            ...         ...
# 9946    TXN_8807600  UNKNOWN        1            4.0         4.0
# 9951    TXN_4122925    ERROR        4            1.0         4.0
# 9958    TXN_4125474    ERROR        2            5.0        10.0
# 9981    TXN_4583012    ERROR        5            4.0        20.0
# 9994    TXN_7851634  UNKNOWN        4            4.0        16.0
#
#       Payment Method  Location Transaction Date
# 6              ERROR  Takeaway       2023-10-06
# 14               NaN  In-store       2023-03-21
# ...

# %%
df['Total Spent'] = pd.to_numeric(good['Total Spent'], errors='coerce')


q1 = df['Total Spent'].quantile(0.25)
q3 = df['Total Spent'].quantile(0.75)
iqr = q3 - q1
outliers = df[(df['Total Spent'] < q1 - 1.5*iqr) |
              (df['Total Spent'] > q3 + 1.5*iqr)]

outliers
# Out:
#      Transaction ID     Item Quantity Price Per Unit  Total Spent  \
# 10      TXN_2548360    Salad        5            5.0         25.0
# 51      TXN_6342161    Salad        5            5.0         25.0
# 52      TXN_8914892  UNKNOWN        5            5.0         25.0
# 96      TXN_5220895    Salad        5            5.0         25.0
# 100     TXN_9517146      NaN        5            5.0         25.0
# ...             ...      ...      ...            ...          ...
# 9791    TXN_1232346    Salad        5            5.0         25.0
# 9805    TXN_9506076    Salad        5            5.0         25.0
# 9879    TXN_6393305    Salad        5            5.0         25.0
# 9908    TXN_8922585    Salad        5            5.0         25.0
# 9971    TXN_6120851    Salad        5            5.0         25.0
#
#       Payment Method  Location Transaction Date
# 10              Cash  Takeaway       2023-11-07
# 51             ERROR  Takeaway       2023-01-08
# ...

# %%
# Load clean California housing + add realistic missing values (15% like real datasets)
print("Loading housing data...")
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Price'] = data.target  # Add target column

# Create "bad data" with missing values (your homework requirement)
np.random.seed(42)
missing_cols = ['MedInc', 'HouseAge', 'AveRooms', 'Population']
for col in missing_cols:
    missing_mask = np.random.choice(df.index, size=int(len(df)*0.15), replace=False)
    df.loc[missing_mask, col] = np.nan

print("✅ Dataset created with missing values!")
print(f"Shape: {df.shape}")
print("\nMissing values per column:")
missing_count = df.isnull().sum()
print(missing_count[missing_count > 0])
