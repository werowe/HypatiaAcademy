# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/george_half_ass_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Homework
#
# Do some exercises use the functions in pandas against your own data
#
# do count by year

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anandshaw2001/netflix-movies-and-tv-shows")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.34M/1.34M [00:00<00:00, 64.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anandshaw2001/netflix-movies-and-tv-shows/versions/1

# %%
import pandas as pd
import os

file_path = path + '/netflix_titles.csv'

if os.path.exists(file_path):
    df_netflix = pd.read_csv(file_path)
    print("Netflix data loaded successfully. First 5 rows:")
    display(df_netflix.head())

    print("\nDataFrame Info:")
    df_netflix.info()
else:
  print("not found")
# Out:
# Netflix data loaded successfully. First 5 rows:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
#df = df_netflix
df.loc[df['country'].isna()]
# Out:
#      show_id     type                                title  \
# 2         s3  TV Show                            Ganglands
# 3         s4  TV Show                Jailbirds New Orleans
# 5         s6  TV Show                        Midnight Mass
# 6         s7    Movie     My Little Pony: A New Generation
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...      ...      ...                                  ...
# 8718   s8719    Movie               Westside vs. the World
# 8759   s8760    Movie               World's Weirdest Homes
# 8783   s8784  TV Show                                 Yoko
# 8785   s8786  TV Show                                  YOM
# 8803   s8804  TV Show                          Zombie Dumb
#
#                            director  \
# 2                   Julien Leclercq
# 3                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 10                              NaN
# ...

# %% [markdown]
# #Homework
#
#
# ##1
#
# def myFunc(row):
#     # look at all columns
#     # if one is Nan
#     # return true
#
#
# df.map(myFunc)
#
#
# ##2
#
# Use a dictionary to make example of download some other data.
#
#
#
# Homework:  give an example of when you would sum across rows and give an example when you would sort across columns
#
# The "axis" parameter in Pandas refers to the direction along which an operation is performed on data structures like Series and DataFrames. In a Series, which is a one-dimensional array of values, there is only "axis 0" representing the single dimension. On the other hand, a DataFrame, a two-dimensional data structure similar to a table, has both "axis 0" for rows and "axis 1" for columns.
#
# # sum across row or column
#
# Give an example using axis
# axis = 0 rows
#
# df = pd.DataFrame({
#
#       "a" : [1,2,3,4],
#       "b" : [5,6,7,8]
# })
#
#
# # add across rows
#
# df.sum(axis=0)

# %%
df = pd.DataFrame({

      "a" : [1,2,3,4],
      "b" : [5,6,7,8]
})


# add across rows
df
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df.sum(axis=0)
# Out:
# a    10
# b    26
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0     6
# 1     8
# 2    10
# 3    12
# dtype: int64

# %%
football=pd.DataFrame({
    "game1" : [1,2,3,4],
      "game2" : [5,6,7,8]

})

football
# Out:
#    game1  game2
# 0      1      5
# 1      2      6
# 2      3      7
# 3      4      8

# %%
football.sum(axis=0)
# Out:
# game1    10
# game2    26
# dtype: int64

# %%
# sum across columns
football.sum(axis=1)
# Out:
# 0     6
# 1     8
# 2    10
# 3    12
# dtype: int64

# %%
df.iloc[8803]
# Out:
# show_id                                                     s8804
# type                                                      TV Show
# title                                                 Zombie Dumb
# director                                                      NaN
# cast                                                          NaN
# country                                                       NaN
# date_added                                           July 1, 2019
# release_year                                                 2018
# rating                                                      TV-Y7
# duration                                                2 Seasons
# listed_in                  Kids' TV, Korean TV Shows, TV Comedies
# description     While living alone in a spooky town, a young g...
# Name: 8803, dtype: object

# %%
print("Values in 'release_year' column:")
display(df_netflix['release_year'].value_counts().sort_index())
# Out:
# Values in 'release_year' column:
# release_year
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      10
# 2014.0      23
# 2015.0      73
# 2016.0     418
# 2017.0    1164
# 2018.0    1625
# 2019.0    1999
# 2020.0    1878
# 2021.0    1498
# Name: count, dtype: int64
