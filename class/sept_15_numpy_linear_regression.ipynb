# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/class/sept_15_numpy_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


study=np.array([3, 5, 6, 4,7])

results=np.array([70, 90, 97, 80, 100])


# weights
coefficient=7.7

# y-intercept
yintercept=48.9

prediction=coefficient*study+yintercept
prediction
# Out:
# array([ 72. ,  87.4,  95.1,  79.7, 102.8])

# %%
'''

using the quession approach change the coefficient and calculate the least squared error

don't change the y-intercept


algorithm:

quess (meaning use a random number)

or you could start at some number n add 0.1 to it, and try then add 0.1 again


'''

# %%
# how do we calculate the least square error

# here are numpy basics

import numpy as np

simpleA=[1,2,3,4,5]
simpleB=[6,7,8,9,0]



a=np.array(simpleA)
b=np.array(simpleB)

lse=(a[0]-b[0])**2
lse

# uses range to make loop as in:
for i in range(4):
    print((a[i]-b[i])**2)

# but now save these 5 LSE differences in a new numpy array

# try a new coefficent

# calculate prediction=coefficient*study+yintercept

# save the LSE sum

# keep going until you find the minimum LSE


# take a guess at coefficient

# what would be a good first guess
# Out:
# 25
# 25
# 25
# 25

# %% [markdown]
# | study | test | prediction | LSE |
# | ----------- | ----------- | ----------- | ----------- |
# | x | y | p | LSE |
#
# somewhere you save the sum of the LSE
#
# save the sum LSE in a numpy array

# %%
import pandas as pd

hoursResults = pd.DataFrame({'hours': a, 'results': b})
hoursResults


#. what we will do is to add columns to this:  prediction, LSE
# Out:
#    hours  results
# 0      1        6
# 1      2        7
# 2      3        8
# 3      4        9
# 4      5        0
