# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/stats/weibull_ilya_numpy_plotting_homework_31_01_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# I used a data array that contains ages at which the Nobel Peace Prize or the Nobel Prize in economics winners received their awards. I got this data array with chatGPT that I ordered to put a data
# from 2 wiki pages into a single dataset. idk about the accuracy of the data, but I checked some random values and it seems to be right

#creating the array

array = np.array([46, 72, 77, 73, 60, 48, 70, 62, 56, 61, 35, 81, 56, 58, 50, 62, 33, 32, 60, 65, 69, 49, 40, 53, 58, 47, 54, 54, 75, 57, 65, 71, 72, 87, 48, 47, 61, 54, 76, 63, 78, 56, 64, 63, 66, 59, 71, 48, 55, 73, 39, 32, 17, 63, 25, 43, 58, 60, 73, 79, 69, 59, 75, 62, 48, 74, 64, 64, 71, 80, 57, 73, 47, 67, 59, 63, 69, 61, 52, 61, 62, 60, 64, 48, 86, 69, 73, 64, 71, 69, 61, 71, 46, 58, 73, 74, 79, 81, 69, 60, 63, 71, 62, 71, 67, 67, 63, 77, 78, 63, 67, 56, 81, 62, 67, 73, 74, 66, 64, 58, 60, 82, 53, 56, 65, 67, 56, 63, 61, 58, 58, 68, 75, 61, 69, 61, 64, 75, 84, 73, 90, 57, 56, 55, 76, 77, 70, 71, 62, 68, 69, 61, 89, 74, 61, 67, 61, 70, 68, 67, 72, 77, 63, 58, 47, 55, 72, 83, 65, 61, 58, 69, 69, 67, 77, 57, 61, 69], dtype=np.int8)

# sorting the array
array.sort()

# calculating the mean for the array
mean = scipy.stats.tmean(array).round(1)

# calculating the std for the array
std = np.std(array).round(1)

# %% [markdown]
# Here you see the most of the data are large values.  It's not symmetrical about the mean.

# %%
cnt=array.shape[0]


x=np.linspace(1,cnt,cnt)

plt.scatter(x,array)

# %% [markdown]
# # Weibull Distribution
#
# So plot it as a Weibull since that by definition is skewed.

# %%
#Testing if the data is weibull

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, shapiro, weibull_min, anderson
import scipy.stats as st


plt.hist(array, bins=15, color='purple', density=True)

mean = array.mean()
std = array.std()

x = np.linspace(min(array), max(array), 100)

y = norm.pdf(x, mean, std)

plt.plot(x,y)


#check if the wind data follows a Weibull distribution
#fit the data to a Weibull distribution
params = weibull_min.fit(array, floc=0)

#perform the Kolmogorov-Smirnov test
ks_stat, ks_p_value = st.kstest(array, 'weibull_min', args=params)

print(f"KS test statistic: {ks_stat}, p-value: {ks_p_value}")

if ks_p_value > 0.05:
    print("The data follows a Weibull distribution")
else:
    print("The data does not follow a Weibull distribution")
# Out:
# KS test statistic: 0.07253912174546154, p-value: 0.2918760388038386
# The data follows a Weibull distribution

# %% [markdown]
# Show that data is not normally distributed.

# %%
from scipy.stats import norm,shapiro


#CHECK IF IT IS THE NORMAL DiSTRIBUTION
stat, p_value = shapiro(array)
print(f"Shapiro-Wilk test stat: {stat}, p-value: {p_value}")

if p_value > 0.05:
    print("The data is a normal distribution")
else:
    print("The data is not a normal distribution")
# Out:
# Shapiro-Wilk test stat: 0.9631593495165754, p-value: 0.0001230928202515056
# The data is not a normal distribution
