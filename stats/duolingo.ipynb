# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/stats/duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.duolingo.com/2020-01-02/users/612592391?fields=currentCourse
#
# https://www.duolingo.com/users/Walker441937

# %%
import json

def custom_read_json(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Perform custom operations on the data
    for key, value in data.items():
        # Check if the value is a list (assuming arrays are represented as lists in your JSON)
        if isinstance(value, list):
            max_length = max(len(item) for item in value)
            data[key] = [item + [np.nan] * (max_length - len(item)) for item in value]

    # Create DataFrame from the modified data
    df = pd.DataFrame(data)
    return df

def pad_arrays(list_of_arrays):
    # Find the maximum length among all arrays
    max_length = max(len(arr) for arr in list_of_arrays)

    # Pad each array to match the maximum length
    padded_arrays = []
    for arr in list_of_arrays:
        padded_arr = arr + [np.nan] * (max_length - len(arr))
        padded_arrays.append(padded_arr)

    return padded_arrays

# %%
# !wget https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json
# Out:
# --2024-05-07 04:17:48--  https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3549801 (3.4M) [text/plain]
# Saving to: ‘user.json.3’
#
# user.json.3         100%[===================>]   3.38M  --.-KB/s    in 0.05s
#
# 2024-05-07 04:17:48 (66.3 MB/s) - ‘user.json.3’ saved [3549801/3549801]

# %%
import pandas as pd
import numpy as np

cu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/course.json"

# get with wget first
#uu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json"

course = pd.read_json(cu)
#user = custom_read_json("user.json")

# %%
with open("user.json", 'r') as f:
        data = json.load(f)

# %%
df=pd.DataFrame(data['languages'])
df=df[df['language_string'] == "Greek"]
df
# Out:
#    streak language_string  points  learning language  level  current_learning  \
# 0     252           Greek   25391      True       el     23              True
#
#    sentences_translated  to_next_level
# 0                     0            609

# %%
pathSectioned=pd.DataFrame(course.loc[['pathSectioned'],['currentCourse']])
pathSectioned=pathSectioned.T
units=pd.DataFrame(pathSectioned.loc[:,"pathSectioned"][0])

# %%
a=units.loc[:,['index','type', 'completedUnits', 'totalUnits', 'units']]
a.rename(columns={'index': 'idx'}, inplace=True)
a
# Out:
#    idx                   type  completedUnits  totalUnits  \
# 0    0               learning              16          16
# 1    1               learning              30          40
# 2    2               learning               0          39
# 3    3  personalized_practice               0          13
# 4    4          daily_refresh               0           1
#
#                                                units
# 0  [{'unitIndex': 0, 'levels': [{'id': '1827c77f4...
# 1  [{'unitIndex': 16, 'levels': [{'id': '25267f10...
# 2  [{'unitIndex': 56, 'levels': [{'id': '92283c66...
# 3  [{'unitIndex': 95, 'levels': [{'id': '7627219c...
# 4  [{'unitIndex': 108, 'levels': [{'id': '7ab313b...

# %%
df = a
# Explode the DataFrame based on the 'units' column
exploded_df = df.explode('units')

# Reset the index to maintain the original index as a column
exploded_df.reset_index(drop=True, inplace=True)


exploded_df
# Out:
#      idx                   type  completedUnits  totalUnits  \
# 0      0               learning              16          16
# 1      0               learning              16          16
# 2      0               learning              16          16
# 3      0               learning              16          16
# 4      0               learning              16          16
# ..   ...                    ...             ...         ...
# 104    3  personalized_practice               0          13
# 105    3  personalized_practice               0          13
# 106    3  personalized_practice               0          13
# 107    3  personalized_practice               0          13
# 108    4          daily_refresh               0           1
#
#                                                  units
# 0    {'unitIndex': 0, 'levels': [{'id': '1827c77f4e...
# 1    {'unitIndex': 1, 'levels': [{'id': 'd3684875c7...
# 2    {'unitIndex': 2, 'levels': [{'id': '81bb9c2bd8...
# 3    {'unitIndex': 3, 'levels': [{'id': '63438e32fc...
# 4    {'unitIndex': 4, 'levels': [{'id': '13772a61af...
# ..                                                 ...
# 104  {'unitIndex': 104, 'levels': [{'id': '2fe28598...
# 105  {'unitIndex': 105, 'levels': [{'id': '74c9e4ff...
# 106  {'unitIndex': 106, 'levels': [{'id': 'b6f6aa2b...
# 107  {'unitIndex': 107, 'levels': [{'id': '7cae39e2...
# 108  {'unitIndex': 108, 'levels': [{'id': '7ab313bd...
#
# [109 rows x 5 columns]

# %%
exploded_df['units']
# Out:
# 0      {'unitIndex': 0, 'levels': [{'id': '1827c77f4e...
# 1      {'unitIndex': 1, 'levels': [{'id': 'd3684875c7...
# 2      {'unitIndex': 2, 'levels': [{'id': '81bb9c2bd8...
# 3      {'unitIndex': 3, 'levels': [{'id': '63438e32fc...
# 4      {'unitIndex': 4, 'levels': [{'id': '13772a61af...
#                              ...
# 104    {'unitIndex': 104, 'levels': [{'id': '2fe28598...
# 105    {'unitIndex': 105, 'levels': [{'id': '74c9e4ff...
# 106    {'unitIndex': 106, 'levels': [{'id': 'b6f6aa2b...
# 107    {'unitIndex': 107, 'levels': [{'id': '7cae39e2...
# 108    {'unitIndex': 108, 'levels': [{'id': '7ab313bd...
# Name: units, Length: 109, dtype: object

# %%
def unwrap(y):

  id=[]
  totalSessions=[]
  debugName=[]

  for i in y['levels']:
     id.append(i['id'])
     totalSessions.append(i['totalSessions'])
     debugName.append(i['debugName'])

  d = {
      "id": id,
      "totalSessions": totalSessions,
      "debugName" : debugName
  }

  return d

  #for k,v in y.items:
  #   d.append(i['id'])
  #  d.append(i['totalSessions'])
  #  d.append(i['debugName'])


  #return y['levels']


exploded_df['levels']=exploded_df['units'].apply(unwrap)


df = exploded_df.drop('units', axis=1)

df
# Out:
#      idx                   type  completedUnits  totalUnits  \
# 0      0               learning              16          16
# 1      0               learning              16          16
# 2      0               learning              16          16
# 3      0               learning              16          16
# 4      0               learning              16          16
# ..   ...                    ...             ...         ...
# 104    3  personalized_practice               0          13
# 105    3  personalized_practice               0          13
# 106    3  personalized_practice               0          13
# 107    3  personalized_practice               0          13
# 108    4          daily_refresh               0           1
#
#                                                 levels
# 0    {'id': ['1827c77f4eb542854a41b4ef652acd4b', '8...
# 1    {'id': ['d3684875c75f2c79dba71dcf1151be60', '0...
# 2    {'id': ['81bb9c2bd87d1c698bc5af84931f20b5', '4...
# 3    {'id': ['63438e32fc6a08a507f3664effaf30f7', '3...
# 4    {'id': ['13772a61affc3034001978d1c16d4628', 'a...
# ..                                                 ...
# 104  {'id': ['2fe285987537e143fe90df72802f1d4b', '6...
# 105  {'id': ['74c9e4ffe55e37718a71c0fb3d7a4e74', '5...
# 106  {'id': ['b6f6aa2b39f499f45595a90a4ce8681d', 'b...
# 107  {'id': ['7cae39e2e1dce0e9f42d7adfb2d5a46c', '5...
# 108  {'id': ['7ab313bda5a3313945760a79311fecf4', 'f...
#
# [109 rows x 5 columns]

# %%
levels = df['levels'].apply(pd.Series)
df =df.drop('levels', axis=1)
df['debugName']=levels['debugName']
df
# Out:
#      idx                   type  completedUnits  totalUnits  \
# 0      0               learning              16          16
# 1      0               learning              16          16
# 2      0               learning              16          16
# 3      0               learning              16          16
# 4      0               learning              16          16
# ..   ...                    ...             ...         ...
# 104    3  personalized_practice               0          13
# 105    3  personalized_practice               0          13
# 106    3  personalized_practice               0          13
# 107    3  personalized_practice               0          13
# 108    4          daily_refresh               0           1
#
#                                              debugName
# 0    [WarmUp, WarmUp, Unit Practice Level 1, Chest ...
# 1    [Forms of S, Forms of S, Unit Practice Level 2...
# 2    [Which the?, Which the?, Unit Practice Level 3...
# 3    [Stretching, Stretching, Practice Level 1, Che...
# 4    [Go, Go, Chest 5, Practice Level 2, Unit Pract...
# ..                                                 ...
# 104  [Path Extension Practice Level 63, Path Extens...
# 105  [Path Extension Practice Level 70, Path Extens...
# 106  [Path Extension Practice Level 77, Path Extens...
# 107  [Path Extension Practice Level 84, Path Extens...
# 108  [Daily Refresh Practice Level 0, Daily Refresh...
#
# [109 rows x 5 columns]

# %%
lessons=df.explode("debugName")

# %%
lessons.to_csv("lessons.csv")

# %%
# !cat lessons.csv
# Out:
# ,idx,type,completedUnits,totalUnits,debugName
# 0,0,learning,16,16,WarmUp
# 0,0,learning,16,16,WarmUp
# 0,0,learning,16,16,Unit Practice Level 1
# 0,0,learning,16,16,Chest 1
# 0,0,learning,16,16,Unit Review 0
# 1,0,learning,16,16,Forms of S
# 1,0,learning,16,16,Forms of S
# 1,0,learning,16,16,Unit Practice Level 2
# 1,0,learning,16,16,Chest 2
# 1,0,learning,16,16,Unit Review 1
# 2,0,learning,16,16,Which the?
# 2,0,learning,16,16,Which the?
# 2,0,learning,16,16,Unit Practice Level 3
# 2,0,learning,16,16,Chest 3
# 2,0,learning,16,16,Unit Review 2
# 3,0,learning,16,16,Stretching
# 3,0,learning,16,16,Stretching
# 3,0,learning,16,16,Practice Level 1
# 3,0,learning,16,16,Chest 4
# 3,0,learning,16,16,Unit Practice Level 4
# 3,0,learning,16,16,Unit Review 3
# 4,0,learning,16,16,Go
# 4,0,learning,16,16,Go
# 4,0,learning,16,16,Chest 5
# 4,0,learning,16,16,Practice Level 2
# 4,0,learning,16,16,Unit Practice Level 5
# 4,0,learning,16,16,Unit Review 4
# 5,0,learning,16,16,Basics 1
# 5,0,learning,16,16,Chest 6
# 5,0,learning,16,16,Basics 1
# 5,0,learning,16,16,Practice Level 3
# 5,0,learning,16,16,Unit Practice Level 6
# 5,0,learning,16,16,Chest 7
# 5,0,learning,16,16,Unit Review 5
# 6,0,learning,16,16,Basics 2
# 6,0,learning,16,16,Basics 2
# 6,0,learning,16,16,Practice Level 4
# 6,0,learning,16,16,Chest 8
# 6,0,learning,16,16,Unit Practice Level 7
# 6,0,learning,16,16,Unit Review 6
# 7,0,learning,16,16,Phrases
# 7,0,learning,16,16,Phrases
# 7,0,learning,16,16,Chest 9
# 7,0,learning,16,16,Practice Level 5
# 7,0,learning,16,16,Unit Practice Level 8
# 7,0,learning,16,16,Unit Review 7
# 8,0,learning,16,16,Possess.
# 8,0,learning,16,16,Chest 10
# 8,0,learning,16,16,Possess.
# 8,0,learning,16,16,Practice Level 6
# 8,0,learning,16,16,Unit Practice Level 9
# 8,0,learning,16,16,Chest 11
# 8,0,learning,16,16,Unit Review 8
# 9,0,learning,16,16,Food
# 9,0,learning,16,16,Food
# 9,0,learning,16,16,Practice Level 7
# 9,0,learning,16,16,Chest 12
# 9,0,learning,16,16,Unit Practice Level 10
# 9,0,learning,16,16,Unit Review 9
# 10,0,learning,16,16,Family
# 10,0,learning,16,16,Family
# 10,0,learning,16,16,Chest 13
# 10,0,learning,16,16,Practice Level 8
# 10,0,learning,16,16,Unit Practice Level 11
# 10,0,learning,16,16,Unit Review 10
# 11,0,learning,16,16,Animals 1
# 11,0,learning,16,16,Chest 14
# 11,0,learning,16,16,Animals 1
# 11,0,learning,16,16,Practice Level 9
# 11,0,learning,16,16,Unit Practice Level 12
# 11,0,learning,16,16,Chest 15
# 11,0,learning,16,16,Unit Review 11
# 12,0,learning,16,16,Plurals
# 12,0,learning,16,16,Plurals
# 12,0,learning,16,16,Practice Level 10
# 12,0,learning,16,16,Chest 16
# 12,0,learning,16,16,Unit Practice Level 13
# 12,0,learning,16,16,Unit Review 12
# 13,0,learning,16,16,Clothing
# 13,0,learning,16,16,Clothing
# 13,0,learning,16,16,Chest 17
# 13,0,learning,16,16,Practice Level 11
# 13,0,learning,16,16,Unit Practice Level 14
# 13,0,learning,16,16,Unit Review 13
# 14,0,learning,16,16,Questions
# 14,0,learning,16,16,Chest 18
# 14,0,learning,16,16,Questions
# 14,0,learning,16,16,Practice Level 12
# 14,0,learning,16,16,Unit Practice Level 15
# 14,0,learning,16,16,Chest 19
# 14,0,learning,16,16,Unit Review 14
# 15,0,learning,16,16,Be & Have
# 15,0,learning,16,16,Be & Have
# 15,0,learning,16,16,Practice Level 13
# 15,0,learning,16,16,Chest 20
# 15,0,learning,16,16,Unit Practice Level 16
# 15,0,learning,16,16,Unit Review 15
# 16,1,learning,30,40,Accusative
# 16,1,learning,30,40,Accusative
# 16,1,learning,30,40,Chest 21
# 16,1,learning,30,40,Practice Level 14
# 16,1,learning,30,40,Unit Practice Level 17
# 16,1,learning,30,40,Unit Review 16
# 17,1,learning,30,40,Present 1
# 17,1,learning,30,40,Chest 22
# 17,1,learning,30,40,Present 1
# 17,1,learning,30,40,Practice Level 15
# 17,1,learning,30,40,Unit Practice Level 18
# 17,1,learning,30,40,Chest 23
# 17,1,learning,30,40,Unit Review 17
# 18,1,learning,30,40,Colors
# 18,1,learning,30,40,Colors
# 18,1,learning,30,40,Practice Level 16
# 18,1,learning,30,40,Chest 24
# 18,1,learning,30,40,Unit Practice Level 19
# 18,1,learning,30,40,Unit Review 18
# 19,1,learning,30,40,Determin.
# 19,1,learning,30,40,Determin.
# 19,1,learning,30,40,Chest 25
# 19,1,learning,30,40,Practice Level 17
# 19,1,learning,30,40,Unit Practice Level 20
# 19,1,learning,30,40,Unit Review 19
# 20,1,learning,30,40,Pers. pron
# 20,1,learning,30,40,Chest 26
# 20,1,learning,30,40,Pers. pron
# 20,1,learning,30,40,Practice Level 18
# 20,1,learning,30,40,Unit Practice Level 21
# 20,1,learning,30,40,Chest 27
# 20,1,learning,30,40,Unit Review 20
# 21,1,learning,30,40,Genitive
# 21,1,learning,30,40,Genitive
# 21,1,learning,30,40,Practice Level 19
# 21,1,learning,30,40,Chest 28
# 21,1,learning,30,40,Unit Practice Level 22
# 21,1,learning,30,40,Unit Review 21
# 22,1,learning,30,40,Weather 1
# 22,1,learning,30,40,Weather 1
# 22,1,learning,30,40,Chest 29
# 22,1,learning,30,40,Practice Level 20
# 22,1,learning,30,40,Unit Practice Level 23
# 22,1,learning,30,40,Unit Review 22
# 23,1,learning,30,40,Prepos.
# 23,1,learning,30,40,Chest 30
# 23,1,learning,30,40,Prepos.
# 23,1,learning,30,40,Practice Level 21
# 23,1,learning,30,40,Unit Practice Level 24
# 23,1,learning,30,40,Chest 31
# 23,1,learning,30,40,Unit Review 23
# 24,1,learning,30,40,Numbers
# 24,1,learning,30,40,Numbers
# 24,1,learning,30,40,Practice Level 22
# 24,1,learning,30,40,Chest 32
# 24,1,learning,30,40,Unit Practice Level 25
# 24,1,learning,30,40,Unit Review 24
# 25,1,learning,30,40,Appearance
# 25,1,learning,30,40,Appearance
# 25,1,learning,30,40,Chest 33
# 25,1,learning,30,40,Practice Level 23
# 25,1,learning,30,40,Unit Practice Level 26
# 25,1,learning,30,40,Unit Review 25
# 26,1,learning,30,40,Adject.
# 26,1,learning,30,40,Chest 34
# 26,1,learning,30,40,Adject.
# 26,1,learning,30,40,Practice Level 24
# 26,1,learning,30,40,Unit Practice Level 27
# 26,1,learning,30,40,Chest 35
# 26,1,learning,30,40,Unit Review 26
# 27,1,learning,30,40,Dates
# 27,1,learning,30,40,Dates
# 27,1,learning,30,40,Practice Level 25
# 27,1,learning,30,40,Chest 36
# 27,1,learning,30,40,Unit Practice Level 28
# 27,1,learning,30,40,Unit Review 27
# 28,1,learning,30,40,Occupation
# 28,1,learning,30,40,Occupation
# 28,1,learning,30,40,Chest 37
# 28,1,learning,30,40,Practice Level 26
# 28,1,learning,30,40,Unit Practice Level 29
# 28,1,learning,30,40,Unit Review 28
# 29,1,learning,30,40,Conjun.
# 29,1,learning,30,40,Chest 38
# 29,1,learning,30,40,Conjun.
# 29,1,learning,30,40,Practice Level 27
# 29,1,learning,30,40,Unit Practice Level 30
# 29,1,learning,30,40,Chest 39
# 29,1,learning,30,40,Unit Review 29
# 30,1,learning,30,40,Defin. Pr.
# 30,1,learning,30,40,Defin. Pr.
# 30,1,learning,30,40,Practice Level 28
# 30,1,learning,30,40,Chest 40
# 30,1,learning,30,40,Unit Practice Level 31
# 30,1,learning,30,40,Unit Review 30
# 31,1,learning,30,40,Objects
# 31,1,learning,30,40,Objects
# 31,1,learning,30,40,Chest 41
# 31,1,learning,30,40,Practice Level 29
# 31,1,learning,30,40,Unit Practice Level 32
# 31,1,learning,30,40,Unit Review 31
# 32,1,learning,30,40,Character
# 32,1,learning,30,40,Chest 42
# 32,1,learning,30,40,Character
# 32,1,learning,30,40,Practice Level 30
# 32,1,learning,30,40,Unit Practice Level 33
# 32,1,learning,30,40,Chest 43
# 32,1,learning,30,40,Unit Review 32
# 33,1,learning,30,40,Household
# 33,1,learning,30,40,Household
# 33,1,learning,30,40,Practice Level 31
# 33,1,learning,30,40,Chest 44
# 33,1,learning,30,40,Unit Practice Level 34
# 33,1,learning,30,40,Unit Review 33
# 34,1,learning,30,40,Present 2
# 34,1,learning,30,40,Present 2
# 34,1,learning,30,40,Chest 45
# 34,1,learning,30,40,Practice Level 32
# 34,1,learning,30,40,Unit Practice Level 35
# 34,1,learning,30,40,Unit Review 34
# 35,1,learning,30,40,Sizes
# 35,1,learning,30,40,Chest 46
# 35,1,learning,30,40,Sizes
# 35,1,learning,30,40,Practice Level 33
# 35,1,learning,30,40,Unit Practice Level 36
# 35,1,learning,30,40,Chest 47
# 35,1,learning,30,40,Unit Review 35
# 36,1,learning,30,40,Subj. Pres
# 36,1,learning,30,40,Subj. Pres
# 36,1,learning,30,40,Practice Level 34
# 36,1,learning,30,40,Chest 48
# 36,1,learning,30,40,Unit Practice Level 37
# 36,1,learning,30,40,Unit Review 36
# 37,1,learning,30,40,Indef. Pr.
# 37,1,learning,30,40,Indef. Pr.
# 37,1,learning,30,40,Chest 49
# 37,1,learning,30,40,Practice Level 35
# 37,1,learning,30,40,Unit Practice Level 38
# 37,1,learning,30,40,Unit Review 37
# 38,1,learning,30,40,Present 3
# 38,1,learning,30,40,Chest 50
# 38,1,learning,30,40,Present 3
# 38,1,learning,30,40,Practice Level 36
# 38,1,learning,30,40,Unit Practice Level 39
# 38,1,learning,30,40,Chest 51
# 38,1,learning,30,40,Unit Review 38
# 39,1,learning,30,40,Adverbs
# 39,1,learning,30,40,Adverbs
# 39,1,learning,30,40,Practice Level 37
# 39,1,learning,30,40,Chest 52
# 39,1,learning,30,40,Unit Practice Level 40
# 39,1,learning,30,40,Unit Review 39
# 40,1,learning,30,40,S.Past 1
# 40,1,learning,30,40,S.Past 1
# 40,1,learning,30,40,Chest 53
# 40,1,learning,30,40,Practice Level 38
# 40,1,learning,30,40,Unit Practice Level 41
# 40,1,learning,30,40,Unit Review 40
# 41,1,learning,30,40,Imper. 1
# 41,1,learning,30,40,Chest 54
# 41,1,learning,30,40,Imper. 1
# 41,1,learning,30,40,Practice Level 39
# 41,1,learning,30,40,Unit Practice Level 42
# 41,1,learning,30,40,Chest 55
# 41,1,learning,30,40,Unit Review 41
# 42,1,learning,30,40,Subj. Aor.
# 42,1,learning,30,40,Subj. Aor.
# 42,1,learning,30,40,Practice Level 40
# 42,1,learning,30,40,Chest 56
# 42,1,learning,30,40,Unit Practice Level 43
# 42,1,learning,30,40,Unit Review 42
# 43,1,learning,30,40,Places
# 43,1,learning,30,40,Places
# 43,1,learning,30,40,Chest 57
# 43,1,learning,30,40,Practice Level 41
# 43,1,learning,30,40,Unit Practice Level 44
# 43,1,learning,30,40,Unit Review 43
# 44,1,learning,30,40,Directions
# 44,1,learning,30,40,Chest 58
# 44,1,learning,30,40,Directions
# 44,1,learning,30,40,Practice Level 42
# 44,1,learning,30,40,Unit Practice Level 45
# 44,1,learning,30,40,Chest 59
# 44,1,learning,30,40,Unit Review 44
# 45,1,learning,30,40,Act. Part.
# 45,1,learning,30,40,Act. Part.
# 45,1,learning,30,40,Practice Level 43
# 45,1,learning,30,40,Chest 60
# 45,1,learning,30,40,Unit Practice Level 46
# 45,1,learning,30,40,Unit Review 45
# 46,1,learning,30,40,People
# 46,1,learning,30,40,People
# 46,1,learning,30,40,Chest 61
# 46,1,learning,30,40,Practice Level 44
# 46,1,learning,30,40,Unit Practice Level 47
# 46,1,learning,30,40,Unit Review 46
# 47,1,learning,30,40,Passive Pr
# 47,1,learning,30,40,Chest 62
# 47,1,learning,30,40,Passive Pr
# 47,1,learning,30,40,Practice Level 45
# 47,1,learning,30,40,Unit Practice Level 48
# 47,1,learning,30,40,Chest 63
# 47,1,learning,30,40,Unit Review 47
# 48,1,learning,30,40,Greece
# 48,1,learning,30,40,Greece
# 48,1,learning,30,40,Practice Level 46
# 48,1,learning,30,40,Chest 64
# 48,1,learning,30,40,Unit Practice Level 49
# 48,1,learning,30,40,Unit Review 48
# 49,1,learning,30,40,Fut. Cont.
# 49,1,learning,30,40,Fut. Cont.
# 49,1,learning,30,40,Chest 65
# 49,1,learning,30,40,Practice Level 47
# 49,1,learning,30,40,Unit Practice Level 50
# 49,1,learning,30,40,Unit Review 49
# 50,1,learning,30,40,Countries
# 50,1,learning,30,40,Chest 66
# 50,1,learning,30,40,Countries
# 50,1,learning,30,40,Practice Level 48
# 50,1,learning,30,40,Unit Practice Level 51
# 50,1,learning,30,40,Chest 67
# 50,1,learning,30,40,Unit Review 50
# 51,1,learning,30,40,Past S. 2
# 51,1,learning,30,40,Past S. 2
# 51,1,learning,30,40,Practice Level 49
# 51,1,learning,30,40,Chest 68
# 51,1,learning,30,40,Unit Practice Level 52
# 51,1,learning,30,40,Unit Review 51
# 52,1,learning,30,40,Adverbs 2
# 52,1,learning,30,40,Adverbs 2
# 52,1,learning,30,40,Chest 69
# 52,1,learning,30,40,Practice Level 50
# 52,1,learning,30,40,Unit Practice Level 53
# 52,1,learning,30,40,Unit Review 52
# 53,1,learning,30,40,Adject. 2
# 53,1,learning,30,40,Chest 70
# 53,1,learning,30,40,Adject. 2
# 53,1,learning,30,40,Practice Level 51
# 53,1,learning,30,40,Unit Practice Level 54
# 53,1,learning,30,40,Chest 71
# 53,1,learning,30,40,Unit Review 53
# 54,1,learning,30,40,Pron. Rel.
# 54,1,learning,30,40,Pron. Rel.
# 54,1,learning,30,40,Practice Level 52
# 54,1,learning,30,40,Chest 72
# 54,1,learning,30,40,Unit Practice Level 55
# 54,1,learning,30,40,Unit Review 54
# 55,1,learning,30,40,Transport
# 55,1,learning,30,40,Transport
# 55,1,learning,30,40,Chest 73
# 55,1,learning,30,40,Practice Level 53
# 55,1,learning,30,40,Unit Practice Level 56
# 55,1,learning,30,40,Unit Review 55
# 56,2,learning,0,39,Adj. Comp.
# 56,2,learning,0,39,Chest 74
# 56,2,learning,0,39,Adj. Comp.
# 56,2,learning,0,39,Practice Level 54
# 56,2,learning,0,39,Unit Practice Level 57
# 56,2,learning,0,39,Chest 75
# 56,2,learning,0,39,Unit Review 56
# 57,2,learning,0,39,Feelings
# 57,2,learning,0,39,Feelings
# 57,2,learning,0,39,Practice Level 55
# 57,2,learning,0,39,Chest 76
# 57,2,learning,0,39,Unit Practice Level 58
# 57,2,learning,0,39,Unit Review 57
# 58,2,learning,0,39,Past Pass.
# 58,2,learning,0,39,Past Pass.
# 58,2,learning,0,39,Chest 77
# 58,2,learning,0,39,Practice Level 56
# 58,2,learning,0,39,Unit Practice Level 59
# 58,2,learning,0,39,Unit Review 58
# 59,2,learning,0,39,Part.Pass
# 59,2,learning,0,39,Chest 78
# 59,2,learning,0,39,Part.Pass
# 59,2,learning,0,39,Practice Level 57
# 59,2,learning,0,39,Unit Practice Level 60
# 59,2,learning,0,39,Chest 79
# 59,2,learning,0,39,Unit Review 59
# 60,2,learning,0,39,Adv. Comp.
# 60,2,learning,0,39,Adv. Comp.
# 60,2,learning,0,39,Practice Level 58
# 60,2,learning,0,39,Chest 80
# 60,2,learning,0,39,Unit Practice Level 61
# 60,2,learning,0,39,Unit Review 60
# 61,2,learning,0,39,Abstr. Obj
# 61,2,learning,0,39,Abstr. Obj
# 61,2,learning,0,39,Chest 81
# 61,2,learning,0,39,Practice Level 59
# 61,2,learning,0,39,Unit Practice Level 62
# 61,2,learning,0,39,Unit Review 61
# 62,2,learning,0,39,Past.Cont.
# 62,2,learning,0,39,Chest 82
# 62,2,learning,0,39,Past.Cont.
# 62,2,learning,0,39,Practice Level 60
# 62,2,learning,0,39,Unit Practice Level 63
# 62,2,learning,0,39,Chest 83
# 62,2,learning,0,39,Unit Review 62
# 63,2,learning,0,39,Nature
# 63,2,learning,0,39,Nature
# 63,2,learning,0,39,Practice Level 61
# 63,2,learning,0,39,Chest 84
# 63,2,learning,0,39,Unit Practice Level 64
# 63,2,learning,0,39,Unit Review 63
# 64,2,learning,0,39,Education
# 64,2,learning,0,39,Education
# 64,2,learning,0,39,Chest 85
# 64,2,learning,0,39,Practice Level 62
# 64,2,learning,0,39,Unit Practice Level 65
# 64,2,learning,0,39,Unit Review 64
# 65,2,learning,0,39,Imp. Pass.
# 65,2,learning,0,39,Chest 86
# 65,2,learning,0,39,Imp. Pass.
# 65,2,learning,0,39,Practice Level 63
# 65,2,learning,0,39,Unit Practice Level 66
# 65,2,learning,0,39,Chest 87
# 65,2,learning,0,39,Unit Review 65
# 66,2,learning,0,39,Adject. 3
# 66,2,learning,0,39,Adject. 3
# 66,2,learning,0,39,Practice Level 64
# 66,2,learning,0,39,Chest 88
# 66,2,learning,0,39,Unit Practice Level 67
# 66,2,learning,0,39,Unit Review 66
# 67,2,learning,0,39,Athletics
# 67,2,learning,0,39,Athletics
# 67,2,learning,0,39,Chest 89
# 67,2,learning,0,39,Practice Level 65
# 67,2,learning,0,39,Unit Practice Level 68
# 67,2,learning,0,39,Unit Review 67
# 68,2,learning,0,39,Past.C.Pas
# 68,2,learning,0,39,Chest 90
# 68,2,learning,0,39,Past.C.Pas
# 68,2,learning,0,39,Practice Level 66
# 68,2,learning,0,39,Unit Practice Level 69
# 68,2,learning,0,39,Chest 91
# 68,2,learning,0,39,Unit Review 68
# 69,2,learning,0,39,Subj.Pass
# 69,2,learning,0,39,Subj.Pass
# 69,2,learning,0,39,Practice Level 67
# 69,2,learning,0,39,Chest 92
# 69,2,learning,0,39,Unit Practice Level 70
# 69,2,learning,0,39,Unit Review 69
# 70,2,learning,0,39,Arts
# 70,2,learning,0,39,Arts
# 70,2,learning,0,39,Chest 93
# 70,2,learning,0,39,Practice Level 68
# 70,2,learning,0,39,Unit Practice Level 71
# 70,2,learning,0,39,Unit Review 70
# 71,2,learning,0,39,Comm/tion
# 71,2,learning,0,39,Chest 94
# 71,2,learning,0,39,Comm/tion
# 71,2,learning,0,39,Practice Level 69
# 71,2,learning,0,39,Unit Practice Level 72
# 71,2,learning,0,39,Chest 95
# 71,2,learning,0,39,Unit Review 71
# 72,2,learning,0,39,Abs. Ob. 2
# 72,2,learning,0,39,Abs. Ob. 2
# 72,2,learning,0,39,Practice Level 70
# 72,2,learning,0,39,Chest 96
# 72,2,learning,0,39,Unit Practice Level 73
# 72,2,learning,0,39,Unit Review 72
# 73,2,learning,0,39,Future S.
# 73,2,learning,0,39,Future S.
# 73,2,learning,0,39,Chest 97
# 73,2,learning,0,39,Practice Level 71
# 73,2,learning,0,39,Unit Practice Level 74
# 73,2,learning,0,39,Unit Review 73
# 74,2,learning,0,39,Pr.Perfect
# 74,2,learning,0,39,Chest 98
# 74,2,learning,0,39,Pr.Perfect
# 74,2,learning,0,39,Practice Level 72
# 74,2,learning,0,39,Unit Practice Level 75
# 74,2,learning,0,39,Chest 99
# 74,2,learning,0,39,Unit Review 74
# 75,2,learning,0,39,Medical
# 75,2,learning,0,39,Medical
# 75,2,learning,0,39,Practice Level 73
# 75,2,learning,0,39,Chest 100
# 75,2,learning,0,39,Unit Practice Level 76
# 75,2,learning,0,39,Unit Review 75
# 76,2,learning,0,39,Animals 2
# 76,2,learning,0,39,Animals 2
# 76,2,learning,0,39,Chest 101
# 76,2,learning,0,39,Practice Level 74
# 76,2,learning,0,39,Unit Practice Level 77
# 76,2,learning,0,39,Unit Review 76
# 77,2,learning,0,39,Fut.S.Pass
# 77,2,learning,0,39,Chest 102
# 77,2,learning,0,39,Fut.S.Pass
# 77,2,learning,0,39,Practice Level 75
# 77,2,learning,0,39,Unit Practice Level 78
# 77,2,learning,0,39,Chest 103
# 77,2,learning,0,39,Unit Review 77
# 78,2,learning,0,39,Politics
# 78,2,learning,0,39,Politics
# 78,2,learning,0,39,Practice Level 76
# 78,2,learning,0,39,Chest 104
# 78,2,learning,0,39,Unit Practice Level 79
# 78,2,learning,0,39,Unit Review 78
# 79,2,learning,0,39,Materials
# 79,2,learning,0,39,Materials
# 79,2,learning,0,39,Chest 105
# 79,2,learning,0,39,Practice Level 77
# 79,2,learning,0,39,Unit Practice Level 80
# 79,2,learning,0,39,Unit Review 79
# 80,2,learning,0,39,Past Perf.
# 80,2,learning,0,39,Chest 106
# 80,2,learning,0,39,Past Perf.
# 80,2,learning,0,39,Practice Level 78
# 80,2,learning,0,39,Unit Practice Level 81
# 80,2,learning,0,39,Chest 107
# 80,2,learning,0,39,Unit Review 80
# 81,2,learning,0,39,Science
# 81,2,learning,0,39,Science
# 81,2,learning,0,39,Practice Level 79
# 81,2,learning,0,39,Chest 108
# 81,2,learning,0,39,Unit Practice Level 82
# 81,2,learning,0,39,Unit Review 81
# 82,2,learning,0,39,Computers
# 82,2,learning,0,39,Computers
# 82,2,learning,0,39,Chest 109
# 82,2,learning,0,39,Practice Level 80
# 82,2,learning,0,39,Unit Practice Level 83
# 82,2,learning,0,39,Unit Review 82
# 83,2,learning,0,39,Soc. Media
# 83,2,learning,0,39,Chest 110
# 83,2,learning,0,39,Soc. Media
# 83,2,learning,0,39,Practice Level 81
# 83,2,learning,0,39,Unit Practice Level 84
# 83,2,learning,0,39,Chest 111
# 83,2,learning,0,39,Unit Review 83
# 84,2,learning,0,39,Shopping
# 84,2,learning,0,39,Shopping
# 84,2,learning,0,39,Practice Level 82
# 84,2,learning,0,39,Chest 112
# 84,2,learning,0,39,Unit Practice Level 85
# 84,2,learning,0,39,Unit Review 84
# 85,2,learning,0,39,Math
# 85,2,learning,0,39,Math
# 85,2,learning,0,39,Chest 113
# 85,2,learning,0,39,Practice Level 83
# 85,2,learning,0,39,Unit Practice Level 86
# 85,2,learning,0,39,Unit Review 85
# 86,2,learning,0,39,Weather 2
# 86,2,learning,0,39,Chest 114
# 86,2,learning,0,39,Weather 2
# 86,2,learning,0,39,Practice Level 84
# 86,2,learning,0,39,Unit Practice Level 87
# 86,2,learning,0,39,Chest 115
# 86,2,learning,0,39,Unit Review 86
# 87,2,learning,0,39,Future Per
# 87,2,learning,0,39,Future Per
# 87,2,learning,0,39,Practice Level 85
# 87,2,learning,0,39,Chest 116
# 87,2,learning,0,39,Unit Practice Level 88
# 87,2,learning,0,39,Unit Review 87
# 88,2,learning,0,39,Business
# 88,2,learning,0,39,Business
# 88,2,learning,0,39,Chest 117
# 88,2,learning,0,39,Practice Level 86
# 88,2,learning,0,39,Unit Practice Level 89
# 88,2,learning,0,39,Unit Review 88
# 89,2,learning,0,39,History
# 89,2,learning,0,39,Chest 118
# 89,2,learning,0,39,History
# 89,2,learning,0,39,Practice Level 87
# 89,2,learning,0,39,Unit Practice Level 90
# 89,2,learning,0,39,Chest 119
# 89,2,learning,0,39,Unit Review 89
# 90,2,learning,0,39,Spiritual
# 90,2,learning,0,39,Spiritual
# 90,2,learning,0,39,Practice Level 88
# 90,2,learning,0,39,Chest 120
# 90,2,learning,0,39,Unit Practice Level 91
# 90,2,learning,0,39,Unit Review 90
# 91,2,learning,0,39,Condit.
# 91,2,learning,0,39,Condit.
# 91,2,learning,0,39,Chest 121
# 91,2,learning,0,39,Practice Level 89
# 91,2,learning,0,39,Unit Practice Level 92
# 91,2,learning,0,39,Unit Review 91
# 92,2,learning,0,39,Philosophy
# 92,2,learning,0,39,Chest 122
# 92,2,learning,0,39,Philosophy
# 92,2,learning,0,39,Practice Level 90
# 92,2,learning,0,39,Unit Practice Level 93
# 92,2,learning,0,39,Chest 123
# 92,2,learning,0,39,Unit Review 92
# 93,2,learning,0,39,Events
# 93,2,learning,0,39,Events
# 93,2,learning,0,39,Practice Level 91
# 93,2,learning,0,39,Chest 124
# 93,2,learning,0,39,Unit Practice Level 94
# 93,2,learning,0,39,Unit Review 93
# 94,2,learning,0,39,Mythology
# 94,2,learning,0,39,Mythology
# 94,2,learning,0,39,Chest 125
# 94,2,learning,0,39,Practice Level 92
# 94,2,learning,0,39,Unit Practice Level 95
# 94,2,learning,0,39,Unit Review 94
# 95,3,personalized_practice,0,13,Path Extension Practice Level 0
# 95,3,personalized_practice,0,13,Path Extension Practice Level 1
# 95,3,personalized_practice,0,13,Path Extension Practice Level 2
# 95,3,personalized_practice,0,13,Path Extension Practice Level 3
# 95,3,personalized_practice,0,13,Path Extension Practice Level 4
# 95,3,personalized_practice,0,13,Path Extension Practice Level 5
# 95,3,personalized_practice,0,13,Path Extension Practice Level 6
# 95,3,personalized_practice,0,13,Unit Review 95
# 96,3,personalized_practice,0,13,Path Extension Practice Level 7
# 96,3,personalized_practice,0,13,Path Extension Practice Level 8
# 96,3,personalized_practice,0,13,Path Extension Practice Level 9
# 96,3,personalized_practice,0,13,Path Extension Practice Level 10
# 96,3,personalized_practice,0,13,Path Extension Practice Level 11
# 96,3,personalized_practice,0,13,Path Extension Practice Level 12
# 96,3,personalized_practice,0,13,Path Extension Practice Level 13
# 96,3,personalized_practice,0,13,Unit Review 96
# 97,3,personalized_practice,0,13,Path Extension Practice Level 14
# 97,3,personalized_practice,0,13,Path Extension Practice Level 15
# 97,3,personalized_practice,0,13,Path Extension Practice Level 16
# 97,3,personalized_practice,0,13,Path Extension Practice Level 17
# 97,3,personalized_practice,0,13,Path Extension Practice Level 18
# 97,3,personalized_practice,0,13,Path Extension Practice Level 19
# 97,3,personalized_practice,0,13,Path Extension Practice Level 20
# 97,3,personalized_practice,0,13,Unit Review 97
# 98,3,personalized_practice,0,13,Path Extension Practice Level 21
# 98,3,personalized_practice,0,13,Path Extension Practice Level 22
# 98,3,personalized_practice,0,13,Path Extension Practice Level 23
# 98,3,personalized_practice,0,13,Path Extension Practice Level 24
# 98,3,personalized_practice,0,13,Path Extension Practice Level 25
# 98,3,personalized_practice,0,13,Path Extension Practice Level 26
# 98,3,personalized_practice,0,13,Path Extension Practice Level 27
# 98,3,personalized_practice,0,13,Unit Review 98
# 99,3,personalized_practice,0,13,Path Extension Practice Level 28
# 99,3,personalized_practice,0,13,Path Extension Practice Level 29
# 99,3,personalized_practice,0,13,Path Extension Practice Level 30
# 99,3,personalized_practice,0,13,Path Extension Practice Level 31
# 99,3,personalized_practice,0,13,Path Extension Practice Level 32
# 99,3,personalized_practice,0,13,Path Extension Practice Level 33
# 99,3,personalized_practice,0,13,Path Extension Practice Level 34
# 99,3,personalized_practice,0,13,Unit Review 99
# 100,3,personalized_practice,0,13,Path Extension Practice Level 35
# 100,3,personalized_practice,0,13,Path Extension Practice Level 36
# 100,3,personalized_practice,0,13,Path Extension Practice Level 37
# 100,3,personalized_practice,0,13,Path Extension Practice Level 38
# 100,3,personalized_practice,0,13,Path Extension Practice Level 39
# 100,3,personalized_practice,0,13,Path Extension Practice Level 40
# 100,3,personalized_practice,0,13,Path Extension Practice Level 41
# 100,3,personalized_practice,0,13,Unit Review 100
# 101,3,personalized_practice,0,13,Path Extension Practice Level 42
# 101,3,personalized_practice,0,13,Path Extension Practice Level 43
# 101,3,personalized_practice,0,13,Path Extension Practice Level 44
# 101,3,personalized_practice,0,13,Path Extension Practice Level 45
# 101,3,personalized_practice,0,13,Path Extension Practice Level 46
# 101,3,personalized_practice,0,13,Path Extension Practice Level 47
# 101,3,personalized_practice,0,13,Path Extension Practice Level 48
# 101,3,personalized_practice,0,13,Unit Review 101
# 102,3,personalized_practice,0,13,Path Extension Practice Level 49
# 102,3,personalized_practice,0,13,Path Extension Practice Level 50
# 102,3,personalized_practice,0,13,Path Extension Practice Level 51
# 102,3,personalized_practice,0,13,Path Extension Practice Level 52
# 102,3,personalized_practice,0,13,Path Extension Practice Level 53
# 102,3,personalized_practice,0,13,Path Extension Practice Level 54
# 102,3,personalized_practice,0,13,Path Extension Practice Level 55
# 102,3,personalized_practice,0,13,Unit Review 102
# 103,3,personalized_practice,0,13,Path Extension Practice Level 56
# 103,3,personalized_practice,0,13,Path Extension Practice Level 57
# 103,3,personalized_practice,0,13,Path Extension Practice Level 58
# 103,3,personalized_practice,0,13,Path Extension Practice Level 59
# 103,3,personalized_practice,0,13,Path Extension Practice Level 60
# 103,3,personalized_practice,0,13,Path Extension Practice Level 61
# 103,3,personalized_practice,0,13,Path Extension Practice Level 62
# 103,3,personalized_practice,0,13,Unit Review 103
# 104,3,personalized_practice,0,13,Path Extension Practice Level 63
# 104,3,personalized_practice,0,13,Path Extension Practice Level 64
# 104,3,personalized_practice,0,13,Path Extension Practice Level 65
# 104,3,personalized_practice,0,13,Path Extension Practice Level 66
# 104,3,personalized_practice,0,13,Path Extension Practice Level 67
# 104,3,personalized_practice,0,13,Path Extension Practice Level 68
# 104,3,personalized_practice,0,13,Path Extension Practice Level 69
# 104,3,personalized_practice,0,13,Unit Review 104
# 105,3,personalized_practice,0,13,Path Extension Practice Level 70
# 105,3,personalized_practice,0,13,Path Extension Practice Level 71
# 105,3,personalized_practice,0,13,Path Extension Practice Level 72
# 105,3,personalized_practice,0,13,Path Extension Practice Level 73
# 105,3,personalized_practice,0,13,Path Extension Practice Level 74
# 105,3,personalized_practice,0,13,Path Extension Practice Level 75
# 105,3,personalized_practice,0,13,Path Extension Practice Level 76
# 105,3,personalized_practice,0,13,Unit Review 105
# 106,3,personalized_practice,0,13,Path Extension Practice Level 77
# 106,3,personalized_practice,0,13,Path Extension Practice Level 78
# 106,3,personalized_practice,0,13,Path Extension Practice Level 79
# 106,3,personalized_practice,0,13,Path Extension Practice Level 80
# 106,3,personalized_practice,0,13,Path Extension Practice Level 81
# 106,3,personalized_practice,0,13,Path Extension Practice Level 82
# 106,3,personalized_practice,0,13,Path Extension Practice Level 83
# 106,3,personalized_practice,0,13,Unit Review 106
# 107,3,personalized_practice,0,13,Path Extension Practice Level 84
# 107,3,personalized_practice,0,13,Path Extension Practice Level 85
# 107,3,personalized_practice,0,13,Path Extension Practice Level 86
# 107,3,personalized_practice,0,13,Path Extension Practice Level 87
# 107,3,personalized_practice,0,13,Path Extension Practice Level 88
# 107,3,personalized_practice,0,13,Path Extension Practice Level 89
# 107,3,personalized_practice,0,13,Path Extension Practice Level 90
# 107,3,personalized_practice,0,13,Path Extension Practice Level 91
# 107,3,personalized_practice,0,13,Path Extension Practice Level 92
# 107,3,personalized_practice,0,13,Path Extension Practice Level 93
# 107,3,personalized_practice,0,13,Path Extension Practice Level 94
# 107,3,personalized_practice,0,13,Unit Review 107
# 108,4,daily_refresh,0,1,Daily Refresh Practice Level 0
# 108,4,daily_refresh,0,1,Daily Refresh Practice Level 1
# 108,4,daily_refresh,0,1,Daily Refresh Practice Level 2
# 108,4,daily_refresh,0,1,Daily Refresh Practice Level 3
# 108,4,daily_refresh,0,1,Daily Refresh Practice Level 4
# 108,4,daily_refresh,0,1,Daily Refresh Unit Review
