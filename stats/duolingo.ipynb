# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/stats/duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.duolingo.com/2020-01-02/users/612592391?fields=currentCourse
#
# https://www.duolingo.com/users/Walker441937

# %%
import json

def custom_read_json(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Perform custom operations on the data
    for key, value in data.items():
        # Check if the value is a list (assuming arrays are represented as lists in your JSON)
        if isinstance(value, list):
            max_length = max(len(item) for item in value)
            data[key] = [item + [np.nan] * (max_length - len(item)) for item in value]

    # Create DataFrame from the modified data
    df = pd.DataFrame(data)
    return df

def pad_arrays(list_of_arrays):
    # Find the maximum length among all arrays
    max_length = max(len(arr) for arr in list_of_arrays)

    # Pad each array to match the maximum length
    padded_arrays = []
    for arr in list_of_arrays:
        padded_arr = arr + [np.nan] * (max_length - len(arr))
        padded_arrays.append(padded_arr)

    return padded_arrays

# %%
# !wget https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json
# Out:
# --2024-05-05 07:55:41--  https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3549801 (3.4M) [text/plain]
# Saving to: ‘user.json.2’
#
# user.json.2         100%[===================>]   3.38M  --.-KB/s    in 0.05s
#
# 2024-05-05 07:55:41 (67.1 MB/s) - ‘user.json.2’ saved [3549801/3549801]

# %%
import pandas as pd
import numpy as np

cu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/course.json"

# get with wget first
#uu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json"

course = pd.read_json(cu)
#user = custom_read_json("user.json")

# %%
with open("user.json", 'r') as f:
        data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['filter_stream', 'language_data', 'last_streak', 'push_night_owl', 'deactivated', 'email_research', 'auto_facebook_post', 'notify_schools_newsletter', 'push_clubs', 'site_streak', 'notification_sms_disabled', 'email_det_marketing', 'notify_edit_suggested', 'dict_base_url', 'languages', 'push_edit_suggested', 'email_beta_feedback', 'twitter_id', 'transliterate', 'push_follow', 'email_events_digest', 'sound_effects', 'location', 'facebook_id', 'browser_language', 'notify_schools_promotion', 'inventory', 'username', 'bio', 'tts_cdn_url', 'created', 'universal_practice_push_enabled', 'push_activity_reply', 'learning_language_string', 'tracking_properties', 'push_comment', 'notification_whatsapp_enabled', 'privacy_settings', 'streak_extended_today', 'notify_activity_comment', 'email_streak_saver', 'requires_parental_consent', 'trial_account', 'push_passed', 'notify_classroom_join', 'notify_classroom_leave', 'universal_practice_email_enabled', 'notify_assignment', 'push_schools_assignment', 'gplus_id', 'ui_language', 'notify_stream_post', 'fullname', 'notify_pass', 'universal_practice_notify_time', 'notify_announcement', 'push_early_bird', 'upload-self-service', 'has_observer', 'push_resurrect_rewards', 'tts_base_url_http', 'creation_date', 'push_streak_freeze_used', 'push_activity_comment', 'timezone', 'calendar', 'insite_sentence_edited', 'id', 'current_time', 'push_leaderboards', 'push_announcement', 'ads_enabled', 'change-design', 'informant_reference', 'speaker', 'created_dt', 'is_self_observer', 'notif_event_ids', 'notify_activity_reply', 'push_stream_post', 'email', 'week_old_account', 'avatar', 'daily_goal', 'email_promotion', 'notify_schools_announcement', 'cohort', 'timezone_offset', 'microphone', 'num_classrooms', 'snooze_expiration_time', 'notify_follow', 'invite_url', 'ab_options', 'freeze-permissions', 'is_observer', 'notify_weekly_report', 'delete-permissions', 'notify_comment', 'insite_immersion_lingots', 'tts_base_url', 'rupees', 'notify_weekly_progress_report', 'notify_assignment_complete', 'admin', 'email_verified', 'learning_language', 'push_happy_hour', 'num_observees', 'email_word_of_the_day', 'notify_clubs', 'push_promotion', 'notify_schools_product_update', 'notification_wechat_enabled', 'autoplay', 'push_streak_saver', 'email_streak_freeze_used'])

# %%
df=pd.DataFrame(data['languages'])
df=df[df['language_string'] == "Greek"]
df
# Out:
#    streak language_string  points  learning language  level  current_learning  \
# 0     252           Greek   25391      True       el     23              True
#
#    sentences_translated  to_next_level
# 0                     0            609

# %%
pd.DataFrame(data['language_data'])
# Out:
#                                                                      el
# bonus_rows                                                           []
# bonus_skills                                                         []
# calendar              [{'skill_id': 'e225023c822807c29eb99193eee6dc4...
# can_transliterate                                                 False
# direction_status                                               released
# exempt_from_health                                                False
# first_time                                                        False
# fluency_score                                                         0
# immersion_enabled                                                 False
# language                                                             el
# language_strength                                                  0.94
# language_string                                                   Greek
# level                                                                23
# level_left                                                          609
# level_percent                                                        82
# level_points                                                       3500
# level_progress                                                     2891
# level_tests           [{'index': 0, 'attempts': 3, 'completed': Fals...
# linkedin_share_url                             https://www.duolingo.com
# max_cefr_level                                                     None
# max_depth_learned                                                    23
# max_level                                                         False
# max_section_index                                                     2
# max_tree_level                                                       23
# next_lesson           {'lesson_number': 1, 'skill_title': 'Warm Up',...
# next_level                                                           24
# no_dep                                                             True
# notifications         {'chrome_app_ad': True, 'net_promoter': False,...
# notify_practice                                                   False
# notify_time                                                        1320
# num_skills_learned                                                   47
# placement_test                                          {'attempts': 1}
# points                                                            25391
# push_practice                                                      True
# skills                [{'language_string': 'Greek', 'dependencies_na...
# streak                                                              252
# tracking_properties   {'direction': 'el<-en', 'took_placementtest': ...
# useSmartReminderTime                                               True

# %%
pathSectioned=pd.DataFrame(course.loc[['pathSectioned'],['currentCourse']])
pathSectioned=pathSectioned.T
units=pd.DataFrame(pathSectioned.loc[:,"pathSectioned"][0])
units
# Out:
#    index       debugName                   type  completedUnits  totalUnits  \
# 0      0  Path Section 0               learning              16          16
# 1      1  Path Section 1               learning              30          40
# 2      2  Path Section 2               learning               0          39
# 3      3  Path Section 3  personalized_practice               0          13
# 4      4  Path Section 4          daily_refresh               0           1
#
#                                                units  cefr  \
# 0  [{'unitIndex': 0, 'levels': [{'id': '1827c77f4...  None
# 1  [{'unitIndex': 16, 'levels': [{'id': '25267f10...  None
# 2  [{'unitIndex': 56, 'levels': [{'id': '92283c66...  None
# 3  [{'unitIndex': 95, 'levels': [{'id': '7627219c...  None
# 4  [{'unitIndex': 108, 'levels': [{'id': '7ab313b...  None
#
#                                              summary exampleSentence
# 0  {'grammarConceptUrl': 'https://s3.amazonaws.co...            None
# 1  {'grammarConceptUrl': 'https://s3.amazonaws.co...            None
# 2  {'grammarConceptUrl': 'https://s3.amazonaws.co...            None
# 3                                               None            None
# 4                                               None            None

# %%
unitsArr = []
for i in range(len(units['units'])):
   unitsArr.append(pd.DataFrame(units['units'][i]))

# %%
allUnits=pd.concat(unitsArr)
allUnits
# Out:
#     unitIndex                                             levels  \
# 0           0  [{'id': '1827c77f4eb542854a41b4ef652acd4b', 's...
# 1           1  [{'id': 'd3684875c75f2c79dba71dcf1151be60', 's...
# 2           2  [{'id': '81bb9c2bd87d1c698bc5af84931f20b5', 's...
# 3           3  [{'id': '63438e32fc6a08a507f3664effaf30f7', 's...
# 4           4  [{'id': '13772a61affc3034001978d1c16d4628', 's...
# ..        ...                                                ...
# 9         104  [{'id': '2fe285987537e143fe90df72802f1d4b', 's...
# 10        105  [{'id': '74c9e4ffe55e37718a71c0fb3d7a4e74', 's...
# 11        106  [{'id': 'b6f6aa2b39f499f45595a90a4ce8681d', 's...
# 12        107  [{'id': '7cae39e2e1dce0e9f42d7adfb2d5a46c', 's...
# 0         108  [{'id': '7ab313bda5a3313945760a79311fecf4', 's...
#
#                                             guidebook  \
# 0   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 1   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 2   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 3   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 4   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# ..                                                ...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 0                                                None
#
#                                     teachingObjective cefrLevel
# 0                             pair letters and sounds      None
# 1                                   recognise letters      None
# 2                                    use the articles      None
# 3                                form basic sentences      None
# 4                                       read any word      None
# ..                                                ...       ...
# 9   discuss business, form the passive voice, disc...      None
# 10  discuss philosophy, tell others what to do, ta...      None
# 11  talk about computers, talk about the weather, ...      None
# 12  talk about the future, talk about the future, ...      None
# 0                                                None      None
#
# [109 rows x 5 columns]

# %%
levelsArr = []

for i in allUnits['levels']:
    levelsArr.append(pd.DataFrame(i))

allLevels=pd.concat(levelsArr)

allLevels
# Out:
#                                   id   state  finishedSessions  \
# 0   1827c77f4eb542854a41b4ef652acd4b  passed                 5
# 1   8e87381297e4e6635039788b261e992b  passed                 5
# 2   d387f2c2606883b932c6298644ff47af  passed                 2
# 3   e1d7202afe07f4b064e3092a2ec6932a  passed                 1
# 4   8dafdbd72e366a429ba46952a4735638  passed                 0
# ..                               ...     ...               ...
# 1   f42249661d31aebbee295b2211630cd3  locked                 0
# 2   e0b20f1f6a353a337e205f4a863e72c5  locked                 0
# 3   ff9ba5d7ffaea81e0488c54a69e92a83  locked                 0
# 4   c69ffef2fd488f513b2ca0e0488b6c58  locked                 0
# 5   63984c788667f07b6ce3307cc936aff0  locked                 0
#
#                                     pathLevelMetadata  \
# 0   {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d'...
# 1   {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d'...
# 2   {'anchorSkillId': 'ecfa53a69c9989b7ecf145fc0dc...
# 3   {'anchorSkillId': 'ecfa53a69c9989b7ecf145fc0dc...
# 4                                    {'unitIndex': 0}
# ..                                                ...
# 1   {'skillIds': ['39d3a81584d4da4bd3debb6b92cc304...
# 2   {'skillIds': ['39d3a81584d4da4bd3debb6b92cc304...
# 3   {'skillIds': ['14f3c03b03a6ea44f3fcc5f6de8144f...
# 4   {'skillIds': ['14f3c03b03a6ea44f3fcc5f6de8144f...
# 5   {'skillIds': ['cb4841824c2ee9bbe7abe4690ca30c7...
#
#                                   pathLevelClientData  totalSessions  \
# 0   {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d'...              5
# 1   {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d'...              5
# 2   {'skillIds': ['ecfa53a69c9989b7ecf145fc0dcb644...              2
# 3                                                  {}              1
# 4   {'skillIds': ['ecfa53a69c9989b7ecf145fc0dcb644...              1
# ..                                                ...            ...
# 1   {'skillIds': ['39d3a81584d4da4bd3debb6b92cc304...              1
# 2   {'skillIds': ['39d3a81584d4da4bd3debb6b92cc304...              1
# 3   {'skillIds': ['14f3c03b03a6ea44f3fcc5f6de8144f...              1
# 4   {'skillIds': ['14f3c03b03a6ea44f3fcc5f6de8144f...              1
# 5   {'skillIds': ['cb4841824c2ee9bbe7abe4690ca30c7...              1
#
#                          debugName  hasLevelReview         type  \
# 0                           WarmUp            True        skill
# 1                           WarmUp            True        skill
# 2            Unit Practice Level 1           False     practice
# 3                          Chest 1           False        chest
# 4                    Unit Review 0           False  unit_review
# ..                             ...             ...          ...
# 1   Daily Refresh Practice Level 1           False     practice
# 2   Daily Refresh Practice Level 2           False     practice
# 3   Daily Refresh Practice Level 3           False     practice
# 4   Daily Refresh Practice Level 4           False     practice
# 5        Daily Refresh Unit Review           False  unit_review
#
#           subtype  isInProgressSequence  \
# 0         regular                 False
# 1         regular                 False
# 2   unit_practice                 False
# 3           chest                 False
# 4     unit_review                 False
# ..            ...                   ...
# 1        practice                  True
# 2        practice                  True
# 3        practice                  True
# 4        practice                  True
# 5     unit_review                  True
#
#                              dailyRefreshInfo
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ..                                        ...
# 1   {'nodeIndex': 1, 'expiresAt': 1200000000}
# 2   {'nodeIndex': 2, 'expiresAt': 1200000000}
# 3   {'nodeIndex': 3, 'expiresAt': 1200000000}
# 4   {'nodeIndex': 4, 'expiresAt': 1200000000}
# 5   {'nodeIndex': 5, 'expiresAt': 1200000000}
#
# [711 rows x 12 columns]
