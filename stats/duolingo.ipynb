# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/stats/duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.duolingo.com/2020-01-02/users/612592391?fields=currentCourse
#
# https://www.duolingo.com/users/Walker441937

# %%
import pandas as pd
import numpy as np


def unwrap(y):

  totalSessions=[]

  for i in y['levels']:

     totalSessions.append(i['totalSessions'])

  d = {
      "totalSessions": totalSessions,
  }

  return totalSessions

cu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/course.json"

# get with wget first
#uu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json"

course = pd.read_json(cu)


pathSectioned=pd.DataFrame(course.loc[['pathSectioned'],['currentCourse']])
pathSectioned=pathSectioned.T
units=pd.DataFrame(pathSectioned.loc[:,"pathSectioned"][0])
units=units.iloc[0:3]

a=units.loc[:,['index','debugName', 'completedUnits', 'totalUnits', 'units']]
a.rename(columns={'index': 'idx'}, inplace=True)
a

df = a

exploded_df = df.explode('units')

# Reset the index to maintain the original index as a column
exploded_df.reset_index(drop=True, inplace=True)

exploded_df['levels']=exploded_df['units'].apply(unwrap)

df = exploded_df.drop('units', axis=1)

exploded_df.reset_index(drop=True, inplace=True)

df=df.explode("levels")

print("total courses", df['levels'].sum())

#df
# Out:
# total courses 1803

# %%
cnt = 0

e=[]
for i in pathSectioned['pathSectioned']['currentCourse']:
 for j in (i['units']):
    d = {}
    d['section']=i['index']+1
    d['unitIndex']= j['unitIndex']
    d['teachingObjective'] = j['teachingObjective']
    d['levels']= len(j['levels'])
    e.append(d)

    #cnt = 0
    #for k in j['levels']:

df=pd.DataFrame(e)
pd.set_option('display.max_rows', None)

#ef=df.explode("levels")
df
# Out:
#      section  unitIndex                                  teachingObjective  \
# 0          1          0                            pair letters and sounds
# 1          1          1                                  recognise letters
# 2          1          2                                   use the articles
# 3          1          3                               form basic sentences
# 4          1          4                                      read any word
# 5          1          5                                  use basic phrases
# 6          1          6                             talk about the present
# 7          1          7                                       greet people
# 8          1          8                             talk about possessions
# 9          1          9                             discuss food and drink
# 10         1         10                               describe your family
# 11         1         11                              discuss about animals
# 12         1         12                                    form the plural
# 13         1         13                                   discuss clothing
# 14         1         14                                      ask questions
# 15         1         15                                    conjugate verbs
# 16         2         16                                form the accusative
# 17         2         17                             talk about the present
# 18         2         18                                    describe colors
# 19         2         19                       talk about things around you
# 20         2         20                                  talk about people
# 21         2         21                       say who something belongs to
# 22         2         22                             talk about the weather
# 23         2         23                             form complex sentences
# 24         2         24                                        use numbers
# 25         2         25                                describe appearance
# 26         2         26                       describe an object or person
# 27         2         27                                     appoint a date
# 28         2         28                             talk about occupations
# 29         2         29                             form complex sentences
# 30         2         30                              talk about one's self
# 31         2         31                            identify common objects
# 32         2         32                      describe a person's character
# 33         2         33                               talk about furniture
# 34         2         34                             talk about your habits
# 35         2         35                                     describe sizes
# 36         2         36                                 talk about desires
# 37         2         37                         make indefinite statements
# 38         2         38                                    say what you do
# 39         2         39                       talk about how you do things
# 40         2         40                                talk about the past
# 41         2         41                                      give commands
# 42         2         42                              talk about intentions
# 43         2         43                                  talk about places
# 44         2         44                                    give directions
# 45         2         45                               form the participles
# 46         2         46                          talk about meeting people
# 47         2         47                             form the passive voice
# 48         2         48                                  talk about Greece
# 49         2         49                              talk about the future
# 50         2         50                               talk about countries
# 51         2         51                               describe past events
# 52         2         52                           describe actions modally
# 53         2         53                         describe people and things
# 54         2         54                              use relative pronouns
# 55         2         55                                 make transit plans
# 56         3         56                                   make comparisons
# 57         3         57                              express your feelings
# 58         3         58                                talk about the past
# 59         3         59                               use past participles
# 60         3         60                                   make comparisons
# 61         3         61                          discuss abstract concepts
# 62         3         62                            say what used to happen
# 63         3         63                                discuss environment
# 64         3         64                                 talk about classes
# 65         3         65                             tell others what to do
# 66         3         66                                    describe things
# 67         3         67                                     discuss sports
# 68         3         68                          talk about your childhood
# 69         3         69                              talk about intentions
# 70         3         70                              discuss art & culture
# 71         3         71                              discuss communication
# 72         3         72                          discuss abstract concepts
# 73         3         73                              talk about the future
# 74         3         74                         talk about the recent past
# 75         3         75                                   discuss medicine
# 76         3         76                            identify common animals
# 77         3         77                              talk about the future
# 78         3         78                                   discuss politics
# 79         3         79                               talk about materials
# 80         3         80                        talk about the distant past
# 81         3         81                                    discuss science
# 82         3         82                               talk about computers
# 83         3         83                               discuss social media
# 84         3         84                          talk about spending money
# 85         3         85                                discuss mathematics
# 86         3         86                             talk about the weather
# 87         3         87                               say what will happen
# 88         3         88                                   discuss business
# 89         3         89                                    discuss history
# 90         3         90                               discuss spirituality
# 91         3         91                       talk about what might happen
# 92         3         92                                 discuss philosophy
# 93         3         93                           talk about social events
# 94         3         94                            discuss Greek mythology
# 95         4         95  make comparisons, make comparisons, talk about...
# 96         4         96  talk about the future, describe people and thi...
# 97         4         97  describe past events, make transit plans, use ...
# 98         4         98  discuss sports, discuss communication, discuss...
# 99         4         99  talk about Greece, describe actions modally, d...
# 100        4        100  identify common animals, talk about the distan...
# 101        4        101  use relative pronouns, talk about the past, sa...
# 102        4        102  discuss social media, say what will happen, ta...
# 103        4        103  discuss art & culture, talk about the recent p...
# 104        4        104  discuss business, form the passive voice, disc...
# 105        4        105  discuss philosophy, tell others what to do, ta...
# 106        4        106  talk about computers, talk about the weather, ...
# 107        4        107  talk about the future, talk about the future, ...
# 108        5        108                                               None
#
#      levels
# 0         5
# 1         5
# 2         5
# 3         6
# 4         6
# 5         7
# 6         6
# 7         6
# 8         7
# 9         6
# 10        6
# 11        7
# 12        6
# 13        6
# 14        7
# 15        6
# 16        6
# 17        7
# 18        6
# 19        6
# 20        7
# 21        6
# 22        6
# 23        7
# 24        6
# 25        6
# 26        7
# 27        6
# 28        6
# 29        7
# 30        6
# 31        6
# 32        7
# 33        6
# 34        6
# 35        7
# 36        6
# 37        6
# 38        7
# 39        6
# 40        6
# 41        7
# 42        6
# 43        6
# 44        7
# 45        6
# 46        6
# 47        7
# 48        6
# 49        6
# 50        7
# 51        6
# 52        6
# 53        7
# 54        6
# 55        6
# 56        7
# 57        6
# 58        6
# 59        7
# 60        6
# 61        6
# 62        7
# 63        6
# 64        6
# 65        7
# 66        6
# 67        6
# 68        7
# 69        6
# 70        6
# 71        7
# 72        6
# 73        6
# 74        7
# 75        6
# 76        6
# 77        7
# 78        6
# 79        6
# 80        7
# 81        6
# 82        6
# 83        7
# 84        6
# 85        6
# 86        7
# 87        6
# 88        6
# 89        7
# 90        6
# 91        6
# 92        7
# 93        6
# 94        6
# 95        8
# 96        8
# 97        8
# 98        8
# 99        8
# 100       8
# 101       8
# 102       8
# 103       8
# 104       8
# 105       8
# 106       8
# 107      12
# 108       6

# %%
df['levels'].sum()
# Out:
# 711

# %%
pathSectioned['pathSectioned']['currentCourse'][0]
# Out:
# {'index': 0,
#  'debugName': 'Path Section 0',
#  'type': 'learning',
#  'completedUnits': 16,
#  'totalUnits': 16,
#  'units': [{'unitIndex': 0,
#    'levels': [{'id': '1827c77f4eb542854a41b4ef652acd4b',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'pair letters and sounds',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'WarmUp',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '8e87381297e4e6635039788b261e992b',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'ecfa53a69c9989b7ecf145fc0dcb644d',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'pair letters and sounds',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'WarmUp',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'd387f2c2606883b932c6298644ff47af',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'ecfa53a69c9989b7ecf145fc0dcb644d',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['ecfa53a69c9989b7ecf145fc0dcb644d'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 1',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'e1d7202afe07f4b064e3092a2ec6932a',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'ecfa53a69c9989b7ecf145fc0dcb644d',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 1',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '8dafdbd72e366a429ba46952a4735638',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 0},
#      'pathLevelClientData': {'skillIds': ['ecfa53a69c9989b7ecf145fc0dcb644d']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 0',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/1dea1ca70c2092e616c95c6edd6e404948acde0b894a8e9a103883f9b66f8a04235d1dc45e76be9cc9400c28a41ef9698a436cc45a48a58fd06f200a0bdde043/10.json'},
#    'teachingObjective': 'pair letters and sounds',
#    'cefrLevel': None},
#   {'unitIndex': 1,
#    'levels': [{'id': 'd3684875c75f2c79dba71dcf1151be60',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '48c1823a223749ae21671449b383bae4',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '48c1823a223749ae21671449b383bae4',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'recognise letters',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Forms of S',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '036f4f1daa37bead7f38b2a04f6b78eb',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '48c1823a223749ae21671449b383bae4',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '48c1823a223749ae21671449b383bae4',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'recognise letters',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Forms of S',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'ee9ee964097022dca2c51022a05fdee6',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '48c1823a223749ae21671449b383bae4',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['48c1823a223749ae21671449b383bae4'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 2',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '28e8196cdbd9af0110bb0995a893070e',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '48c1823a223749ae21671449b383bae4',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 2',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '20018dfddcd134079cd9ed00fda9724b',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 1},
#      'pathLevelClientData': {'skillIds': ['48c1823a223749ae21671449b383bae4']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 1',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/59896d4e046c1eafdbb449201ab6001419552aeefc628cd4cb46b8c63795696bf9e9a00b72b75110bcb83b0aebe55125b87e1875ab190dc27b4e5136f4b365b7/12.json'},
#    'teachingObjective': 'recognise letters',
#    'cefrLevel': None},
#   {'unitIndex': 2,
#    'levels': [{'id': '81bb9c2bd87d1c698bc5af84931f20b5',
#      'state': 'passed',
#      'finishedSessions': 6,
#      'pathLevelMetadata': {'skillId': '57756a0f0fd46db6f19ced10c540def0',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '57756a0f0fd46db6f19ced10c540def0',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'use the articles',
#       'assignmentInfo': None},
#      'totalSessions': 6,
#      'debugName': 'Which the?',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '465c8ec26b423c5120a88e292d59249d',
#      'state': 'passed',
#      'finishedSessions': 6,
#      'pathLevelMetadata': {'skillId': '57756a0f0fd46db6f19ced10c540def0',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '57756a0f0fd46db6f19ced10c540def0',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'use the articles',
#       'assignmentInfo': None},
#      'totalSessions': 6,
#      'debugName': 'Which the?',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '56a378896097dbb6137bf9d010a56ecf',
#      'state': 'passed',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': '57756a0f0fd46db6f19ced10c540def0',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['57756a0f0fd46db6f19ced10c540def0'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Unit Practice Level 3',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '167c424dad01b69634f82dbf7cee6e44',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '57756a0f0fd46db6f19ced10c540def0',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 3',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'de3d672e0c74b0f93f746058287cb22a',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 2},
#      'pathLevelClientData': {'skillIds': ['57756a0f0fd46db6f19ced10c540def0']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 2',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/b40d17a2e2465309528d038180b9a5bc4520dd44a696894de9176b63b02989b49fb6a4f0f48c0fea921eecbf6ce301221f0860dc010c4e9ded4f06a9f251129a/12.json'},
#    'teachingObjective': 'use the articles',
#    'cefrLevel': None},
#   {'unitIndex': 3,
#    'levels': [{'id': '63438e32fc6a08a507f3664effaf30f7',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'form basic sentences',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Stretching',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '3b67c4a72021b224fae243d4a23921f5',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'form basic sentences',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Stretching',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '2c0f89ea02b9b2e34395720172bb892d',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['48c1823a223749ae21671449b383bae4',
#        '57756a0f0fd46db6f19ced10c540def0'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 1',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'd3dd316ec743d8c3a513dafdd4490874',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 4',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '2e5fdcf5770f19117fc3de5b5485cd93',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'c45253f3bb7231ba69a91a3d4eac4775',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['c45253f3bb7231ba69a91a3d4eac4775'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 4',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '78789b5a27f1c23848779e2ffbe3760d',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 3},
#      'pathLevelClientData': {'skillIds': ['c45253f3bb7231ba69a91a3d4eac4775']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 3',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/84df31d84bee9ef79362d785fec1cd19b32f6e4e4270e9efc975ecdf055f0215305b35585df9dad6fb2d167699587cb2bafc879cfa0bee2fe8cfb14eb0417cdc/12.json'},
#    'teachingObjective': 'form basic sentences',
#    'cefrLevel': None},
#   {'unitIndex': 4,
#    'levels': [{'id': '13772a61affc3034001978d1c16d4628',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'read any word',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Go',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'aa0a551f0f699b57e1fd6f8559b435c0',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'read any word',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Go',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'f10981b3e641ab89a4368cadd8aebb92',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 5',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '64ca8905eaede748ebf97e33a8cdd63c',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['57756a0f0fd46db6f19ced10c540def0',
#        'c45253f3bb7231ba69a91a3d4eac4775'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 2',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '46f288984c02ff74d46cea47adff1d73',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'a9221e52a05ababf95f37d4f566c4b98',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['a9221e52a05ababf95f37d4f566c4b98'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 5',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '27e722c9cac7d4c2f7bc12fc763b9812',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 4},
#      'pathLevelClientData': {'skillIds': ['a9221e52a05ababf95f37d4f566c4b98']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 4',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/e87806576a8d119212deeefa295e3f5fac825026226f94ea789927a39bf7bcd2ec3da334657c253929eb85c08763bc0c04dd8f1a0d14540aa560b5ebbcf76710/11.json'},
#    'teachingObjective': 'read any word',
#    'cefrLevel': None},
#   {'unitIndex': 5,
#    'levels': [{'id': '596fd479cc2278fc85e4a69784961cb2',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'use basic phrases',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Basics 1',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '4fe9552e5705bbae06fbed369f006ca0',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 6',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'bfe264cbda760188823a332b44e02e6c',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'use basic phrases',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Basics 1',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '3c2c2dca4e2d918fee56bc65eacd34fe',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['c45253f3bb7231ba69a91a3d4eac4775',
#        'a9221e52a05ababf95f37d4f566c4b98'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 3',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '3fc399751af08f4b9588aa0b60cf4d18',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['58b787adea5ae7fad6c85d1559ed71c3'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 6',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '9b24460cf6b57dd63bf75c7c8a5b8319',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '58b787adea5ae7fad6c85d1559ed71c3',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 7',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '1425667bc5334d94db9794d967779a30',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 5},
#      'pathLevelClientData': {'skillIds': ['58b787adea5ae7fad6c85d1559ed71c3']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 5',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/09ec8bfb7255c9279e302d7e31531c3de85824c4da921aa262018dc6ced9c31c41fd1dcbfb47bcd1407c395f963388f093ac21c542fd2760defeae6f4b9ffee9/12.json'},
#    'teachingObjective': 'use basic phrases',
#    'cefrLevel': None},
#   {'unitIndex': 6,
#    'levels': [{'id': '3e2649572669e29bc726bf1d68c98066',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'talk about the present',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Basics 2',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'c3b4728a979294b35dd8ab3555a2b8c9',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'talk about the present',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Basics 2',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '7986a1bb50d6a45b1cb3f73f82941065',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['a9221e52a05ababf95f37d4f566c4b98',
#        '58b787adea5ae7fad6c85d1559ed71c3'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 4',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'e736229c059776a0834309245117c55e',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 8',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '887a4edb3eab1cd2ab5d0bbb7710f53c',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'ef307ced6eebee1c0c322b18574fe9ed',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['ef307ced6eebee1c0c322b18574fe9ed'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 7',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'c9680b1421f23bb39272f68626e517a2',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 6},
#      'pathLevelClientData': {'skillIds': ['ef307ced6eebee1c0c322b18574fe9ed']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 6',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/56a1961bd3ebeca6c5ed3dd669b6573678c855d5fc09ed0b95074d9d5d397423e58e1c33a6e70580180d3a55c84256c751d0a9ca3b8c39476ae8e7de9005213f/12.json'},
#    'teachingObjective': 'talk about the present',
#    'cefrLevel': None},
#   {'unitIndex': 7,
#    'levels': [{'id': 'a673ad9bf992b4db6e063d552267de0a',
#      'state': 'passed',
#      'finishedSessions': 7,
#      'pathLevelMetadata': {'skillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'greet people',
#       'assignmentInfo': None},
#      'totalSessions': 7,
#      'debugName': 'Phrases',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '44735efae3fc8b2e4cf64588c0ce99ab',
#      'state': 'passed',
#      'finishedSessions': 7,
#      'pathLevelMetadata': {'skillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'greet people',
#       'assignmentInfo': None},
#      'totalSessions': 7,
#      'debugName': 'Phrases',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'ba40309961e8e3e723f99c7f80a0ae72',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 9',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'aadd9e14a6224e55b1f737c49355961b',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['a9221e52a05ababf95f37d4f566c4b98',
#        '58b787adea5ae7fad6c85d1559ed71c3',
#        'ef307ced6eebee1c0c322b18574fe9ed'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 5',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '32ffdbb51f3f77ec389fcf0a43579d17',
#      'state': 'passed',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': 'b449587166242e04c2cd7a6e3e91ad56',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['b449587166242e04c2cd7a6e3e91ad56'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Unit Practice Level 8',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '2a1788f5c0b454c3c5126e5bfe80c871',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 7},
#      'pathLevelClientData': {'skillIds': ['b449587166242e04c2cd7a6e3e91ad56']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 7',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/42cce7d70bf022ae8ec4360f4ce94c8fa050c943a44953dd529c3dc184ae2be7aa42758c6a3c8ecd332b046996014d2b06b1a2a9d91a7331073a67608790a4c9/12.json'},
#    'teachingObjective': 'greet people',
#    'cefrLevel': None},
#   {'unitIndex': 8,
#    'levels': [{'id': 'f602f630b8f088f607fded9ccd1cdd6f',
#      'state': 'passed',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'skillId': '828585372845ea50d201004bbe5ea508',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '828585372845ea50d201004bbe5ea508',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'talk about possessions',
#       'assignmentInfo': None},
#      'totalSessions': 3,
#      'debugName': 'Possess.',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'de25d4b1fcbae249160292a3f96c2bdb',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '828585372845ea50d201004bbe5ea508',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 10',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '7fd453330f8c84bc1e32e0d8bd1f6763',
#      'state': 'passed',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'skillId': '828585372845ea50d201004bbe5ea508',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '828585372845ea50d201004bbe5ea508',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'talk about possessions',
#       'assignmentInfo': None},
#      'totalSessions': 3,
#      'debugName': 'Possess.',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'd9df9ef56952694af468322a87dd5dca',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '828585372845ea50d201004bbe5ea508',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['58b787adea5ae7fad6c85d1559ed71c3',
#        'ef307ced6eebee1c0c322b18574fe9ed',
#        'b449587166242e04c2cd7a6e3e91ad56'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 6',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'a694f17143151af08af1da98a3d82477',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '828585372845ea50d201004bbe5ea508',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['828585372845ea50d201004bbe5ea508'],
#       'isPathExtension': False},
#      'totalSessions': 1,
#      'debugName': 'Unit Practice Level 9',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '24f756c9573ef1800e37a7f0f2244337',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '828585372845ea50d201004bbe5ea508',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 11',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'a4b98d797f5037493bbc2ca099ec2b4d',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 8},
#      'pathLevelClientData': {'skillIds': ['828585372845ea50d201004bbe5ea508']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 8',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/9bcf5d4f6f34f69202f2a8f2e09a3ba96353363145363f04bcf535468dd01b444d9fa289f28fb736572ed43d8f3b63a2a686c2c884a53f38fb64b2593f4cdd57/12.json'},
#    'teachingObjective': 'talk about possessions',
#    'cefrLevel': None},
#   {'unitIndex': 9,
#    'levels': [{'id': '6e350e489f067ce92ba81fd22f565e35',
#      'state': 'passed',
#      'finishedSessions': 9,
#      'pathLevelMetadata': {'skillId': '65b2086fff9923650bbf1e4e328faa57',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '65b2086fff9923650bbf1e4e328faa57',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'discuss food and drink',
#       'assignmentInfo': None},
#      'totalSessions': 9,
#      'debugName': 'Food',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '07bc259a939d148e37a0e76551d6822d',
#      'state': 'passed',
#      'finishedSessions': 9,
#      'pathLevelMetadata': {'skillId': '65b2086fff9923650bbf1e4e328faa57',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '65b2086fff9923650bbf1e4e328faa57',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'discuss food and drink',
#       'assignmentInfo': None},
#      'totalSessions': 9,
#      'debugName': 'Food',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '3c0f157df32ccf42eaf424fe54ce8bfb',
#      'state': 'passed',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '65b2086fff9923650bbf1e4e328faa57',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['ef307ced6eebee1c0c322b18574fe9ed',
#        'b449587166242e04c2cd7a6e3e91ad56',
#        '828585372845ea50d201004bbe5ea508'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 7',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'b6066d33f4a648d0d4f7c7472bec0473',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '65b2086fff9923650bbf1e4e328faa57',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 12',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '4744b26d333dde0c5b51324c1b2c7812',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'anchorSkillId': '65b2086fff9923650bbf1e4e328faa57',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['65b2086fff9923650bbf1e4e328faa57'],
#       'isPathExtension': False},
#      'totalSessions': 4,
#      'debugName': 'Unit Practice Level 10',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'aefaa072fec6fd0a791fcc2ea4bb8944',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 9},
#      'pathLevelClientData': {'skillIds': ['65b2086fff9923650bbf1e4e328faa57']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 9',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/578476a70735b36190013c048e25d7d84f26de859bd39e3beab094a6507d0e9618b1b2945417abd98404bdf295e192632b90d3c106aec12fbeea764cffd00284/12.json'},
#    'teachingObjective': 'discuss food and drink',
#    'cefrLevel': None},
#   {'unitIndex': 10,
#    'levels': [{'id': '0a7434aeb347d76d5bdbfba0b6ab8cb3',
#      'state': 'legendary',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'describe your family',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Family',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'cbfffbf6850fd8bf1b567cc57f23963f',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'describe your family',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Family',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '8b48ec6671be7f50edd50f3b1655a0d8',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 13',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'd84189f93fadfa3ba0246a9ecee46987',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['b449587166242e04c2cd7a6e3e91ad56',
#        '828585372845ea50d201004bbe5ea508',
#        '65b2086fff9923650bbf1e4e328faa57'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Practice Level 8',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '59d7f5d331f8bfbade297c0f095b209f',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'a2fd1a97d1ee7c56c22a6c2feea10206',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['a2fd1a97d1ee7c56c22a6c2feea10206'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 11',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '443b72d83dfea82f2419c178a9667f06',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 10},
#      'pathLevelClientData': {'skillIds': ['a2fd1a97d1ee7c56c22a6c2feea10206']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 10',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/a54340de6be4dc40dcd5b2d0dddadf29eba546b8740f3ed5fb1fc56f4fa2650ac5451fe0c25a86c4510a0470883f4988ed08728efdd539ae5d1e1188bb8b33d8/12.json'},
#    'teachingObjective': 'describe your family',
#    'cefrLevel': None},
#   {'unitIndex': 11,
#    'levels': [{'id': '2763e856375dd5e5a9b27a2d6d2de9e4',
#      'state': 'legendary',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': '8103f9c6969977847319ba9514e0c001',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '8103f9c6969977847319ba9514e0c001',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'discuss about animals',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Animals 1',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'f3c88630267abeb841d3427c251697a0',
#      'state': 'legendary',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '8103f9c6969977847319ba9514e0c001',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 14',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'eb99cd20303bfc1e10e9a3f1ef28f0db',
#      'state': 'legendary',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': '8103f9c6969977847319ba9514e0c001',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '8103f9c6969977847319ba9514e0c001',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'discuss about animals',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Animals 1',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '73f9d3d71e25b39ad6cfff6b8c8840a7',
#      'state': 'legendary',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': '8103f9c6969977847319ba9514e0c001',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['828585372845ea50d201004bbe5ea508',
#        '65b2086fff9923650bbf1e4e328faa57',
#        'a2fd1a97d1ee7c56c22a6c2feea10206'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Practice Level 9',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '4609b2a7222c1c882422fe360f7c5e84',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '8103f9c6969977847319ba9514e0c001',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['8103f9c6969977847319ba9514e0c001'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 12',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '7b6d0e890989bb23f9c4e9729508981d',
#      'state': 'legendary',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '8103f9c6969977847319ba9514e0c001',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 15',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'd1c214e161930cfffaed757082253cfd',
#      'state': 'legendary',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 11},
#      'pathLevelClientData': {'skillIds': ['8103f9c6969977847319ba9514e0c001']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 11',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/2d4e2ad3bb1be93e4b754b7e0fab8b376ce09de03e882f212dace4fdd5c6a7c68116cee85174ea103a0939a5716e3db6f4955ce2facb42e041213f8881654025/11.json'},
#    'teachingObjective': 'discuss about animals',
#    'cefrLevel': None},
#   {'unitIndex': 12,
#    'levels': [{'id': 'a1174cb22e5dabad3e759ff4ac4ea20b',
#      'state': 'legendary',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'form the plural',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Plurals',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'cbec8adf2b45820dbc7ffb9a31b52b7b',
#      'state': 'passed',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'form the plural',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Plurals',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '345ec039fd2c2c3f98252137aa836c2a',
#      'state': 'legendary',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['65b2086fff9923650bbf1e4e328faa57',
#        'a2fd1a97d1ee7c56c22a6c2feea10206',
#        '8103f9c6969977847319ba9514e0c001'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Practice Level 10',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'db92f66a52b7259bc348e88800687b4a',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 16',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'f96da8cc0bfeac27516bd28475b7c5c7',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '6627a196d6ed4db15a8e853388ee1e9f',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['6627a196d6ed4db15a8e853388ee1e9f'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 13',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '37fe5a67d4df81ba20731de4bb959b2b',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 12},
#      'pathLevelClientData': {'skillIds': ['6627a196d6ed4db15a8e853388ee1e9f']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 12',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/f257b4bb37f5b1a46e4e09684a1cd3c640a3072245f0e52d47aaf9be69f35ee2dc9fcbbbf51dc7748e585bed1b7accfd786dd0f480a0854371e0660e3719871a/12.json'},
#    'teachingObjective': 'form the plural',
#    'cefrLevel': None},
#   {'unitIndex': 13,
#    'levels': [{'id': '50cbec0330540e955ea68617de7d8c1e',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'discuss clothing',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Clothing',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '713c30f8b3fe9fcd58e8343f3bdb56e6',
#      'state': 'passed',
#      'finishedSessions': 5,
#      'pathLevelMetadata': {'skillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'discuss clothing',
#       'assignmentInfo': None},
#      'totalSessions': 5,
#      'debugName': 'Clothing',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '3b4e8dcf2e674b974538692c7dd7bb96',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 17',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'aa8b3aeded02c62c12246ea5ff32a5da',
#      'state': 'legendary',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['a2fd1a97d1ee7c56c22a6c2feea10206',
#        '8103f9c6969977847319ba9514e0c001',
#        '6627a196d6ed4db15a8e853388ee1e9f'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Practice Level 11',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '53d0fb75d3d32cd6a9b194363dad336a',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': 'e250c469cdb4d0b5875d8c54e3c16810',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['e250c469cdb4d0b5875d8c54e3c16810'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 14',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '70afa5807ab086d93ef5ec720f0d9f91',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 13},
#      'pathLevelClientData': {'skillIds': ['e250c469cdb4d0b5875d8c54e3c16810']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 13',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/81670e04ed46a68c0ed246ac8beca7c5cb7f5039f673fe0f1081ddd690c334c4d552bcc9b8b835d0792383d3166de7d2bdd757eaeb9ab76f5cf0353c4767e11a/9.json'},
#    'teachingObjective': 'discuss clothing',
#    'cefrLevel': None},
#   {'unitIndex': 14,
#    'levels': [{'id': '09c857b2ae89cd0e9023fb4dc50b7b80',
#      'state': 'legendary',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'skillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'ask questions',
#       'assignmentInfo': None},
#      'totalSessions': 3,
#      'debugName': 'Questions',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'f51eff6c44e9942be746cd9223d1aa14',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 18',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'feb7f4f803258d039685d05466f1f38f',
#      'state': 'passed',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'skillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'ask questions',
#       'assignmentInfo': None},
#      'totalSessions': 3,
#      'debugName': 'Questions',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '0f878a705c8e54d2353c3b72f3372df8',
#      'state': 'legendary',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['a2fd1a97d1ee7c56c22a6c2feea10206',
#        '8103f9c6969977847319ba9514e0c001',
#        '6627a196d6ed4db15a8e853388ee1e9f',
#        'e250c469cdb4d0b5875d8c54e3c16810'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Practice Level 12',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '47b1a5af298416892facf016112586fa',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['3104dfac7d4c679f35f78deb27fbca6d'],
#       'isPathExtension': False},
#      'totalSessions': 1,
#      'debugName': 'Unit Practice Level 15',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'd9679d71e801466cdeedeae26820a5eb',
#      'state': 'passed',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '3104dfac7d4c679f35f78deb27fbca6d',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 19',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'c31755ccc6785d37aff9f6ce447b10de',
#      'state': 'passed',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 14},
#      'pathLevelClientData': {'skillIds': ['3104dfac7d4c679f35f78deb27fbca6d']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 14',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/829226685d0c3739fc3b592099e2ca3690bdd5f9775011b2d946bfdc1f62122f7fe3040427806dc3e245e06bde93ca3b7e91462b9c19355c29e83d3f73d31701/11.json'},
#    'teachingObjective': 'ask questions',
#    'cefrLevel': None},
#   {'unitIndex': 15,
#    'levels': [{'id': '7e8d76b1a22f0d1205168e115547677c',
#      'state': 'legendary',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'crownLevelIndex': 0},
#      'pathLevelClientData': {'skillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'crownLevelIndex': 0,
#       'hardModeLevelIndex': 1,
#       'teachingObjective': 'conjugate verbs',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Be & Have',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': 'b0db671186b07a682e034238b80a1b76',
#      'state': 'legendary',
#      'finishedSessions': 4,
#      'pathLevelMetadata': {'skillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'crownLevelIndex': 1},
#      'pathLevelClientData': {'skillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'crownLevelIndex': 1,
#       'hardModeLevelIndex': 3,
#       'teachingObjective': 'conjugate verbs',
#       'assignmentInfo': None},
#      'totalSessions': 4,
#      'debugName': 'Be & Have',
#      'hasLevelReview': True,
#      'type': 'skill',
#      'subtype': 'regular',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '6d68d4acc6c9d7b0473d2a47f7545146',
#      'state': 'legendary',
#      'finishedSessions': 3,
#      'pathLevelMetadata': {'anchorSkillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['8103f9c6969977847319ba9514e0c001',
#        '6627a196d6ed4db15a8e853388ee1e9f',
#        'e250c469cdb4d0b5875d8c54e3c16810',
#        '3104dfac7d4c679f35f78deb27fbca6d'],
#       'isPathExtension': False},
#      'totalSessions': 3,
#      'debugName': 'Practice Level 13',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '53c3044ed9531dcb1064152e4b77765f',
#      'state': 'legendary',
#      'finishedSessions': 1,
#      'pathLevelMetadata': {'anchorSkillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'indexSinceAnchorSkill': 0,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {},
#      'totalSessions': 1,
#      'debugName': 'Chest 20',
#      'hasLevelReview': False,
#      'type': 'chest',
#      'subtype': 'chest',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '92b8713851a66ecb68b5d36deaac51f4',
#      'state': 'legendary',
#      'finishedSessions': 2,
#      'pathLevelMetadata': {'anchorSkillId': '84eec52a8864c4818fa51e1c0ef3703b',
#       'indexSinceAnchorSkill': 1,
#       'treeId': 'd179dfc3f115cc3ad4a0a5877ba9a608'},
#      'pathLevelClientData': {'skillIds': ['84eec52a8864c4818fa51e1c0ef3703b'],
#       'isPathExtension': False},
#      'totalSessions': 2,
#      'debugName': 'Unit Practice Level 16',
#      'hasLevelReview': False,
#      'type': 'practice',
#      'subtype': 'unit_practice',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None},
#     {'id': '5561ea463a1622401f1ea09dc009cb11',
#      'state': 'legendary',
#      'finishedSessions': 0,
#      'pathLevelMetadata': {'unitIndex': 15},
#      'pathLevelClientData': {'skillIds': ['84eec52a8864c4818fa51e1c0ef3703b']},
#      'totalSessions': 1,
#      'debugName': 'Unit Review 15',
#      'hasLevelReview': False,
#      'type': 'unit_review',
#      'subtype': 'unit_review',
#      'isInProgressSequence': False,
#      'dailyRefreshInfo': None}],
#    'guidebook': {'url': 'https://d1btvuu4dwu627.cloudfront.net/guidebook/compiled/el/en/iOS/1/185766b1c4e39fa481a2077ef7dcd6a7c4181e492895ee181ffad6a09c08e0b5db2b8867570ea5dade1b7d93c877b136d6ed48cf8d3221250e10cefdad80688a/12.json'},
#    'teachingObjective': 'conjugate verbs',
#    'cefrLevel': None}],
#  'cefr': None,
#  'summary': {'grammarConceptUrl': 'https://s3.amazonaws.com/duolingo-explanations/path_sections/el_en/grammar_content/d179dfc3f115cc3ad4a0a5877ba9a608/2/web/version_1/section_0.json',
#   'cefrContentUrl': None},
#  'exampleSentence': None}
