# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/stats/duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.duolingo.com/2020-01-02/users/612592391?fields=currentCourse
#
# https://www.duolingo.com/users/Walker441937

# %%
import json

def custom_read_json(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Perform custom operations on the data
    for key, value in data.items():
        # Check if the value is a list (assuming arrays are represented as lists in your JSON)
        if isinstance(value, list):
            max_length = max(len(item) for item in value)
            data[key] = [item + [np.nan] * (max_length - len(item)) for item in value]

    # Create DataFrame from the modified data
    df = pd.DataFrame(data)
    return df

def pad_arrays(list_of_arrays):
    # Find the maximum length among all arrays
    max_length = max(len(arr) for arr in list_of_arrays)

    # Pad each array to match the maximum length
    padded_arrays = []
    for arr in list_of_arrays:
        padded_arr = arr + [np.nan] * (max_length - len(arr))
        padded_arrays.append(padded_arr)

    return padded_arrays

# %%
# !wget https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json
# Out:
# --2024-05-05 07:55:41--  https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3549801 (3.4M) [text/plain]
# Saving to: ‘user.json.2’
#
# user.json.2         100%[===================>]   3.38M  --.-KB/s    in 0.05s
#
# 2024-05-05 07:55:41 (67.1 MB/s) - ‘user.json.2’ saved [3549801/3549801]

# %%
import pandas as pd
import numpy as np

cu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/course.json"

# get with wget first
#uu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/user.json"

course = pd.read_json(cu)
#user = custom_read_json("user.json")

# %%
with open("user.json", 'r') as f:
        data = json.load(f)

# %%
df=pd.DataFrame(data['languages'])
df=df[df['language_string'] == "Greek"]
df
# Out:
#    streak language_string  points  learning language  level  current_learning  \
# 0     252           Greek   25391      True       el     23              True
#
#    sentences_translated  to_next_level
# 0                     0            609

# %%
pd.DataFrame(data['language_data'])
# Out:
#                                                                      el
# bonus_rows                                                           []
# bonus_skills                                                         []
# calendar              [{'skill_id': 'e225023c822807c29eb99193eee6dc4...
# can_transliterate                                                 False
# direction_status                                               released
# exempt_from_health                                                False
# first_time                                                        False
# fluency_score                                                         0
# immersion_enabled                                                 False
# language                                                             el
# language_strength                                                  0.94
# language_string                                                   Greek
# level                                                                23
# level_left                                                          609
# level_percent                                                        82
# level_points                                                       3500
# level_progress                                                     2891
# level_tests           [{'index': 0, 'attempts': 3, 'completed': Fals...
# linkedin_share_url                             https://www.duolingo.com
# max_cefr_level                                                     None
# max_depth_learned                                                    23
# max_level                                                         False
# max_section_index                                                     2
# max_tree_level                                                       23
# next_lesson           {'lesson_number': 1, 'skill_title': 'Warm Up',...
# next_level                                                           24
# no_dep                                                             True
# notifications         {'chrome_app_ad': True, 'net_promoter': False,...
# notify_practice                                                   False
# notify_time                                                        1320
# num_skills_learned                                                   47
# placement_test                                          {'attempts': 1}
# points                                                            25391
# push_practice                                                      True
# skills                [{'language_string': 'Greek', 'dependencies_na...
# streak                                                              252
# tracking_properties   {'direction': 'el<-en', 'took_placementtest': ...
# useSmartReminderTime                                               True

# %%
pathSectioned=pd.DataFrame(course.loc[['pathSectioned'],['currentCourse']])
pathSectioned=pathSectioned.T
units=pd.DataFrame(pathSectioned.loc[:,"pathSectioned"][0])
units
# Out:
#    index       debugName                   type  completedUnits  totalUnits  \
# 0      0  Path Section 0               learning              16          16
# 1      1  Path Section 1               learning              30          40
# 2      2  Path Section 2               learning               0          39
# 3      3  Path Section 3  personalized_practice               0          13
# 4      4  Path Section 4          daily_refresh               0           1
#
#                                                units  cefr  \
# 0  [{'unitIndex': 0, 'levels': [{'id': '1827c77f4...  None
# 1  [{'unitIndex': 16, 'levels': [{'id': '25267f10...  None
# 2  [{'unitIndex': 56, 'levels': [{'id': '92283c66...  None
# 3  [{'unitIndex': 95, 'levels': [{'id': '7627219c...  None
# 4  [{'unitIndex': 108, 'levels': [{'id': '7ab313b...  None
#
#                                              summary exampleSentence
# 0  {'grammarConceptUrl': 'https://s3.amazonaws.co...            None
# 1  {'grammarConceptUrl': 'https://s3.amazonaws.co...            None
# 2  {'grammarConceptUrl': 'https://s3.amazonaws.co...            None
# 3                                               None            None
# 4                                               None            None

# %%
for i in range(len(units['units'])):
  print(pd.DataFrame(units['units'][i]))
# Out:
#     unitIndex                                             levels  \
# 0           0  [{'id': '1827c77f4eb542854a41b4ef652acd4b', 's...
# 1           1  [{'id': 'd3684875c75f2c79dba71dcf1151be60', 's...
# 2           2  [{'id': '81bb9c2bd87d1c698bc5af84931f20b5', 's...
# 3           3  [{'id': '63438e32fc6a08a507f3664effaf30f7', 's...
# 4           4  [{'id': '13772a61affc3034001978d1c16d4628', 's...
# 5           5  [{'id': '596fd479cc2278fc85e4a69784961cb2', 's...
# 6           6  [{'id': '3e2649572669e29bc726bf1d68c98066', 's...
# 7           7  [{'id': 'a673ad9bf992b4db6e063d552267de0a', 's...
# 8           8  [{'id': 'f602f630b8f088f607fded9ccd1cdd6f', 's...
# 9           9  [{'id': '6e350e489f067ce92ba81fd22f565e35', 's...
# 10         10  [{'id': '0a7434aeb347d76d5bdbfba0b6ab8cb3', 's...
# 11         11  [{'id': '2763e856375dd5e5a9b27a2d6d2de9e4', 's...
# 12         12  [{'id': 'a1174cb22e5dabad3e759ff4ac4ea20b', 's...
# 13         13  [{'id': '50cbec0330540e955ea68617de7d8c1e', 's...
# 14         14  [{'id': '09c857b2ae89cd0e9023fb4dc50b7b80', 's...
# 15         15  [{'id': '7e8d76b1a22f0d1205168e115547677c', 's...
#
#                                             guidebook  \
# 0   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 1   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 2   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 3   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 4   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 5   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 6   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 7   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 8   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 9   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 10  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 11  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 12  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 13  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 14  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 15  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
#
#           teachingObjective cefrLevel
# 0   pair letters and sounds      None
# 1         recognise letters      None
# 2          use the articles      None
# 3      form basic sentences      None
# 4             read any word      None
# 5         use basic phrases      None
# 6    talk about the present      None
# 7              greet people      None
# 8    talk about possessions      None
# 9    discuss food and drink      None
# 10     describe your family      None
# 11    discuss about animals      None
# 12          form the plural      None
# 13         discuss clothing      None
# 14            ask questions      None
# 15          conjugate verbs      None
#     unitIndex                                             levels  \
# 0          16  [{'id': '25267f109058748526c6b44eb896aaeb', 's...
# 1          17  [{'id': '6d726734fe998c5c80d0dd525f5a0c6e', 's...
# 2          18  [{'id': '9d8c835a17c65a401722c94aebf03201', 's...
# 3          19  [{'id': '0faea82c55508dd8ab7d43c093bb4d9d', 's...
# 4          20  [{'id': 'ad0006b27baa67720c1b70ac5327800f', 's...
# 5          21  [{'id': '522a51838afce01cae57d4f1b409125d', 's...
# 6          22  [{'id': 'fc86adef113b1537cb487a3d707a6763', 's...
# 7          23  [{'id': '25e1f086dc4ee2b075374e50dc4aaa0d', 's...
# 8          24  [{'id': 'e2fa6322b5e03afdcd4d1bfcec616778', 's...
# 9          25  [{'id': 'd31b966251ecccb2be68e7528bd661ea', 's...
# 10         26  [{'id': '3da36624c92ee42767c0c6e3f71f8d23', 's...
# 11         27  [{'id': '9890c4622ccacceb53e733fb93a9e5c0', 's...
# 12         28  [{'id': 'fd2d7078a03fbfb14fede871c723d5fd', 's...
# 13         29  [{'id': '2da96a939b673f5d8db26a43f4657ba9', 's...
# 14         30  [{'id': '54bfcdc9acb56f98c716c403b9ef1a3e', 's...
# 15         31  [{'id': 'ed26f251142ebb7353a6fa90141fe32e', 's...
# 16         32  [{'id': '0de74e2fad8d81ee83ad2f5e36a632aa', 's...
# 17         33  [{'id': '1fcc10ac9e3c2f2d84761ade7780166f', 's...
# 18         34  [{'id': 'fae1facfe4aa0f7407d52034ee040604', 's...
# 19         35  [{'id': '16b03ff9a6d998426ae5fd50c6010139', 's...
# 20         36  [{'id': '40b7b235b1f3c811113d63d53a4e73f2', 's...
# 21         37  [{'id': '83c83666847bb77854de86d2beaaaf86', 's...
# 22         38  [{'id': '90024d8b5c8a25f7d5c2ca590af18ca8', 's...
# 23         39  [{'id': 'a865029e310db0a91bf427445bd17e54', 's...
# 24         40  [{'id': '62bde205e27ab3622ae15e78dd035e33', 's...
# 25         41  [{'id': '88e0b40ff9367c1128f0fd83c0aeb9be', 's...
# 26         42  [{'id': '1971048a6c620bba47a547e74d77963c', 's...
# 27         43  [{'id': 'cebab46474ea88863107c68adc71ddc0', 's...
# 28         44  [{'id': '681b17d044fc3235f7ed229cfdab4b84', 's...
# 29         45  [{'id': 'f8e8dcffb98b1ce1069fbdadb7e8f6f5', 's...
# 30         46  [{'id': 'f843d447b937bdd24f78f6dca5be7547', 's...
# 31         47  [{'id': '2826933c97bc4a4da785f8bcefa3431e', 's...
# 32         48  [{'id': 'a50e1b008b24a85775230ffc141f26c5', 's...
# 33         49  [{'id': '4f10b8448225f347a6c37c36a6c9a374', 's...
# 34         50  [{'id': 'fee4d549628f0bd7d39b206ccf1b7865', 's...
# 35         51  [{'id': '5181fcc428e55bbb2bd3a356b1e4b269', 's...
# 36         52  [{'id': '89914a18f287880e08ce6d59ec12540d', 's...
# 37         53  [{'id': 'bb23269c98a88ae1bcc4902ad3c298e3', 's...
# 38         54  [{'id': '64d92cd97bca30e4550d0efe99830c6a', 's...
# 39         55  [{'id': '9e5c7798547e8e4152202e2949369e30', 's...
#
#                                             guidebook  \
# 0   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 1   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 2   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 3   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 4   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 5   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 6   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 7   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 8   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 9   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 10  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 11  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 12  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 13                                               None
# 14  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 15  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 16  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 17  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 18  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 19  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 20  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 21  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 22  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 23  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 24  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 25  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 26  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 27  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 28  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 29  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 30  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 31  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 32  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 33  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 34  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 35  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 36  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 37  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 38  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 39  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
#
#                 teachingObjective cefrLevel
# 0             form the accusative      None
# 1          talk about the present      None
# 2                 describe colors      None
# 3    talk about things around you      None
# 4               talk about people      None
# 5    say who something belongs to      None
# 6          talk about the weather      None
# 7          form complex sentences      None
# 8                     use numbers      None
# 9             describe appearance      None
# 10   describe an object or person      None
# 11                 appoint a date      None
# 12         talk about occupations      None
# 13         form complex sentences      None
# 14          talk about one's self      None
# 15        identify common objects      None
# 16  describe a person's character      None
# 17           talk about furniture      None
# 18         talk about your habits      None
# 19                 describe sizes      None
# 20             talk about desires      None
# 21     make indefinite statements      None
# 22                say what you do      None
# 23   talk about how you do things      None
# 24            talk about the past      None
# 25                  give commands      None
# 26          talk about intentions      None
# 27              talk about places      None
# 28                give directions      None
# 29           form the participles      None
# 30      talk about meeting people      None
# 31         form the passive voice      None
# 32              talk about Greece      None
# 33          talk about the future      None
# 34           talk about countries      None
# 35           describe past events      None
# 36       describe actions modally      None
# 37     describe people and things      None
# 38          use relative pronouns      None
# 39             make transit plans      None
#     unitIndex                                             levels  \
# 0          56  [{'id': '92283c66142e3ec6530d4e3ccb6667f1', 's...
# 1          57  [{'id': '4e4f9c7e692009edef8e4e33565a2d97', 's...
# 2          58  [{'id': 'c8e84bd45ba4b555e4d1cc58d0fddcc7', 's...
# 3          59  [{'id': 'f940841c2790a7fe91370786aa381473', 's...
# 4          60  [{'id': '84f10b1c4231aa578d27fc13ad0fbb06', 's...
# 5          61  [{'id': '0391447dca10a96ab8b22eb39a6db407', 's...
# 6          62  [{'id': '4938cdcd6f3df1173dd6665b055d16b3', 's...
# 7          63  [{'id': 'bd0fa9fa14c0f9d3e3e376555d2e03b3', 's...
# 8          64  [{'id': 'afd1348822d527b78f4fc42ee4fad68f', 's...
# 9          65  [{'id': '03a6294ff5e28f6f9da03cfd90f4bb89', 's...
# 10         66  [{'id': '088081f11bbbcafda6f083357a1e54a2', 's...
# 11         67  [{'id': '11c0c18900882cb35bb61371e47b807a', 's...
# 12         68  [{'id': 'b16703364a3f1dba5aecd028b434bda4', 's...
# 13         69  [{'id': '3021cf3616d6121078ad7cfdc060df0b', 's...
# 14         70  [{'id': '3e9364380277aa391c928aea81182029', 's...
# 15         71  [{'id': 'ed224ded9a4d9fcce290a18a3f9e0241', 's...
# 16         72  [{'id': 'e50a1833a445494985ed6d518e4daf1a', 's...
# 17         73  [{'id': '29e5d84eb1abaa97773f1250e72d8651', 's...
# 18         74  [{'id': '7e2e6186dcaf60e2c4f6939ca211c031', 's...
# 19         75  [{'id': 'c5496e8aed5bafa583ccad8c491a0bc9', 's...
# 20         76  [{'id': '6462e2fba68ff58aa66c1ab5685bfd6a', 's...
# 21         77  [{'id': 'e2f690779c84e57c498c44d77cc8ce0e', 's...
# 22         78  [{'id': 'e11ee60ff7a91341e844521cb3b923be', 's...
# 23         79  [{'id': 'f7b5ea1e73c7d729333eb1d92efcdf9f', 's...
# 24         80  [{'id': '0cb164eae57142016cb00b6ba5fc85cb', 's...
# 25         81  [{'id': '1372bc6aa86e674d356be2c8a484370c', 's...
# 26         82  [{'id': 'ccec06b21a4dc7df6a016b77d0a9d23e', 's...
# 27         83  [{'id': '04aae48c64906bd96b8abee07f6b9d52', 's...
# 28         84  [{'id': '6ff5bafc52a2a16bf6ace401e5c8be48', 's...
# 29         85  [{'id': '72efbc2a38e8500fdc725d85f90d6340', 's...
# 30         86  [{'id': '0ed68e258266d053934d2b66f718166f', 's...
# 31         87  [{'id': '64b64d05fdee52ddb609cf6cf7be302f', 's...
# 32         88  [{'id': '94a789f256458406d0a524523ef71fae', 's...
# 33         89  [{'id': '097ebcbba73b1e97a6215eb0dd595334', 's...
# 34         90  [{'id': '52d702b48d7c00ef0df5f314216e0883', 's...
# 35         91  [{'id': '90ec204d4fbd1993db6d623db5dfdb08', 's...
# 36         92  [{'id': '2a19a35a1d653910e65aa148647d76bf', 's...
# 37         93  [{'id': '7246991dc7888c879d34c4b9a62fee99', 's...
# 38         94  [{'id': '08e6dbb8bfa49daf45ce2614f0459112', 's...
#
#                                             guidebook  \
# 0   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 1   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 2   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 3   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 4   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 5   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 6   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 7   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 8   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 9   {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 10  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 11  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 12  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 13  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 14  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 15  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 16  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 17  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 18  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 19  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 20  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 21  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 22  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 23  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 24  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 25  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 26  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 27  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 28  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 29  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 30  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 31  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 32  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 33  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 34  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 35  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 36  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 37  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
# 38  {'url': 'https://d1btvuu4dwu627.cloudfront.net...
#
#                teachingObjective cefrLevel
# 0               make comparisons      None
# 1          express your feelings      None
# 2            talk about the past      None
# 3           use past participles      None
# 4               make comparisons      None
# 5      discuss abstract concepts      None
# 6        say what used to happen      None
# 7            discuss environment      None
# 8             talk about classes      None
# 9         tell others what to do      None
# 10               describe things      None
# 11                discuss sports      None
# 12     talk about your childhood      None
# 13         talk about intentions      None
# 14         discuss art & culture      None
# 15         discuss communication      None
# 16     discuss abstract concepts      None
# 17         talk about the future      None
# 18    talk about the recent past      None
# 19              discuss medicine      None
# 20       identify common animals      None
# 21         talk about the future      None
# 22              discuss politics      None
# 23          talk about materials      None
# 24   talk about the distant past      None
# 25               discuss science      None
# 26          talk about computers      None
# 27          discuss social media      None
# 28     talk about spending money      None
# 29           discuss mathematics      None
# 30        talk about the weather      None
# 31          say what will happen      None
# 32              discuss business      None
# 33               discuss history      None
# 34          discuss spirituality      None
# 35  talk about what might happen      None
# 36            discuss philosophy      None
# 37      talk about social events      None
# 38       discuss Greek mythology      None
#     unitIndex                                             levels guidebook  \
# 0          95  [{'id': '7627219cfb9008b7905a1bb180329f90', 's...      None
# 1          96  [{'id': 'cffd38e41fb8ddea1b4611902e31613e', 's...      None
# 2          97  [{'id': '03a846a9941b303e22db4033760bae16', 's...      None
# 3          98  [{'id': '8de5876f8269b10d3f5d7503863dd2c8', 's...      None
# 4          99  [{'id': '33b7298bb9757069e4af134cf26107d9', 's...      None
# 5         100  [{'id': '6e3b81db00bd2266b2b508db0492286b', 's...      None
# 6         101  [{'id': '137b1124b71ea8bfb67149470b56c62d', 's...      None
# 7         102  [{'id': '894aa6def54752d7e824192f452e625a', 's...      None
# 8         103  [{'id': 'a14078a31d541f645336b8ee4d44b612', 's...      None
# 9         104  [{'id': '2fe285987537e143fe90df72802f1d4b', 's...      None
# 10        105  [{'id': '74c9e4ffe55e37718a71c0fb3d7a4e74', 's...      None
# 11        106  [{'id': 'b6f6aa2b39f499f45595a90a4ce8681d', 's...      None
# 12        107  [{'id': '7cae39e2e1dce0e9f42d7adfb2d5a46c', 's...      None
#
#                                     teachingObjective cefrLevel
# 0   make comparisons, make comparisons, talk about...      None
# 1   talk about the future, describe people and thi...      None
# 2   describe past events, make transit plans, use ...      None
# 3   discuss sports, discuss communication, discuss...      None
# 4   talk about Greece, describe actions modally, d...      None
# 5   identify common animals, talk about the distan...      None
# 6   use relative pronouns, talk about the past, sa...      None
# 7   discuss social media, say what will happen, ta...      None
# 8   discuss art & culture, talk about the recent p...      None
# 9   discuss business, form the passive voice, disc...      None
# 10  discuss philosophy, tell others what to do, ta...      None
# 11  talk about computers, talk about the weather, ...      None
# 12  talk about the future, talk about the future, ...      None
#    unitIndex                                             levels guidebook  \
# 0        108  [{'id': '7ab313bda5a3313945760a79311fecf4', 's...      None
#
#   teachingObjective cefrLevel
# 0              None      None

# %%
len(units['units'])
# Out:
# 5
