# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/pandas/2024_04_16_pandas_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # More on Selecting Data
#
# * .loc()
# * .iloc()
#
# * selecting rows based on column values
#
# * select columns based on row values
#
# * select by boolean condition
#
# * counting and group by

# %% [markdown]
# # pandas_indexing_and_selecting
#
#
# https://www.kaggle.com/datasets/saurabhbadole/latest-data-science-job-salaries-2024
#
# * work_year: The year of the data related to the job salary.
# * experience_level: The level of experience of the employee (e.g., entry-level, mid-level, senior-level).
# employment_type: The type of employment (e.g., full-time, part-time, contract).
# * job_title: The title or role of the employee within the data science field.
# * salary: The salary of the employee.
# * salary_currency: The currency in which the salary is denoted.
# * salary_in_usd: The salary converted to US dollars for standardization.
# * employee_residence: The residence location of the employee.
# * remote_ratio: The ratio of remote work allowed for the position.
# * company_location: The location of the company.
# * company_size: The size of the company based on employee count or revenue.

# %%
import pandas as pd

file="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/pandas/DataScience_salaries_2024.csv"
df = pd.read_csv(file)
df
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# 4       Lead Machine Learning Engineer   7500000             INR
# ...                                ...       ...             ...
# 14833  Business Intelligence Developer     15000             USD
# 14834               Staff Data Analyst     15000             USD
# 14835       Machine Learning Developer     15000             USD
# 14836                     Data Analyst     15000             USD
# 14837                      ML Engineer     14000             EUR
#
#        salary_in_usd employee_residence  remote_ratio company_location  \
# 0              40038                 CL           100               CL
# 1              36259                 HU            50               US
# 2              35735                 HU            50               HU
# 3              77364                 JP            50               JP
# 4              95386                 IN            50               IN
# ...              ...                ...           ...              ...
# 14833          15000                 GH           100               GH
# 14834          15000                 NG             0               CA
# 14835          15000                 TH           100               TH
# 14836          15000                 ID             0               ID
# 14837          15966                 DE           100               DE
#
#       company_size
# 0                L
# 1                L
# 2                L
# 3                S
# 4                L
# ...            ...
# 14833            M
# 14834            M
# 14835            L
# 14836            L
# 14837            S
#
# [14838 rows x 11 columns]

# %%
# you can put [selection, columns]

# .loc look up by labels
# .iloc is look up positions

#df.loc[ some logical statement, columns]



fr = df.loc[(df['company_location'] == 'FR') & (df['work_year'] == 2023), ['salary', 'job_title']]

fr
# Out:
#        salary                                 job_title
# 1895   225000                 Machine Learning Engineer
# 1901   225000                         Research Engineer
# 3169   199000                 Machine Learning Engineer
# 5181   168000                         Research Engineer
# 6612   150000                              AI Developer
# 9655   120000                             AI Programmer
# 10518  110000                             Data Engineer
# 11407  100000  Machine Learning Infrastructure Engineer
# 12125   90000                             Data Engineer
# 13047   75000                             Data Engineer
# 13418   70000               Machine Learning Specialist
# 13456   70000  Machine Learning Infrastructure Engineer
# 13663   65000                             Data Engineer
# 13862   60000                             Data Engineer
# 13885   60000                            Data Scientist
# 14130   53000                             Data Engineer
# 14253   50000                      Data DevOps Engineer
# 14322   48000                             Data Engineer
# 14546   40000               Machine Learning Specialist
# 14554   40000                            Data Scientist
# 14726   30000                         Research Engineer

# %%
df[(df.company_location.isin(['US', 'FR'])) & (df.work_year == 2023)].groupby(['company_location','experience_level','job_title']).mean(numeric_only=True)
# Out:
#                                                                work_year  \
# company_location experience_level job_title
# FR               EN               Research Engineer               2023.0
#                  MI               Data Engineer                   2023.0
#                                   Data Scientist                  2023.0
#                                   Machine Learning Specialist     2023.0
#                  SE               AI Developer                    2023.0
# ...                                                                  ...
# US               SE               Prompt Engineer                 2023.0
#                                   Research Analyst                2023.0
#                                   Research Engineer               2023.0
#                                   Research Scientist              2023.0
#                                   Software Data Engineer          2023.0
#
#                                                                       salary  \
# company_location experience_level job_title
# FR               EN               Research Engineer             30000.000000
#                  MI               Data Engineer                 71571.428571
#                                   Data Scientist                50000.000000
#                                   Machine Learning Specialist   55000.000000
#                  SE               AI Developer                 150000.000000
# ...                                                                      ...
# US               SE               Prompt Engineer              166500.000000
#                                   Research Analyst             132669.350000
#                                   Research Engineer            194935.145455
#                                   Research Scientist           194981.989691
#                                   Software Data Engineer       210000.000000
#
#                                                                salary_in_usd  \
# company_location experience_level job_title
# FR               EN               Research Engineer             32390.000000
#                  MI               Data Engineer                 74997.571429
#                                   Data Scientist                52390.500000
#                                   Machine Learning Specialist   55000.000000
#                  SE               AI Developer                 161952.000000
# ...                                                                      ...
# US               SE               Prompt Engineer              166500.000000
#                                   Research Analyst             132669.350000
#                                   Research Engineer            194935.145455
#                                   Research Scientist           194981.989691
#                                   Software Data Engineer       210000.000000
#
#                                                                remote_ratio
# company_location experience_level job_title
# FR               EN               Research Engineer                0.000000
#                  MI               Data Engineer                   92.857143
#                                   Data Scientist                  50.000000
#                                   Machine Learning Specialist    100.000000
#                  SE               AI Developer                    50.000000
# ...                                                                     ...
# US               SE               Prompt Engineer                  0.000000
#                                   Research Analyst                10.000000
#                                   Research Engineer               10.909091
#                                   Research Scientist               9.278351
#                                   Software Data Engineer         100.000000
#
# [184 rows x 4 columns]

# %%
df[df['experience_level'] == 'EN'].groupby('employee_residence')['salary'].describe()
# Out:
#                     count          mean           std       min        25%  \
# employee_residence
# AR                    3.0  4.666667e+04  1.527525e+04   30000.0    40000.0
# AT                    1.0  5.000000e+04           NaN   50000.0    50000.0
# AU                   10.0  8.025530e+04  3.799970e+04   34160.0    44000.0
# BA                    1.0  1.200000e+05           NaN  120000.0   120000.0
