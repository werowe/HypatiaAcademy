# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/pandas/2024_04_23_pandas_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# make a series

import numpy as np
import pandas as pd

s = pd.DataFrame({
       "studentId": np.random.randint(1000,2000,5),
       "name": np.array(["a", "b", "c", "d", "e"])
    })

s.set_index("studentId",inplace=True)
s
# Out:
#           name
# studentId
# 1402         a
# 1505         b
# 1301         c
# 1333         d
# 1769         e

# %%
s
# Out:
#           name
# studentId
# 1402         a
# 1505         b
# 1301         c
# 1333         d
# 1769         e

# %%
# writing functions

#1.  use def()
#2.  use lambda
#3.  you can user series
#4.  you can use def


# This is our series function
# here we send in a single value.  that is what a series is.  a single value
# one thing is called a primitive or a scalar or a single value (as opposed to some object)
def upperSeries(str):

  return str.upper()

# this is our Row function, meaning one that works with the whole dataframe
# here we send in rows
# a row is a dataframe row.  so it's columns of data.  but here we only have one column
def lowerRow(row):

  row['name'].lower

  return row

upperSeries("tamara")
# Out:
# 'TAMARA'

# %%
# send in the whole dataframe

# axis = 1 means by column, axis = means by row
t=s.apply(lowerRow,axis=1)
t
# Out:
#           name
# studentId
# 1402         a
# 1505         b
# 1301         c
# 1333         d
# 1769         e

# %%
# use Series

u=s['name'].apply(upperSeries)
u
# Out:
# studentId
# 1402    A
# 1505    B
# 1301    C
# 1333    D
# 1769    E
# Name: name, dtype: object

# %%
# instead of using def you can use lambda
# means an in-line function.  also known as autonomous

upperL = lambda x : x.upper()

def upperD(s):
  return s.upper()

upperL("tamara")
# Out:
# 'TAMARA'

# %%
s['name'].apply(lambda x : x.upper())
# Out:
# studentId
# 1402    A
# 1505    B
# 1301    C
# 1333    D
# 1769    E
# Name: name, dtype: object

# %%
# open question:  how can you use lamdba with a row
# walker fix.  why am I no able to use a lambda function here

s = pd.DataFrame({
       "studentId": np.random.randint(1000,2000,5),
       "name": np.array(["a", "b", "c", "d", "e"])
    })

s.set_index("studentId",inplace=True)

s.columns
# open question:  how can you use lamdba with a row
# walker fix.  why am I no able to use a lambda function here
# Out:
# Index(['name'], dtype='object')

# %%
s = pd.DataFrame({
       "studentId": np.random.randint(1000,2000,5),
       "name": np.array(["a", "b", "c", "d", "e"])
    })

s.set_index("studentId",inplace=True)


s = s.apply(lambda row: pd.Series({
     'name': row['name'].lower(),
     'studentId': row.index
     }),axis=1)




s.apply(lambda row: pd.Series({
    'name': row['name'].lower()
    },
    index=row.index), axis=1)

s
# Out:
#           name                        studentId
# studentId
# 1465         a  Index(['name'], dtype='object')
# 1115         b  Index(['name'], dtype='object')
# 1047         c  Index(['name'], dtype='object')
# 1885         d  Index(['name'], dtype='object')
# 1182         e  Index(['name'], dtype='object')

# %%
s
# Out:
#           name                        studentId
# studentId
# 1621         a  Index(['name'], dtype='object')
# 1172         b  Index(['name'], dtype='object')
# 1745         c  Index(['name'], dtype='object')
# 1721         d  Index(['name'], dtype='object')
# 1453         e  Index(['name'], dtype='object')

# %%
# Homework


# make a dataframe with the columns name, age, sex, birthdate (use the date constructor, don't make it a string)

# we don't have any unique value so don't change the index.  in other words
# the index will just a range object


# use def() to uppercase the name

# use lambda() to multiply the age by 2


# print the dataframe
