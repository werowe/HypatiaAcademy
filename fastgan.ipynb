# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/fastgan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
archive = tf.keras.utils.get_file(origin=dataset_url, extract=True)
data_dir = pathlib.Path(archive).with_suffix('')
# !cd flowers


image_count = len(list(data_dir.glob('daisy/*.jpg')))
print(image_count)

daisy = list(data_dir.glob('daisy/*'))
PIL.Image.open(str(daisy[2]))
# Out:
# ...
# 228813984/228813984 [==============================] - 8s 0us/step
# /bin/bash: line 0: cd: flowers: No such file or directory
# 633
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7FA93FB25340>
