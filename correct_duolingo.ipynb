# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/correct_duolingo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.duolingo.com/2020-01-02/users/612592391?fields=currentCourse
#
# https://www.duolingo.com/users/Walker441937

# %%
import pandas as pd
import numpy as np


def unwrap(y):

  totalSessions=[]

  for i in y['levels']:

     totalSessions.append(i['totalSessions'])

  d = {
      "totalSessions": totalSessions,
  }

  return totalSessions

cu="https://raw.githubusercontent.com/werowe/HypatiaAcademy/master/stats/course.json"



course = pd.read_json(cu)


pathSectioned=pd.DataFrame(course.loc[['pathSectioned'],['currentCourse']])
pathSectioned=pathSectioned.T

# %%
import re

e=[]



pattern = r"\b(Chest|Review)\b"


totalLessions = 0

for i in pathSectioned['pathSectioned']['currentCourse']:
 cnt = 1

 for j in (i['units']):
    lessons = []
    d = {}
    section=i['index']+1
    d['section']=section
    if section < 4:
      if d['section'] != prevSection:
        cnt = 1
      d['unit']= cnt
      d['teachingObjective'] = j['teachingObjective']

      lessons = []
      for l in j['levels']:
        skip = re.findall(pattern, l["debugName"])
        if len(skip) == 0:
          lessons.append(l["totalSessions"])
          totalLessions = totalLessions + l["totalSessions"]
      d['lessons'] = lessons
      e.append(d)
      cnt = cnt + 1
      prevSection=d['section']

print("totalLessions=", totalLessions)

df=pd.DataFrame(e)
pd.set_option('display.max_rows', None)


exploded=df.explode("lessons")
#exploded(['exploded'])=
# Out:
# totalLessions= 1583

# %%
exploded
# Out:
#     section  unit              teachingObjective  levels lessons
# 0         1     1        pair letters and sounds       5       5
# 0         1     1        pair letters and sounds       5       5
# 0         1     1        pair letters and sounds       5       2
# 1         1     2              recognise letters       5       4
# 1         1     2              recognise letters       5       4
# 1         1     2              recognise letters       5       2
# 2         1     3               use the articles       5       6
# 2         1     3               use the articles       5       6
# 2         1     3               use the articles       5       3
# 3         1     4           form basic sentences       6       5
# 3         1     4           form basic sentences       6       5
# 3         1     4           form basic sentences       6       2
# 3         1     4           form basic sentences       6       2
# ...
