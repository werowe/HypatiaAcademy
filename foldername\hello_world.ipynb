# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/foldername%5Chello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# When you learn programming.  Traditionally the first thing you learn is how to write "hello world".    This comes from the book The C Language by Kernigan and Ritchie
