# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/charts/2023_03_26_charting_heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# this is data drawn from a normal distribution with mean 0 and standard deviation 3

import matplotlib.pyplot as plt

a = np.random.normal(loc=0, scale=3, size=25)

b= np.round(a).astype(int)
c= b.reshape(5,5)

plt.imshow(c, cmap='viridis')

plt.colorbar()

for i in range(c.shape[0]):
    for j in range(c.shape[1]):
        plt.annotate(str(c[i, j]), xy=(j, i), ha='center', va='center', color='white')


plt.show()

# %% [markdown]
# heatmap charts are used for visualizing patterns, trends, and correlations in data by representing values using colors. They provide an intuitive way to identify areas of high and low density in data, making it easier to detect patterns and anomalies.

# %%
c[2,2]
# Out:
# -3

# %%
import seaborn as sns

# Homework: how do you do annotation on a seaborn chart


sns.heatmap(c)
# Out:
# <Axes: >
