# %% [markdown]
# <a href="https://colab.research.google.com/github/werowe/HypatiaAcademy/blob/master/tree_ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tree Ensemble
#
# Problem is trees and highly sensitive to small changes of the data.  Answer is not to train just one decision tree but a wjole bunch of different decision trees.
#
# A **tree ensemble** is a collection of different trees.
#
# So make multiple trees and pick classification answer that had majority like twice.
#
# ## Sampling with Replacement
#
# Create random training set.
#
#
#
# ## Random Forest
#
# ###Randomizing the feature choice
# At each node, when choosing a feature to use to split, if $n$  features are available, pick a random subset of $k < n$ and allow the algorithm to only choose from that subset of features.
#
# If k is large you could use $k=\sqrt{n}$

# %% [markdown]
# #XGBoost

# %% [markdown]
# ![Screenshot 2025-06-28 at 10.37.06.png](data:image/png;base64,...)

# %%
import xgboost as xgb
model = xgb.XGBClassifier()

model.fit(X_train, y_train)

# %% [markdown]
# # When to use Decision Trees
