# %%
from datetime import date,timedelta
import uuid
import jaydebeapi, os
import random
import simplejson as json


def getToday():
    return date.today().isoformat()

def generateOrderDict(record):
    
    j = {}
    
    columns=record.getColumns()
    values=record.getValues()
    
    
    for i in range(len(columns)):
        j[columns[i]] = values[i]
        
    
    return (j)

# %%
class Customer:
    
    columns = ['customernumber',
     'customername',           
    'phonenumber',
    'postalcode',
    'locale',
    'datecreated',
    'email']
    
    salesOrders = []

    
    def __init__(self):
        
        self.customernumber = str(uuid.uuid1())
        self.customername = randomString(20)
        self.phonenumber = random.randint(1000000,9000000)
        self.postalcode = randomString(4)
        self.locale = ''
        self.datecreated = getToday()
        self.email = randomString(4) + '@' + randomString(4) + ".com"
        
      
        
    def getColumns(self):
        return self.columns
    
    def getValues(self):
               
        return [self.customernumber,
            self.customername,
            self.phonenumber,
            self.postalcode,
            self.locale,
            self.datecreated,
            self.email]

    def getSalesOrders(self):
        return self.salesOrders
     
class SalesOrder:

    columns =  ['customernumber',
        'ordernumber' ,
        'comments' ,
        'orderdate' ,
        'ordertype' ,
        'shipdate'  ,
        'discount'  ,
        'quantity'  ,
        'productnumber']

    def __init__(self, customerNumber):

        self.customernumber = customerNumber
        self.ordernumber = str(uuid.uuid1())
        self.comments = randomString(20)
        self.orderdate =  getToday()
        self.ordertype = "sale"
        self.shipdate  =  (date.today() + timedelta(days=random.randint(3,14))).isoformat()
        self.discount  = random.random()
        self.quantity  = random.randint(1,100)
        self.productnumber = str(uuid.uuid1())  
        
    def getColumns(self):
        return self.columns    
        
        
    def getValues(self):
        return  [ self.customernumber,
        self.ordernumber ,
        self.comments ,
        self.orderdate ,
        self.ordertype ,
        self.shipdate  ,
        self.discount  ,
        self.quantity  ,
        self.productnumber ]

# %%
def randomString(length):
    
    char=""
    for i in range(length):
        char = char + chr(random.randint(97,122))
    return char

# %%
def commaCheck(field):
    
    if isinstance(field,int):
        return  str(field)  
    if isinstance(field,float):
        return  str(field) 
    else:
        return field

# %%
def generateCustomers(c,o,format):
    for i in range(2):        
        customer = Customer()
       
        columns = ','.join([col for col in customer.getColumns()])
        values = ','.join(["'" + commaCheck(value) + "'" for value in customer.getValues()])

        j=""
      
        if format=="SQL":
            sql="insert into customers ({}) values ({});".format(columns,values)
            print(sql)
        else:
            j=generateJSON(customer)
            j=json.dumps(j)
      
        c.write(j)
        generateOrders(customer,o,format)

# %%
def generateOrders(customer,o,format):
    
    for i in range(random.randint(1,4)):
    
        order=SalesOrder(customer.customernumber)
         
        columns = ','.join([col for col in order.getColumns()])
     
        values = ','.join(["'" + commaCheck(value) + "'" for value in order.getValues()])

        j=generateOrderDict(order)
        customer.salesOrders.append(j)
        
        if format=="SQL":
            sql="insert into orders ({}) values ({});".format(columns, values)
            print(sql)
            o.write(sql)
        else:
            print(j)
            o.write(json.dumps(sql))

# %%
def main():
    
    c = open("customers.json", "w")
    o = open("orders.json", "w")
    
    generateCustomers(c,o, "SQL")
    
    c.close()
    o.close()
   

if __name__ == "__main__":
    main()
# Out:
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('5d2b742e-fcaa-11ea-ab7a-0ec120e133fc','zmueovtgomhuodnxykru','5958321','iual','','2020-09-22','brwl@ivye.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('5d2b742e-fcaa-11ea-ab7a-0ec120e133fc','5d2b742f-fcaa-11ea-ab7a-0ec120e133fc','mcngbjyvwgugyyoxfmpp','2020-09-22','sale','2020-10-05','0.7447697120821644','9','5d2b7430-fcaa-11ea-ab7a-0ec120e133fc');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('5d2b742e-fcaa-11ea-ab7a-0ec120e133fc','5d2b7431-fcaa-11ea-ab7a-0ec120e133fc','vxvumhgwrbqunybpcpsf','2020-09-22','sale','2020-09-29','0.7003176040848438','55','5d2b7432-fcaa-11ea-ab7a-0ec120e133fc');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('5d2b742e-fcaa-11ea-ab7a-0ec120e133fc','5d2b7433-fcaa-11ea-ab7a-0ec120e133fc','turhfftpoaudutykjvvc','2020-09-22','sale','2020-09-26','0.22819382130119703','92','5d2b7434-fcaa-11ea-ab7a-0ec120e133fc');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('5d2b7435-fcaa-11ea-ab7a-0ec120e133fc','xpqyaiycptgceffawhtt','2696748','eyzy','','2020-09-22','kavn@hwut.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('5d2b7435-fcaa-11ea-ab7a-0ec120e133fc','5d2b7436-fcaa-11ea-ab7a-0ec120e133fc','vahghkmremftlayqiewt','2020-09-22','sale','2020-09-27','0.648621894018958','85','5d2b7437-fcaa-11ea-ab7a-0ec120e133fc');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('5d2b7435-fcaa-11ea-ab7a-0ec120e133fc','5d2b7438-fcaa-11ea-ab7a-0ec120e133fc','ujwpdiwsoaxfpoetglgf','2020-09-22','sale','2020-09-27','0.2551485676079057','26','5d2b7439-fcaa-11ea-ab7a-0ec120e133fc');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('5d2b7435-fcaa-11ea-ab7a-0ec120e133fc','5d2b743a-fcaa-11ea-ab7a-0ec120e133fc','zmqacdutrwafllhpefwa','2020-09-22','sale','2020-10-03','0.6599368907633423','35','5d2b743b-fcaa-11ea-ab7a-0ec120e133fc');

# %% [markdown]
# ```sql
# CREATE TABLE customers
#   (
#      customernumber     varchar(100) PRIMARY KEY,
#     customername varchar(50),
#     phonenumber varchar(50),
#     postalcode varchar(50),
#     locale varchar(10),
#     datecreated date,
#     email varchar(50)
#   );
#  ```

# %% [markdown]
#
# ```sql
# CREATE TABLE orders
#   (
#      customernumber     varchar(100) PRIMARY KEY,
#     ordernumber varchar(100),
#     comments varchar(200),
#     orderdate date,
#     ordertype varchar(10),
#     shipdate date,
# discount number,
# quantity int,
#     productnumber varchar(50)
# )
# ```
