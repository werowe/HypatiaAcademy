# %%
from datetime import date,timedelta
import uuid

import random
import simplejson as json


def getToday():
    return date.today().isoformat()

def generateOrderDict(record):
    
    j = {}
    
    columns=record.getColumns()
    values=record.getValues()
    
    
    for i in range(len(columns)):
        j[columns[i]] = values[i]
        
    
    return (j)

# %%
class Customer:
    
    columns = ['customernumber',
     'customername',           
    'phonenumber',
    'postalcode',
    'locale',
    'datecreated',
    'email']
    
    salesOrders = []

    
    def __init__(self):
        
        self.customernumber = str(random.randint(100,999))
        self.customername = randomString(20)
        self.phonenumber = random.randint(1000000,9000000)
        self.postalcode = randomString(4)
        self.locale = ''
        self.datecreated = getToday()
        self.email = randomString(4) + '@' + randomString(4) + ".com"
        
      
        
    def getColumns(self):
        return self.columns
    
    def getValues(self):
               
        return [self.customernumber,
            self.customername,
            self.phonenumber,
            self.postalcode,
            self.locale,
            self.datecreated,
            self.email]

    def getSalesOrders(self):
        return self.salesOrders
     
class SalesOrder:
    
    products = ['AA111', 'BB111', 'CC222', 'EE333', 'FF4444']

    columns =  ['customernumber',
        'ordernumber' ,
        'comments' ,
        'orderdate' ,
        'ordertype' ,
        'shipdate'  ,
        'discount'  ,
        'quantity'  ,
        'productnumber']

    def __init__(self, customerNumber):

        self.customernumber = customerNumber
        self.ordernumber = str(random.randint(100,999))
        self.comments = randomString(10)
        self.orderdate =  getToday()
        self.ordertype = "sale"
        self.shipdate  =  (date.today() + timedelta(days=random.randint(3,14))).isoformat()
        self.discount  = random.random()
        self.quantity  = random.randint(1,100)
        self.productnumber = self.products[random.randint(0,4)]  
        
    def getColumns(self):
        return self.columns    
        
        
    def getValues(self):
        return  [ self.customernumber,
        self.ordernumber ,
        self.comments ,
        self.orderdate ,
        self.ordertype ,
        self.shipdate  ,
        self.discount  ,
        self.quantity  ,
        self.productnumber ]

# %%
def randomString(length):
    
    char=""
    for i in range(length):
        char = char + chr(random.randint(97,122))
    return char

# %%
def commaCheck(field):
    
    if isinstance(field,int):
        return  str(field)  
    if isinstance(field,float):
        return  str(field) 
    else:
        return field

# %%
def generateCustomers(c,format):
    for i in range(50):        
        customer = Customer()
       
        columns = ','.join([col for col in customer.getColumns()])
        values = ','.join(["'" + commaCheck(value) + "'" for value in customer.getValues()])

        j=""
      
        if format=="SQL":
            sql="insert into customers ({}) values ({});".format(columns,values)
            print(sql)
            c.write(sql)
        else:
            j=generateJSON(customer)
            j=json.dumps(j)
            c.write(j)
      
        generateOrders(customer,c,format)

# %%
def generateOrders(customer,c,format):
    
    for i in range(random.randint(1,4)):
    
        order=SalesOrder(customer.customernumber)
         
        columns = ','.join([col for col in order.getColumns()])
     
        values = ','.join(["'" + commaCheck(value) + "'" for value in order.getValues()])

        j=generateOrderDict(order)
        customer.salesOrders.append(j)
        
        if format=="SQL":
            sql="insert into orders ({}) values ({});".format(columns, values)
            print(sql)
            c.write(sql)
        else:
            print(j)
            c.write(json.dumps(sql))

# %%
def main():
    
    c = open("customersOrders.sql", "w") 
    
    generateCustomers(c,"SQL")
    
    c.close()
    o.close()
   

if __name__ == "__main__":
    main()
# Out:
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('107','ndjefwkyafqhdrjyytqi','6134905','rdhn','','2020-09-27','qrse@dnzs.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('107','983','drmmdccscf','2020-09-27','sale','2020-10-02','0.881643701171071','94','FF4444');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values 
AA111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('100','544','fpgatiwfaw','2020-09-27','sale','2020-10-11','0.8258998963078106','90','BB111');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('465','gtjouxnpxwwcwlmrjemv','7555856','tpbg','','2020-09-27','odsr@jixx.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('465','906','xllggcenyz','2020-09-27','sale','2020-10-05','0.7278947460892021','43','CC222');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('479','uwjwufxvwjefxongvrpb','3623896','yfnh','','2020-09-27','iaqk@bubu.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('479','849','lnukcjaqwt','2020-09-27','sale','2020-10-01','0.30886822805753633','78','EE333');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('479','397','fzsycahjtr','2020-09-27','sale','2020-09-30','0.3260072225927274','22','CC222');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('309','pujieyvhwvwuozdyrvno','4854800','iamo','','2020-09-27','edwj@blvk.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('309','323','rqwegwkjqi','2020-09-27','sale','2020-10-02','0.6572098624749259','67','BB111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('309','928','mnodzvorvn','2020-09-27','sale','2020-09-30','0.4880353573362931','13','AA111');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('901','vmidltyznhylhncnpdrt','6366936','fhoj','','2020-09-27','mjjr@wkck.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('901','376','lyuokrvwyf','2020-09-27','sale','2020-10-05','0.18981789484127687','76','EE333');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('901','279','urrqjkpqam','2020-09-27','sale','2020-10-06','0.3115574986038332','58','BB111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('901','866','lymdjqhgaj','2020-09-27','sale','2020-10-10','0.4220774372210645','93','BB111');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('824','xeojkckiogctzgjcsckx','5434710','axcd','','2020-09-27','eecl@jllh.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('824','921','pjtfcdvlji','2020-09-27','sale','2020-10-10','0.5271756783900945','55','AA111');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('334','wftovdulwqkosvrzcbpd','3679439','odlo','','2020-09-27','dfbl@bjfv.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('334','791','upachwhhcf','2020-09-27','sale','2020-09-30','0.5249226760202741','68','BB111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('334','666','mothaorjyj','2020-09-27','sale','2020-10-06','0.6639398363955159','34','FF4444');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('856','crsksoofpchmrdmzdtpo','1358766','ocya','','2020-09-27','hyef@vgkt.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('856','885','yfjpsnyyfe','2020-09-27','sale','2020-10-09','0.04267456389552471','72','FF4444');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('856','677','jyjutfrzko','2020-09-27','sale','2020-10-10','0.9104725736130143','56','CC222');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('856','870','pbutsfcjws','2020-09-27','sale','2020-10-01','0.9246719726017096','76','AA111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('856','340','mgcswmypjb','2020-09-27','sale','2020-10-06','0.079180210266518','39','EE333');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('456','dlmiwkiupcrjchkkhpqx','5357877','zthx','','2020-09-27','vrub@wyoj.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('456','990','jwhguptgun','2020-09-27','sale','2020-10-08','0.01581227706725985','90','EE333');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('456','489','yqyjpwpymr','2020-09-27','sale','2020-10-08','0.1977763646464874','89','EE333');
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-503836acb64f> in <module>()
#      10
#      11 if __name__ == "__main__":
# ---> 12     main()
#
# <ipython-input-79-503836acb64f> in main()
#       6
#       7     c.close()
# ----> 8     o.close()
#       9
#      10
#
# NameError: name 'o' is not defined

# %% [markdown]
# ```sql
# CREATE TABLE customers
#   (
#      customernumber     varchar(100) PRIMARY KEY,
#     customername varchar(50),
#     phonenumber varchar(50),
#     postalcode varchar(50),
#     locale varchar(10),
#     datecreated date,
#     email varchar(50)
#   );
#  ```

# %% [markdown]
#
# ```sql
# CREATE TABLE orders
#   (
#      customernumber     varchar(100) PRIMARY KEY,
#     ordernumber varchar(100),
#     comments varchar(200),
#     orderdate date,
#     ordertype varchar(10),
#     shipdate date,
# discount number,
# quantity int,
#     productnumber varchar(50)
# )
# ```
